# %%
import logging
import requests
import pandas as pd
import time
from time import sleep
from tqdm import tqdm  # progress bar package
from processors.update_tokens import main as update_tokens_main
import sys
from db.connection import DatabaseConnection
from db.queries import DatabaseQueries
from config import load_config
import random
import os
from datetime import datetime

# Configure logging globally
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")
logger = logging.getLogger(__name__)

# -------------------------------------------------------------------
def fetch_historical_price(token_mint, api_key):
    """
    Fetch the historical price data for a given token using the Birdeye API endpoint
    /defi/history_price. The API call requests the price history from:
        time_from = now - 188700 (seconds)
        time_to   = now

    Returns a DataFrame with historical snapshots sorted by unixTime or None if not found.
    """
    now = int(time.time())
    time_from = now - 188700  # 188700 seconds before now
    url = f"https://public-api.birdeye.so/defi/history_price?address={token_mint}&address_type=token&type=5m&time_from={time_from}&time_to={now}"
    logger.info(f"fetch_historical_price: Requesting history for token '{token_mint}' from {time_from} to {now}.")
    headers = {
        "accept": "application/json",
        "x-chain": "solana",
        "X-API-KEY": api_key
    }
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        data = response.json()
        if data.get("success") is True:
            items = data.get("data", {}).get("items", [])
            if items:
                df = pd.DataFrame(items)
                df = df.sort_values("unixTime")
                logger.info(f"fetch_historical_price: Retrieved {len(df)} price snapshots for token '{token_mint}'.")
                return df
            else:
                logger.error(f"fetch_historical_price: No items found in API response for token '{token_mint}'. Response: {data}")
                return None
        else:
            logger.error(f"fetch_historical_price: API returned error for token '{token_mint}'. Response: {data}")
            return None
    except requests.RequestException as e:
        logger.error(f"fetch_historical_price: Request error for token '{token_mint}': {e}")
        return None

# -------------------------------------------------------------------
def fetch_token_details(chain_id, token_addresses, api_key):
    """
    Fetch token details from the Birdeye token overview endpoint.
    For each token address, it sends a GET request to:
      https://public-api.birdeye.so/defi/token_overview?address={token}
    The chain is specified in the request headers.

    Returns a DataFrame containing the details for all tokens.
    """
    logger.info(f"fetch_token_details: Starting to fetch details for {len(token_addresses)} tokens on chain '{chain_id}' using Birdeye API.")
    token_details_list = []
    # Filter out any None values
    token_addresses = [address for address in token_addresses if address is not None]
    for token in tqdm(token_addresses, desc='Fetching token details', unit='token'):
        url = f"https://public-api.birdeye.so/defi/token_overview?address={token}"
        headers = {
            "accept": "application/json",
            "x-chain": chain_id,
            "X-API-KEY": api_key
        }
        logger.info(f"fetch_token_details: Fetching details for token: {token}")
        try:
            response = requests.get(url, headers=headers)
            response.raise_for_status()
            data = response.json()
            if data.get("success") is True:
                token_data = data.get("data", {})
                # Ensure the 'address' field exists for merging later.
                if "address" not in token_data:
                    token_data["address"] = token
                token_details_list.append(token_data)
                logger.info(f"fetch_token_details: Retrieved details for token: {token}")
            else:
                logger.error(f"fetch_token_details: API returned error for token {token}. Response: {data}")
            sleep(0.2)  # avoid rate limiting
        except requests.RequestException as e:
            logger.error(f"fetch_token_details: Request error for token {token}: {e}")
            sleep(0.2)
    token_details_df = pd.DataFrame(token_details_list)
    logger.info("fetch_token_details: Finished fetching all token details.")
    return token_details_df

# -------------------------------------------------------------------
def get_closest_price(token, block_time, token_history_data):
    """
    Given a token and a block_time, look up the historical price data for that token
    (as returned by fetch_historical_price) and return the price ('value') from the
    snapshot with the smallest time difference to block_time.
    """
    df = token_history_data.get(token)
    if df is None or df.empty:
        logger.warning(f"get_closest_price: No historical data available for token {token}.")
        return None
    # Calculate the absolute time difference between block_time and all snapshots
    time_diffs = (df["unixTime"] - block_time).abs()
    closest_idx = time_diffs.idxmin()
    closest_price = df.loc[closest_idx, "value"]
    return closest_price

# -------------------------------------------------------------------
def main():
    # Initialize configuration and database connections
    config = load_config()
    db_connection = DatabaseConnection(config.db)
    db_queries = DatabaseQueries(db_connection)

    try:
        logger.info("main: Starting main function execution.")

        # (1) Optionally update token information
        # logger.info("main: Calling update_tokens.main()...")
        # update_tokens_main()

        # (2) Fetch recent transactions (e.g., from the past 6 hours)
        logger.info("main: Fetching recent transactions...")
        transactions_df = db_queries.get_recent_transactions(n=3)
        logger.info(f"main: Fetched {len(transactions_df)} transactions.")

        # (3) Fetch token details once using the Birdeye API
        token_columns = ["open_input_mint", "open_output_mint", "close_input_mint", "close_output_mint"]
        unique_tokens = pd.unique(transactions_df[token_columns].values.ravel())
        logger.info(f"main: Found {len(unique_tokens)} unique token addresses for details.")
        chain_id = "solana"
        token_details_df = fetch_token_details(chain_id, unique_tokens, config.birdeye.api_key)

        # (4) Add new columns for tokens and their historical prices
        transactions_df["input_token"] = None
        transactions_df["output_token"] = None
        transactions_df["input_price"] = None
        transactions_df["output_price"] = None

        # (5) For each distinct token, fetch its historical price snapshots once
        logger.info("main: Fetching historical price data for each unique token...")
        token_history_data = {}
        for token in tqdm(unique_tokens, desc="Fetching token historical prices", unit="token"):
            df_history = fetch_historical_price(token, config.birdeye.api_key)
            if df_history is not None:
                token_history_data[token] = df_history
            else:
                logger.warning(f"main: No historical data found for token {token}.")
            sleep(0.2)  # To avoid rate limiting

        # (6) Process each transaction to look up the closest historical price for both input and output tokens
        logger.info("main: Processing transactions to calculate historical prices...")
        for index, row in tqdm(transactions_df.iterrows(), total=len(transactions_df), desc="Processing transactions"):
            if pd.notnull(row["open_input_mint"]):
                input_token = row["open_input_mint"]
                output_token = row["open_output_mint"]
                block_time = row["open_block_time"]
            else:
                input_token = row["close_input_mint"]
                output_token = row["close_output_mint"]
                block_time = row["close_block_time"]

            transactions_df.at[index, "input_token"] = input_token
            transactions_df.at[index, "output_token"] = output_token

            # Look up the closest price snapshot for each token based on block_time
            input_price = get_closest_price(input_token, block_time, token_history_data)
            output_price = get_closest_price(output_token, block_time, token_history_data)

            transactions_df.at[index, "input_price"] = input_price
            transactions_df.at[index, "output_price"] = output_price

        # (7) Calculate per-transaction dollar amounts
        logger.info("main: Calculating per-transaction dollar values...")
        transactions_df["dollars_sold"] = (
                transactions_df["in_amount"].astype(float) *
                transactions_df["input_price"].astype(float)
        )
        transactions_df["dollars_bought"] = (
                transactions_df["out_amount"].astype(float) *
                transactions_df["output_price"].astype(float)
        )

        # (8) Aggregate dollar amounts per token
        logger.info("main: Aggregating dollar values per token...")
        aggregated_sold = (
            transactions_df.groupby("input_token")["dollars_sold"]
            .sum()
            .reset_index()
            .rename(columns={"input_token": "token"})
        )
        aggregated_bought = (
            transactions_df.groupby("output_token")["dollars_bought"]
            .sum()
            .reset_index()
            .rename(columns={"output_token": "token"})
        )
        aggregated = pd.merge(aggregated_sold, aggregated_bought, on="token", how="outer")
        aggregated["dollars_sold"] = aggregated["dollars_sold"].fillna(0)
        aggregated["dollars_bought"] = aggregated["dollars_bought"].fillna(0)
        logger.info("main: Aggregated token values:")
        logger.info(aggregated)

        # (9) Merge aggregated data with token details
        # We merge on the token address field ("address") from the Birdeye API data.
        logger.info("main: Merging aggregated data with token details...")
        final_df = pd.merge(aggregated, token_details_df, left_on="token", right_on="address", how="left")

        # (10) Format dollars columns to use a comma as the decimal separator
        logger.info("main: Formatting dollar values with comma as decimal separator...")
        final_df["dollars_sold"] = final_df["dollars_sold"].apply(lambda x: f"{x:.2f}".replace('.',','))
        final_df["dollars_bought"] = final_df["dollars_bought"].apply(lambda x: f"{x:.2f}".replace('.',','))

        # (11) Remove timezone information for Excel compatibility
        for col in transactions_df.select_dtypes(include=["datetimetz"]).columns:
            transactions_df[col] = transactions_df[col].dt.tz_localize(None)
        for col in final_df.select_dtypes(include=["datetimetz"]).columns:
            final_df[col] = final_df[col].dt.tz_localize(None)

        # (12) Create a folder to store generated Excel files (if not exists) and write the final merged output to an Excel file.
        output_folder = "../data/"
        if not os.path.exists(output_folder):
            os.makedirs(output_folder)
            logger.info(f"main: Created output folder '{output_folder}'.")

        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        excel_filename = f"final_aggregated_token_details_{timestamp}.xlsx"
        output_path = os.path.join(output_folder, excel_filename)

        logger.info(f"main: Writing final aggregated token details to Excel file at '{output_path}'...")
        final_df.to_excel(output_path, index=False)
        logger.info("main: Final Excel file written successfully.")
        print(final_df)

    except Exception as e:
        logger.error(f"main: An error occurred: {e}", exc_info=True)
    finally:
        db_connection.close()
        logger.info("main: Database connection closed.")

if __name__ == "__main__":
    main()
# Out:
# INFO:__main__:main: Starting main function execution.
# INFO:__main__:main: Fetching recent transactions...
# INFO:db.queries:Fetching recent transactions for the past 3 hours.
# INFO:db.queries:Fetched 433 rows of transactions.
# INFO:__main__:main: Fetched 433 transactions.
# INFO:__main__:main: Found 94 unique token addresses for details.
# INFO:__main__:fetch_token_details: Starting to fetch details for 94 tokens on chain 'solana' using Birdeye API.
# Fetching token details:   0%|          | 0/93 [00:00<?, ?token/s]INFO:__main__:fetch_token_details: Fetching details for token: BonK1YhkXEGLZzwtcvRTip3gAL9nCeQD7ppZBLXhtTs
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=BonK1YhkXEGLZzwtcvRTip3gAL9nCeQD7ppZBLXhtTs HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: BonK1YhkXEGLZzwtcvRTip3gAL9nCeQD7ppZBLXhtTs
# Fetching token details:   1%|          | 1/93 [00:00<01:09,  1.32token/s]INFO:__main__:fetch_token_details: Fetching details for token: 7GCihgDB8fe6KNjn2MYtkzZcRjQy3t9GHdC8uHYmW2hr
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=7GCihgDB8fe6KNjn2MYtkzZcRjQy3t9GHdC8uHYmW2hr HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 7GCihgDB8fe6KNjn2MYtkzZcRjQy3t9GHdC8uHYmW2hr
# Fetching token details:   2%|▏         | 2/93 [00:01<00:56,  1.61token/s]INFO:__main__:fetch_token_details: Fetching details for token: 2nCeHpECQvnMfzjU5fDMAKws1vBxMzxvWr6qqLpApump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=2nCeHpECQvnMfzjU5fDMAKws1vBxMzxvWr6qqLpApump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 2nCeHpECQvnMfzjU5fDMAKws1vBxMzxvWr6qqLpApump
# Fetching token details:   3%|▎         | 3/93 [00:01<00:48,  1.87token/s]INFO:__main__:fetch_token_details: Fetching details for token: 9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump
# Fetching token details:   4%|▍         | 4/93 [00:02<00:43,  2.02token/s]INFO:__main__:fetch_token_details: Fetching details for token: So11111111111111111111111111111111111111112
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=So11111111111111111111111111111111111111112 HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: So11111111111111111111111111111111111111112
# Fetching token details:   5%|▌         | 5/93 [00:02<00:42,  2.09token/s]INFO:__main__:fetch_token_details: Fetching details for token: Gh8yeA9vH5Fun7J6esFH3mV65cQTBpxk9Z5XpzU7pump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=Gh8yeA9vH5Fun7J6esFH3mV65cQTBpxk9Z5XpzU7pump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: Gh8yeA9vH5Fun7J6esFH3mV65cQTBpxk9Z5XpzU7pump
# Fetching token details:   6%|▋         | 6/93 [00:03<00:39,  2.19token/s]INFO:__main__:fetch_token_details: Fetching details for token: LGNDeXXXaDDeRerwwHfUtPBNz5s6vrn1NMSt9hdaCwx
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=LGNDeXXXaDDeRerwwHfUtPBNz5s6vrn1NMSt9hdaCwx HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: LGNDeXXXaDDeRerwwHfUtPBNz5s6vrn1NMSt9hdaCwx
# Fetching token details:   8%|▊         | 7/93 [00:03<00:38,  2.23token/s]INFO:__main__:fetch_token_details: Fetching details for token: EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# Fetching token details:   9%|▊         | 8/93 [00:03<00:37,  2.28token/s]INFO:__main__:fetch_token_details: Fetching details for token: Cjrrc595e9R47EZ3gkbUmL6ZZpLSxiXg16v2Y3Aapump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=Cjrrc595e9R47EZ3gkbUmL6ZZpLSxiXg16v2Y3Aapump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: Cjrrc595e9R47EZ3gkbUmL6ZZpLSxiXg16v2Y3Aapump
# Fetching token details:  10%|▉         | 9/93 [00:04<00:37,  2.22token/s]INFO:__main__:fetch_token_details: Fetching details for token: 5zaGbQSZk2pSSugnKojH3NxpVkcvGFqQbYH6fuuofAAA
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=5zaGbQSZk2pSSugnKojH3NxpVkcvGFqQbYH6fuuofAAA HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 5zaGbQSZk2pSSugnKojH3NxpVkcvGFqQbYH6fuuofAAA
# Fetching token details:  11%|█         | 10/93 [00:04<00:36,  2.25token/s]INFO:__main__:fetch_token_details: Fetching details for token: C1odMKziGNXd8g9w6qxVfRvwuSfFaUW66XfKb6rTpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=C1odMKziGNXd8g9w6qxVfRvwuSfFaUW66XfKb6rTpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: C1odMKziGNXd8g9w6qxVfRvwuSfFaUW66XfKb6rTpump
# Fetching token details:  12%|█▏        | 11/93 [00:05<00:36,  2.27token/s]INFO:__main__:fetch_token_details: Fetching details for token: 8U6TLeWtxCTPQ6e4W7qDvLEGUnu8L3hJeL1ZN6CgAXm9
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=8U6TLeWtxCTPQ6e4W7qDvLEGUnu8L3hJeL1ZN6CgAXm9 HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 8U6TLeWtxCTPQ6e4W7qDvLEGUnu8L3hJeL1ZN6CgAXm9
# Fetching token details:  13%|█▎        | 12/93 [00:05<00:36,  2.21token/s]INFO:__main__:fetch_token_details: Fetching details for token: J8njvmBmUYS4RfdQdoszQj3QcbaobbBwjD37Zr36pump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=J8njvmBmUYS4RfdQdoszQj3QcbaobbBwjD37Zr36pump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: J8njvmBmUYS4RfdQdoszQj3QcbaobbBwjD37Zr36pump
# Fetching token details:  14%|█▍        | 13/93 [00:06<00:34,  2.29token/s]INFO:__main__:fetch_token_details: Fetching details for token: ADkDZN4S6DecsCdiXsfquVkRMjSf8JtEvLBJBTYQojHT
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=ADkDZN4S6DecsCdiXsfquVkRMjSf8JtEvLBJBTYQojHT HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: ADkDZN4S6DecsCdiXsfquVkRMjSf8JtEvLBJBTYQojHT
# Fetching token details:  15%|█▌        | 14/93 [00:06<00:34,  2.32token/s]INFO:__main__:fetch_token_details: Fetching details for token: 4V68SgViyBsEv37ridbG7pxzd1V78fVMHGaCHa2HGZMp
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=4V68SgViyBsEv37ridbG7pxzd1V78fVMHGaCHa2HGZMp HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 4V68SgViyBsEv37ridbG7pxzd1V78fVMHGaCHa2HGZMp
# Fetching token details:  16%|█▌        | 15/93 [00:06<00:33,  2.34token/s]INFO:__main__:fetch_token_details: Fetching details for token: 2yd2Suus3YY4Sa7LHhn1PSHkjXj3XKrars4cCog2tGU8
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=2yd2Suus3YY4Sa7LHhn1PSHkjXj3XKrars4cCog2tGU8 HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 2yd2Suus3YY4Sa7LHhn1PSHkjXj3XKrars4cCog2tGU8
# Fetching token details:  17%|█▋        | 16/93 [00:07<00:32,  2.39token/s]INFO:__main__:fetch_token_details: Fetching details for token: AxriehR6Xw3adzHopnvMn7GcpRFcD41ddpiTWMg6pump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=AxriehR6Xw3adzHopnvMn7GcpRFcD41ddpiTWMg6pump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: AxriehR6Xw3adzHopnvMn7GcpRFcD41ddpiTWMg6pump
# Fetching token details:  18%|█▊        | 17/93 [00:07<00:32,  2.37token/s]INFO:__main__:fetch_token_details: Fetching details for token: STrikemJEk2tFVYpg7SMo9nGPrnJ56fHnS1K7PV2fPw
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=STrikemJEk2tFVYpg7SMo9nGPrnJ56fHnS1K7PV2fPw HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: STrikemJEk2tFVYpg7SMo9nGPrnJ56fHnS1K7PV2fPw
# Fetching token details:  19%|█▉        | 18/93 [00:08<00:31,  2.41token/s]INFO:__main__:fetch_token_details: Fetching details for token: 6ogzHhzdrQr9Pgv6hZ2MNze7UrzBMAFyBBWUYp1Fhitx
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=6ogzHhzdrQr9Pgv6hZ2MNze7UrzBMAFyBBWUYp1Fhitx HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 6ogzHhzdrQr9Pgv6hZ2MNze7UrzBMAFyBBWUYp1Fhitx
# Fetching token details:  20%|██        | 19/93 [00:08<00:31,  2.33token/s]INFO:__main__:fetch_token_details: Fetching details for token: BLUv63M5ib2U62EeYhjHgC5dBe5cbW87TbeCQEqjpoDe
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=BLUv63M5ib2U62EeYhjHgC5dBe5cbW87TbeCQEqjpoDe HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: BLUv63M5ib2U62EeYhjHgC5dBe5cbW87TbeCQEqjpoDe
# Fetching token details:  22%|██▏       | 20/93 [00:09<00:31,  2.35token/s]INFO:__main__:fetch_token_details: Fetching details for token: AcS3jVxHJSVdz6rNYcKfZuQcuQG9wfY4KBrUaSqLVQoM
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=AcS3jVxHJSVdz6rNYcKfZuQcuQG9wfY4KBrUaSqLVQoM HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: AcS3jVxHJSVdz6rNYcKfZuQcuQG9wfY4KBrUaSqLVQoM
# Fetching token details:  23%|██▎       | 21/93 [00:09<00:31,  2.29token/s]INFO:__main__:fetch_token_details: Fetching details for token: 3RQezWojDNw4kVfYZAiav1Fq3RnB1DmLxnhHKReQTYEb
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=3RQezWojDNw4kVfYZAiav1Fq3RnB1DmLxnhHKReQTYEb HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 3RQezWojDNw4kVfYZAiav1Fq3RnB1DmLxnhHKReQTYEb
# Fetching token details:  24%|██▎       | 22/93 [00:09<00:30,  2.32token/s]INFO:__main__:fetch_token_details: Fetching details for token: 9FmQWVDqiwCjVw1dDbb4pALB9C9CMCRBBDYvtbCCpkR
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=9FmQWVDqiwCjVw1dDbb4pALB9C9CMCRBBDYvtbCCpkR HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 9FmQWVDqiwCjVw1dDbb4pALB9C9CMCRBBDYvtbCCpkR
# Fetching token details:  25%|██▍       | 23/93 [00:10<00:30,  2.27token/s]INFO:__main__:fetch_token_details: Fetching details for token: A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump
# Fetching token details:  26%|██▌       | 24/93 [00:10<00:30,  2.29token/s]INFO:__main__:fetch_token_details: Fetching details for token: 9RjwNo6hBPkxayWHCqQD1VjaH8igSizEseNZNbddpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=9RjwNo6hBPkxayWHCqQD1VjaH8igSizEseNZNbddpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 9RjwNo6hBPkxayWHCqQD1VjaH8igSizEseNZNbddpump
# Fetching token details:  27%|██▋       | 25/93 [00:11<00:28,  2.35token/s]INFO:__main__:fetch_token_details: Fetching details for token: 2mhszy8YHwqs1fxruVHQQAUmNcfq31mtkmYYtNZNpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=2mhszy8YHwqs1fxruVHQQAUmNcfq31mtkmYYtNZNpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 2mhszy8YHwqs1fxruVHQQAUmNcfq31mtkmYYtNZNpump
# Fetching token details:  28%|██▊       | 26/93 [00:11<00:28,  2.39token/s]INFO:__main__:fetch_token_details: Fetching details for token: JUPyiwrYJFskUPiHa7hkeR8VUtAeFoSYbKedZNsDvCN
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=JUPyiwrYJFskUPiHa7hkeR8VUtAeFoSYbKedZNsDvCN HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: JUPyiwrYJFskUPiHa7hkeR8VUtAeFoSYbKedZNsDvCN
# Fetching token details:  29%|██▉       | 27/93 [00:11<00:27,  2.42token/s]INFO:__main__:fetch_token_details: Fetching details for token: 7mHCx9iXPJ7EJDbDAUGmej39Kme8cxZfeVi1EAvEpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=7mHCx9iXPJ7EJDbDAUGmej39Kme8cxZfeVi1EAvEpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 7mHCx9iXPJ7EJDbDAUGmej39Kme8cxZfeVi1EAvEpump
# Fetching token details:  30%|███       | 28/93 [00:12<00:27,  2.39token/s]INFO:__main__:fetch_token_details: Fetching details for token: 6P8ixuqGZpfyHAxyxbU4a31vsMiFiCQjBzVV58gPpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=6P8ixuqGZpfyHAxyxbU4a31vsMiFiCQjBzVV58gPpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 6P8ixuqGZpfyHAxyxbU4a31vsMiFiCQjBzVV58gPpump
# Fetching token details:  31%|███       | 29/93 [00:12<00:26,  2.42token/s]INFO:__main__:fetch_token_details: Fetching details for token: BzpqoPc44oaHu9SB5hek1GRNjzc4UwFcL4oWusWozm3N
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=BzpqoPc44oaHu9SB5hek1GRNjzc4UwFcL4oWusWozm3N HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: BzpqoPc44oaHu9SB5hek1GRNjzc4UwFcL4oWusWozm3N
# Fetching token details:  32%|███▏      | 30/93 [00:13<00:25,  2.44token/s]INFO:__main__:fetch_token_details: Fetching details for token: Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB
# Fetching token details:  33%|███▎      | 31/93 [00:13<00:25,  2.43token/s]INFO:__main__:fetch_token_details: Fetching details for token: 9kEcnFj9vwShFtjyLNULGFugBS9KrYAazMAcx3GWpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=9kEcnFj9vwShFtjyLNULGFugBS9KrYAazMAcx3GWpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 9kEcnFj9vwShFtjyLNULGFugBS9KrYAazMAcx3GWpump
# Fetching token details:  34%|███▍      | 32/93 [00:14<00:25,  2.42token/s]INFO:__main__:fetch_token_details: Fetching details for token: DKu9kykSfbN5LBfFXtNNDPaX35o4Fv6vJ9FKk7pZpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=DKu9kykSfbN5LBfFXtNNDPaX35o4Fv6vJ9FKk7pZpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: DKu9kykSfbN5LBfFXtNNDPaX35o4Fv6vJ9FKk7pZpump
# Fetching token details:  35%|███▌      | 33/93 [00:14<00:24,  2.44token/s]INFO:__main__:fetch_token_details: Fetching details for token: 9McvH6w97oewLmPxqQEoHUAv3u5iYMyQ9AeZZhguYf1T
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=9McvH6w97oewLmPxqQEoHUAv3u5iYMyQ9AeZZhguYf1T HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 9McvH6w97oewLmPxqQEoHUAv3u5iYMyQ9AeZZhguYf1T
# Fetching token details:  37%|███▋      | 34/93 [00:14<00:24,  2.39token/s]INFO:__main__:fetch_token_details: Fetching details for token: 4Atupq32xLbD7Txa38fP2oxAv6RGNca62CBPw817vbxC
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=4Atupq32xLbD7Txa38fP2oxAv6RGNca62CBPw817vbxC HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 4Atupq32xLbD7Txa38fP2oxAv6RGNca62CBPw817vbxC
# Fetching token details:  38%|███▊      | 35/93 [00:15<00:24,  2.36token/s]INFO:__main__:fetch_token_details: Fetching details for token: FSTRgYfDaudjDwFg5A9LQpDMq5vxqhskHq4rkjUMwERE
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=FSTRgYfDaudjDwFg5A9LQpDMq5vxqhskHq4rkjUMwERE HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: FSTRgYfDaudjDwFg5A9LQpDMq5vxqhskHq4rkjUMwERE
# Fetching token details:  39%|███▊      | 36/93 [00:15<00:24,  2.37token/s]INFO:__main__:fetch_token_details: Fetching details for token: eL5fUxj2J4CiQsmW85k5FG9DvuQjjUoBHoQBi2Kpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=eL5fUxj2J4CiQsmW85k5FG9DvuQjjUoBHoQBi2Kpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: eL5fUxj2J4CiQsmW85k5FG9DvuQjjUoBHoQBi2Kpump
# Fetching token details:  40%|███▉      | 37/93 [00:16<00:23,  2.38token/s]INFO:__main__:fetch_token_details: Fetching details for token: FzsP5hGf2UHcLpwQjY8jwszHfNZShAfFaVLAXFs5HZBN
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=FzsP5hGf2UHcLpwQjY8jwszHfNZShAfFaVLAXFs5HZBN HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: FzsP5hGf2UHcLpwQjY8jwszHfNZShAfFaVLAXFs5HZBN
# Fetching token details:  41%|████      | 38/93 [00:16<00:23,  2.36token/s]INFO:__main__:fetch_token_details: Fetching details for token: EWMfSJgDCE7CXDAYz3hbCaA7NsFHTnddySXx3shco2Hs
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=EWMfSJgDCE7CXDAYz3hbCaA7NsFHTnddySXx3shco2Hs HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: EWMfSJgDCE7CXDAYz3hbCaA7NsFHTnddySXx3shco2Hs
# Fetching token details:  42%|████▏     | 39/93 [00:17<00:22,  2.35token/s]INFO:__main__:fetch_token_details: Fetching details for token: 4dikXY7cZW2R5Zout46LLEGrS4Zn2K8Dm6AQJhtg1H56
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=4dikXY7cZW2R5Zout46LLEGrS4Zn2K8Dm6AQJhtg1H56 HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 4dikXY7cZW2R5Zout46LLEGrS4Zn2K8Dm6AQJhtg1H56
# Fetching token details:  43%|████▎     | 40/93 [00:17<00:22,  2.37token/s]INFO:__main__:fetch_token_details: Fetching details for token: AKvyTsNr7v7x4WhEU6Z8X2Muh1uBTQNJgMoB39bB4LGE
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=AKvyTsNr7v7x4WhEU6Z8X2Muh1uBTQNJgMoB39bB4LGE HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: AKvyTsNr7v7x4WhEU6Z8X2Muh1uBTQNJgMoB39bB4LGE
# Fetching token details:  44%|████▍     | 41/93 [00:17<00:22,  2.35token/s]INFO:__main__:fetch_token_details: Fetching details for token: AATo232QyveLNTcUbxbv4LMLxaQe133a1jx3RjiGpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=AATo232QyveLNTcUbxbv4LMLxaQe133a1jx3RjiGpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: AATo232QyveLNTcUbxbv4LMLxaQe133a1jx3RjiGpump
# Fetching token details:  45%|████▌     | 42/93 [00:18<00:21,  2.39token/s]INFO:__main__:fetch_token_details: Fetching details for token: 9VpurAQLFaRQcTuJ3oVHdGDwJ8LRFWJA3ZVsYySsmoon
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=9VpurAQLFaRQcTuJ3oVHdGDwJ8LRFWJA3ZVsYySsmoon HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 9VpurAQLFaRQcTuJ3oVHdGDwJ8LRFWJA3ZVsYySsmoon
# Fetching token details:  46%|████▌     | 43/93 [00:18<00:21,  2.37token/s]INFO:__main__:fetch_token_details: Fetching details for token: 9hYWua8e8YFDJdDmQML4RVqVZaFFR3hXs9HJjpMUpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=9hYWua8e8YFDJdDmQML4RVqVZaFFR3hXs9HJjpMUpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 9hYWua8e8YFDJdDmQML4RVqVZaFFR3hXs9HJjpMUpump
# Fetching token details:  47%|████▋     | 44/93 [00:19<00:21,  2.33token/s]INFO:__main__:fetch_token_details: Fetching details for token: FwzpNxnabjZvc8QCnV6qPEBKxqLxSyjobc5Etdgxpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=FwzpNxnabjZvc8QCnV6qPEBKxqLxSyjobc5Etdgxpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: FwzpNxnabjZvc8QCnV6qPEBKxqLxSyjobc5Etdgxpump
# Fetching token details:  48%|████▊     | 45/93 [00:19<00:20,  2.35token/s]INFO:__main__:fetch_token_details: Fetching details for token: J3NKxxXZcnNiMjKw9hYb2K4LUxgwB6t1FtPtQVsv3KFr
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=J3NKxxXZcnNiMjKw9hYb2K4LUxgwB6t1FtPtQVsv3KFr HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: J3NKxxXZcnNiMjKw9hYb2K4LUxgwB6t1FtPtQVsv3KFr
# Fetching token details:  49%|████▉     | 46/93 [00:20<00:20,  2.34token/s]INFO:__main__:fetch_token_details: Fetching details for token: 2qWN2BMi8C8rkpRghLN6eaWzp76KKQBS9JGRVVdA1BC3
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=2qWN2BMi8C8rkpRghLN6eaWzp76KKQBS9JGRVVdA1BC3 HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 2qWN2BMi8C8rkpRghLN6eaWzp76KKQBS9JGRVVdA1BC3
# Fetching token details:  51%|█████     | 47/93 [00:20<00:19,  2.38token/s]INFO:__main__:fetch_token_details: Fetching details for token: D9FQBapGFBr3WHfNNXLWHY5sZQTRdiWKZEog1YiadvBQ
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=D9FQBapGFBr3WHfNNXLWHY5sZQTRdiWKZEog1YiadvBQ HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: D9FQBapGFBr3WHfNNXLWHY5sZQTRdiWKZEog1YiadvBQ
# Fetching token details:  52%|█████▏    | 48/93 [00:20<00:18,  2.41token/s]INFO:__main__:fetch_token_details: Fetching details for token: 3NZ9JMVBmGAqocybic2c7LQCJScmgsAZ6vQqTDzcqmJh
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=3NZ9JMVBmGAqocybic2c7LQCJScmgsAZ6vQqTDzcqmJh HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 3NZ9JMVBmGAqocybic2c7LQCJScmgsAZ6vQqTDzcqmJh
# Fetching token details:  53%|█████▎    | 49/93 [00:21<00:18,  2.36token/s]INFO:__main__:fetch_token_details: Fetching details for token: 7vfCXTUXx5WJV5JADk17DUJ4ksgau7utNKj4b963voxs
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=7vfCXTUXx5WJV5JADk17DUJ4ksgau7utNKj4b963voxs HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 7vfCXTUXx5WJV5JADk17DUJ4ksgau7utNKj4b963voxs
# Fetching token details:  54%|█████▍    | 50/93 [00:21<00:18,  2.37token/s]INFO:__main__:fetch_token_details: Fetching details for token: CRAMvzDsSpXYsFpcoDr6vFLJMBeftez1E7277xwPpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=CRAMvzDsSpXYsFpcoDr6vFLJMBeftez1E7277xwPpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: CRAMvzDsSpXYsFpcoDr6vFLJMBeftez1E7277xwPpump
# Fetching token details:  55%|█████▍    | 51/93 [00:22<00:17,  2.35token/s]INFO:__main__:fetch_token_details: Fetching details for token: 3up9oA3hqCYRoxXhnAeUBfLv3oNrTCyAqL44t82qpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=3up9oA3hqCYRoxXhnAeUBfLv3oNrTCyAqL44t82qpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 3up9oA3hqCYRoxXhnAeUBfLv3oNrTCyAqL44t82qpump
# Fetching token details:  56%|█████▌    | 52/93 [00:22<00:17,  2.39token/s]INFO:__main__:fetch_token_details: Fetching details for token: EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm
# Fetching token details:  57%|█████▋    | 53/93 [00:22<00:17,  2.34token/s]INFO:__main__:fetch_token_details: Fetching details for token: EoRe4xECTe9imaYtwfdmrGoinD2S1N5yMeu1LrjQpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=EoRe4xECTe9imaYtwfdmrGoinD2S1N5yMeu1LrjQpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: EoRe4xECTe9imaYtwfdmrGoinD2S1N5yMeu1LrjQpump
# Fetching token details:  58%|█████▊    | 54/93 [00:23<00:16,  2.39token/s]INFO:__main__:fetch_token_details: Fetching details for token: Gn4Jb8kg8UpnyEjgbUDktSiW8QGu8yn62JbWs911pump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=Gn4Jb8kg8UpnyEjgbUDktSiW8QGu8yn62JbWs911pump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: Gn4Jb8kg8UpnyEjgbUDktSiW8QGu8yn62JbWs911pump
# Fetching token details:  59%|█████▉    | 55/93 [00:23<00:15,  2.42token/s]INFO:__main__:fetch_token_details: Fetching details for token: DEf93bSt8dx58gDFCcz4CwbjYZzjwaRBYAciJYLfdCA9
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=DEf93bSt8dx58gDFCcz4CwbjYZzjwaRBYAciJYLfdCA9 HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: DEf93bSt8dx58gDFCcz4CwbjYZzjwaRBYAciJYLfdCA9
# Fetching token details:  60%|██████    | 56/93 [00:24<00:15,  2.38token/s]INFO:__main__:fetch_token_details: Fetching details for token: DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263 HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263
# Fetching token details:  61%|██████▏   | 57/93 [00:24<00:15,  2.31token/s]INFO:__main__:fetch_token_details: Fetching details for token: 27G8MtK7VtTcCHkpASjSDdkWWYfoqT6ggEuKidVJidD4
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=27G8MtK7VtTcCHkpASjSDdkWWYfoqT6ggEuKidVJidD4 HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 27G8MtK7VtTcCHkpASjSDdkWWYfoqT6ggEuKidVJidD4
# Fetching token details:  62%|██████▏   | 58/93 [00:25<00:14,  2.36token/s]INFO:__main__:fetch_token_details: Fetching details for token: 3WPep4ufaToK1aS5s8BL9inzeUrt4DYaQCiic6ZkkC1U
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=3WPep4ufaToK1aS5s8BL9inzeUrt4DYaQCiic6ZkkC1U HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 3WPep4ufaToK1aS5s8BL9inzeUrt4DYaQCiic6ZkkC1U
# Fetching token details:  63%|██████▎   | 59/93 [00:25<00:14,  2.34token/s]INFO:__main__:fetch_token_details: Fetching details for token: 61V8vBaqAGMpgDQi4JcAwo1dmBGHsyhzodcPqnEVpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=61V8vBaqAGMpgDQi4JcAwo1dmBGHsyhzodcPqnEVpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 61V8vBaqAGMpgDQi4JcAwo1dmBGHsyhzodcPqnEVpump
# Fetching token details:  65%|██████▍   | 60/93 [00:25<00:14,  2.32token/s]INFO:__main__:fetch_token_details: Fetching details for token: J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn
# Fetching token details:  66%|██████▌   | 61/93 [00:26<00:13,  2.35token/s]INFO:__main__:fetch_token_details: Fetching details for token: jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v
# Fetching token details:  67%|██████▋   | 62/93 [00:26<00:13,  2.36token/s]INFO:__main__:fetch_token_details: Fetching details for token: GekTNfm84QfyP2GdAHZ5AgACBRd69aNmgA5FDhZupump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=GekTNfm84QfyP2GdAHZ5AgACBRd69aNmgA5FDhZupump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: GekTNfm84QfyP2GdAHZ5AgACBRd69aNmgA5FDhZupump
# Fetching token details:  68%|██████▊   | 63/93 [00:27<00:12,  2.34token/s]INFO:__main__:fetch_token_details: Fetching details for token: ATRLuHph8dxnPny4WSNW7fxkhbeivBrtWbY6BfB4xpLj
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=ATRLuHph8dxnPny4WSNW7fxkhbeivBrtWbY6BfB4xpLj HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: ATRLuHph8dxnPny4WSNW7fxkhbeivBrtWbY6BfB4xpLj
# Fetching token details:  69%|██████▉   | 64/93 [00:27<00:12,  2.33token/s]INFO:__main__:fetch_token_details: Fetching details for token: FcsgEKX5cu2xeYQeQ5GiWKvPCEYmdBtPRTvYNFrLxoxo
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=FcsgEKX5cu2xeYQeQ5GiWKvPCEYmdBtPRTvYNFrLxoxo HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: FcsgEKX5cu2xeYQeQ5GiWKvPCEYmdBtPRTvYNFrLxoxo
# Fetching token details:  70%|██████▉   | 65/93 [00:28<00:12,  2.32token/s]INFO:__main__:fetch_token_details: Fetching details for token: 6NcdiK8B5KK2DzKvzvCfqi8EHaEqu48fyEzC8Mm9pump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=6NcdiK8B5KK2DzKvzvCfqi8EHaEqu48fyEzC8Mm9pump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 6NcdiK8B5KK2DzKvzvCfqi8EHaEqu48fyEzC8Mm9pump
# Fetching token details:  71%|███████   | 66/93 [00:28<00:11,  2.31token/s]INFO:__main__:fetch_token_details: Fetching details for token: 6umx1LkUbwbWp9y5kPFXdQ8b1KqoXQ7jLi6KmhowqpvH
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=6umx1LkUbwbWp9y5kPFXdQ8b1KqoXQ7jLi6KmhowqpvH HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 6umx1LkUbwbWp9y5kPFXdQ8b1KqoXQ7jLi6KmhowqpvH
# Fetching token details:  72%|███████▏  | 67/93 [00:28<00:11,  2.26token/s]INFO:__main__:fetch_token_details: Fetching details for token: G8yexXGRyBqxw3SfyAdDMTcBVvhYG69RdEBqULCpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=G8yexXGRyBqxw3SfyAdDMTcBVvhYG69RdEBqULCpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: G8yexXGRyBqxw3SfyAdDMTcBVvhYG69RdEBqULCpump
# Fetching token details:  73%|███████▎  | 68/93 [00:29<00:10,  2.30token/s]INFO:__main__:fetch_token_details: Fetching details for token: 7XJiwLDrjzxDYdZipnJXzpr1iDTmK55XixSFAa7JgNEL
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=7XJiwLDrjzxDYdZipnJXzpr1iDTmK55XixSFAa7JgNEL HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 7XJiwLDrjzxDYdZipnJXzpr1iDTmK55XixSFAa7JgNEL
# Fetching token details:  74%|███████▍  | 69/93 [00:29<00:10,  2.30token/s]INFO:__main__:fetch_token_details: Fetching details for token: EfgEGG9PxLhyk1wqtqgGnwgfVC7JYic3vC9BCWLvpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=EfgEGG9PxLhyk1wqtqgGnwgfVC7JYic3vC9BCWLvpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: EfgEGG9PxLhyk1wqtqgGnwgfVC7JYic3vC9BCWLvpump
# Fetching token details:  75%|███████▌  | 70/93 [00:30<00:09,  2.35token/s]INFO:__main__:fetch_token_details: Fetching details for token: FeR8VBqNRSUD5NtXAj2n3j1dAHkZHfyDktKuLXD4pump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=FeR8VBqNRSUD5NtXAj2n3j1dAHkZHfyDktKuLXD4pump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: FeR8VBqNRSUD5NtXAj2n3j1dAHkZHfyDktKuLXD4pump
# Fetching token details:  76%|███████▋  | 71/93 [00:30<00:09,  2.33token/s]INFO:__main__:fetch_token_details: Fetching details for token: 644MryX1MXBNjA8QEUNeQ5HSEVZZqGRzPdiLz4EBpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=644MryX1MXBNjA8QEUNeQ5HSEVZZqGRzPdiLz4EBpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 644MryX1MXBNjA8QEUNeQ5HSEVZZqGRzPdiLz4EBpump
# Fetching token details:  77%|███████▋  | 72/93 [00:31<00:08,  2.34token/s]INFO:__main__:fetch_token_details: Fetching details for token: 63LfDmNb3MQ8mw9MtZ2To9bEA2M71kZUUGq5tiJxcqj9
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=63LfDmNb3MQ8mw9MtZ2To9bEA2M71kZUUGq5tiJxcqj9 HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 63LfDmNb3MQ8mw9MtZ2To9bEA2M71kZUUGq5tiJxcqj9
# Fetching token details:  78%|███████▊  | 73/93 [00:31<00:08,  2.38token/s]INFO:__main__:fetch_token_details: Fetching details for token: 9qriMjPPAJTMCtfQnz7Mo9BsV2jAWTr2ff7yc3JWpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=9qriMjPPAJTMCtfQnz7Mo9BsV2jAWTr2ff7yc3JWpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 9qriMjPPAJTMCtfQnz7Mo9BsV2jAWTr2ff7yc3JWpump
# Fetching token details:  80%|███████▉  | 74/93 [00:31<00:08,  2.36token/s]INFO:__main__:fetch_token_details: Fetching details for token: 8iokxpQzJ5RqqCCV7xrRtHTywQwd6AkSV1pdPutUMCpZ
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=8iokxpQzJ5RqqCCV7xrRtHTywQwd6AkSV1pdPutUMCpZ HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 8iokxpQzJ5RqqCCV7xrRtHTywQwd6AkSV1pdPutUMCpZ
# Fetching token details:  81%|████████  | 75/93 [00:32<00:07,  2.39token/s]INFO:__main__:fetch_token_details: Fetching details for token: DLWAppSDc4BEMXeYDhBxEeuctJbQiGYiQ7DtkJWUWgaq
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=DLWAppSDc4BEMXeYDhBxEeuctJbQiGYiQ7DtkJWUWgaq HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: DLWAppSDc4BEMXeYDhBxEeuctJbQiGYiQ7DtkJWUWgaq
# Fetching token details:  82%|████████▏ | 76/93 [00:32<00:07,  2.36token/s]INFO:__main__:fetch_token_details: Fetching details for token: ERFHviNRhG2zB84wn4kfQ4et1sZRr3bP953KbPB3k8gM
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=ERFHviNRhG2zB84wn4kfQ4et1sZRr3bP953KbPB3k8gM HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: ERFHviNRhG2zB84wn4kfQ4et1sZRr3bP953KbPB3k8gM
# Fetching token details:  83%|████████▎ | 77/93 [00:33<00:06,  2.34token/s]INFO:__main__:fetch_token_details: Fetching details for token: mo7mapMrCsyci5w1td1wgrKPtNeCfjfkKi96DknWi5N
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=mo7mapMrCsyci5w1td1wgrKPtNeCfjfkKi96DknWi5N HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: mo7mapMrCsyci5w1td1wgrKPtNeCfjfkKi96DknWi5N
# Fetching token details:  84%|████████▍ | 78/93 [00:33<00:06,  2.32token/s]INFO:__main__:fetch_token_details: Fetching details for token: 8eCTjtFKWXJkyxDhpQsjvMZG24TqE1h2iSb7xg69MNww
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=8eCTjtFKWXJkyxDhpQsjvMZG24TqE1h2iSb7xg69MNww HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 8eCTjtFKWXJkyxDhpQsjvMZG24TqE1h2iSb7xg69MNww
# Fetching token details:  85%|████████▍ | 79/93 [00:34<00:06,  2.31token/s]INFO:__main__:fetch_token_details: Fetching details for token: Hax9LTgsQkze1YFychnBLtFH8gYbQKtKfWKKg2SP6gdD
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=Hax9LTgsQkze1YFychnBLtFH8gYbQKtKfWKKg2SP6gdD HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: Hax9LTgsQkze1YFychnBLtFH8gYbQKtKfWKKg2SP6gdD
# Fetching token details:  86%|████████▌ | 80/93 [00:34<00:05,  2.34token/s]INFO:__main__:fetch_token_details: Fetching details for token: 5JrGM1hxUJZwkBQbDURPFeNgiSXe34eg3TSbNEKCpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=5JrGM1hxUJZwkBQbDURPFeNgiSXe34eg3TSbNEKCpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 5JrGM1hxUJZwkBQbDURPFeNgiSXe34eg3TSbNEKCpump
# Fetching token details:  87%|████████▋ | 81/93 [00:34<00:05,  2.35token/s]INFO:__main__:fetch_token_details: Fetching details for token: vPtS4ywrbEuufwPkBXsCYkeTBfpzCd6hF52p8kJGt9b
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=vPtS4ywrbEuufwPkBXsCYkeTBfpzCd6hF52p8kJGt9b HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: vPtS4ywrbEuufwPkBXsCYkeTBfpzCd6hF52p8kJGt9b
# Fetching token details:  88%|████████▊ | 82/93 [00:35<00:04,  2.39token/s]INFO:__main__:fetch_token_details: Fetching details for token: 4k3Dyjzvzp8eMZWUXbBCjEvwSkkk59S5iCNLY3QrkX6R
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=4k3Dyjzvzp8eMZWUXbBCjEvwSkkk59S5iCNLY3QrkX6R HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 4k3Dyjzvzp8eMZWUXbBCjEvwSkkk59S5iCNLY3QrkX6R
# Fetching token details:  89%|████████▉ | 83/93 [00:35<00:04,  2.41token/s]INFO:__main__:fetch_token_details: Fetching details for token: USDSwr9ApdHk5bvJKMjzff41FfuX8bSxdKcR81vTwcA
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=USDSwr9ApdHk5bvJKMjzff41FfuX8bSxdKcR81vTwcA HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: USDSwr9ApdHk5bvJKMjzff41FfuX8bSxdKcR81vTwcA
# Fetching token details:  90%|█████████ | 84/93 [00:36<00:03,  2.41token/s]INFO:__main__:fetch_token_details: Fetching details for token: FfKsSuFnwH6oAoDChmoK5m6WEQjVBe2b8dNJfGaS7FA1
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=FfKsSuFnwH6oAoDChmoK5m6WEQjVBe2b8dNJfGaS7FA1 HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: FfKsSuFnwH6oAoDChmoK5m6WEQjVBe2b8dNJfGaS7FA1
# Fetching token details:  91%|█████████▏| 85/93 [00:36<00:03,  2.40token/s]INFO:__main__:fetch_token_details: Fetching details for token: 4BBjpGwLgGmUxtT82YFK9xMhcvyy3zgf3HpxTRip1YoU
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=4BBjpGwLgGmUxtT82YFK9xMhcvyy3zgf3HpxTRip1YoU HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 4BBjpGwLgGmUxtT82YFK9xMhcvyy3zgf3HpxTRip1YoU
# Fetching token details:  92%|█████████▏| 86/93 [00:36<00:02,  2.42token/s]INFO:__main__:fetch_token_details: Fetching details for token: Cy1GS2FqefgaMbi45UunrUzin1rfEmTUYnomddzBpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=Cy1GS2FqefgaMbi45UunrUzin1rfEmTUYnomddzBpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: Cy1GS2FqefgaMbi45UunrUzin1rfEmTUYnomddzBpump
# Fetching token details:  94%|█████████▎| 87/93 [00:37<00:02,  2.35token/s]INFO:__main__:fetch_token_details: Fetching details for token: GmWheL8niCtNwZaEoix7UZUroEdH37f5ySdP2o1fLRRg
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=GmWheL8niCtNwZaEoix7UZUroEdH37f5ySdP2o1fLRRg HTTP/1.1" 200 None
# ...
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '5JrGM1hxUJZwkBQbDURPFeNgiSXe34eg3TSbNEKCpump'.
# Fetching token historical prices:  87%|████████▋ | 82/94 [00:38<00:05,  2.22token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'vPtS4ywrbEuufwPkBXsCYkeTBfpzCd6hF52p8kJGt9b' from 1738928961 to 1739117661.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=vPtS4ywrbEuufwPkBXsCYkeTBfpzCd6hF52p8kJGt9b&address_type=token&type=5m&time_from=1738928961&time_to=1739117661 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'vPtS4ywrbEuufwPkBXsCYkeTBfpzCd6hF52p8kJGt9b'.
# Fetching token historical prices:  88%|████████▊ | 83/94 [00:39<00:05,  2.19token/s]INFO:__main__:fetch_historical_price: Requesting history for token '4k3Dyjzvzp8eMZWUXbBCjEvwSkkk59S5iCNLY3QrkX6R' from 1738928961 to 1739117661.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=4k3Dyjzvzp8eMZWUXbBCjEvwSkkk59S5iCNLY3QrkX6R&address_type=token&type=5m&time_from=1738928961&time_to=1739117661 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '4k3Dyjzvzp8eMZWUXbBCjEvwSkkk59S5iCNLY3QrkX6R'.
# Fetching token historical prices:  89%|████████▉ | 84/94 [00:39<00:04,  2.18token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'USDSwr9ApdHk5bvJKMjzff41FfuX8bSxdKcR81vTwcA' from 1738928962 to 1739117662.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=USDSwr9ApdHk5bvJKMjzff41FfuX8bSxdKcR81vTwcA&address_type=token&type=5m&time_from=1738928962&time_to=1739117662 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'USDSwr9ApdHk5bvJKMjzff41FfuX8bSxdKcR81vTwcA'.
# Fetching token historical prices:  90%|█████████ | 85/94 [00:40<00:04,  2.14token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'FfKsSuFnwH6oAoDChmoK5m6WEQjVBe2b8dNJfGaS7FA1' from 1738928962 to 1739117662.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=FfKsSuFnwH6oAoDChmoK5m6WEQjVBe2b8dNJfGaS7FA1&address_type=token&type=5m&time_from=1738928962&time_to=1739117662 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 126 price snapshots for token 'FfKsSuFnwH6oAoDChmoK5m6WEQjVBe2b8dNJfGaS7FA1'.
# Fetching token historical prices:  91%|█████████▏| 86/94 [00:40<00:03,  2.25token/s]INFO:__main__:fetch_historical_price: Requesting history for token '4BBjpGwLgGmUxtT82YFK9xMhcvyy3zgf3HpxTRip1YoU' from 1738928962 to 1739117662.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=4BBjpGwLgGmUxtT82YFK9xMhcvyy3zgf3HpxTRip1YoU&address_type=token&type=5m&time_from=1738928962&time_to=1739117662 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '4BBjpGwLgGmUxtT82YFK9xMhcvyy3zgf3HpxTRip1YoU'.
# Fetching token historical prices:  93%|█████████▎| 87/94 [00:41<00:03,  2.20token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'Cy1GS2FqefgaMbi45UunrUzin1rfEmTUYnomddzBpump' from 1738928963 to 1739117663.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=Cy1GS2FqefgaMbi45UunrUzin1rfEmTUYnomddzBpump&address_type=token&type=5m&time_from=1738928963&time_to=1739117663 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'Cy1GS2FqefgaMbi45UunrUzin1rfEmTUYnomddzBpump'.
# Fetching token historical prices:  94%|█████████▎| 88/94 [00:41<00:02,  2.23token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'GmWheL8niCtNwZaEoix7UZUroEdH37f5ySdP2o1fLRRg' from 1738928963 to 1739117663.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=GmWheL8niCtNwZaEoix7UZUroEdH37f5ySdP2o1fLRRg&address_type=token&type=5m&time_from=1738928963&time_to=1739117663 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 126 price snapshots for token 'GmWheL8niCtNwZaEoix7UZUroEdH37f5ySdP2o1fLRRg'.
# Fetching token historical prices:  95%|█████████▍| 89/94 [00:41<00:02,  2.29token/s]INFO:__main__:fetch_historical_price: Requesting history for token '8oEHKQYYYavrfVXnF8qAHmJF18DWJwnvhwz6Wqktpump' from 1738928964 to 1739117664.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=8oEHKQYYYavrfVXnF8qAHmJF18DWJwnvhwz6Wqktpump&address_type=token&type=5m&time_from=1738928964&time_to=1739117664 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 178 price snapshots for token '8oEHKQYYYavrfVXnF8qAHmJF18DWJwnvhwz6Wqktpump'.
# Fetching token historical prices:  96%|█████████▌| 90/94 [00:42<00:01,  2.20token/s]INFO:__main__:fetch_historical_price: Requesting history for token '6mZ76DjmTYhtEGLcVSEyeS5VcByHauxpw6oYQL4spump' from 1738928964 to 1739117664.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=6mZ76DjmTYhtEGLcVSEyeS5VcByHauxpw6oYQL4spump&address_type=token&type=5m&time_from=1738928964&time_to=1739117664 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '6mZ76DjmTYhtEGLcVSEyeS5VcByHauxpw6oYQL4spump'.
# Fetching token historical prices:  97%|█████████▋| 91/94 [00:42<00:01,  2.23token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'ET3BPsRH5PfS2GJj6gPqfDHhqmXY2TZzK4baHqxEpump' from 1738928965 to 1739117665.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=ET3BPsRH5PfS2GJj6gPqfDHhqmXY2TZzK4baHqxEpump&address_type=token&type=5m&time_from=1738928965&time_to=1739117665 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 96 price snapshots for token 'ET3BPsRH5PfS2GJj6gPqfDHhqmXY2TZzK4baHqxEpump'.
# Fetching token historical prices:  98%|█████████▊| 92/94 [00:43<00:00,  2.25token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'HhCLbkW6FwhriTkk81W8tYstsRCLUu6Y7Je1SQjVpump' from 1738928965 to 1739117665.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=HhCLbkW6FwhriTkk81W8tYstsRCLUu6Y7Je1SQjVpump&address_type=token&type=5m&time_from=1738928965&time_to=1739117665 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'HhCLbkW6FwhriTkk81W8tYstsRCLUu6Y7Je1SQjVpump'.
# Fetching token historical prices:  99%|█████████▉| 93/94 [00:43<00:00,  2.24token/s]INFO:__main__:fetch_historical_price: Requesting history for token '6VVq3KCxHdgeCvWzeaCQotpvPLkBr9jbvFCFvtbnBX3g' from 1738928966 to 1739117666.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=6VVq3KCxHdgeCvWzeaCQotpvPLkBr9jbvFCFvtbnBX3g&address_type=token&type=5m&time_from=1738928966&time_to=1739117666 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '6VVq3KCxHdgeCvWzeaCQotpvPLkBr9jbvFCFvtbnBX3g'.
# Fetching token historical prices: 100%|██████████| 94/94 [00:44<00:00,  2.13token/s]
# INFO:__main__:main: Processing transactions to calculate historical prices...
# Processing transactions: 100%|██████████| 433/433 [00:00<00:00, 6398.91it/s]
# INFO:__main__:main: Calculating per-transaction dollar values...
# INFO:__main__:main: Aggregating dollar values per token...
# INFO:__main__:main: Aggregated token values:
# INFO:__main__:                                           token  dollars_sold  dollars_bought
# 0   27G8MtK7VtTcCHkpASjSDdkWWYfoqT6ggEuKidVJidD4  19854.661233     4903.865777
# 1   2mhszy8YHwqs1fxruVHQQAUmNcfq31mtkmYYtNZNpump      0.000000    19067.001654
# 2   2nCeHpECQvnMfzjU5fDMAKws1vBxMzxvWr6qqLpApump   1039.189924        0.000000
# 3   2qWN2BMi8C8rkpRghLN6eaWzp76KKQBS9JGRVVdA1BC3      7.296191        0.000000
# 4   2yd2Suus3YY4Sa7LHhn1PSHkjXj3XKrars4cCog2tGU8   9566.326851     3042.160805
# ..                                           ...           ...             ...
# 88   USDSwr9ApdHk5bvJKMjzff41FfuX8bSxdKcR81vTwcA  14999.179486        0.000000
# 89   eL5fUxj2J4CiQsmW85k5FG9DvuQjjUoBHoQBi2Kpump   4164.431121     4974.885274
# 90   jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v    103.002548      207.102057
# 91   mo7mapMrCsyci5w1td1wgrKPtNeCfjfkKi96DknWi5N      0.000000        0.000000
# 92   vPtS4ywrbEuufwPkBXsCYkeTBfpzCd6hF52p8kJGt9b      0.000000     2028.813808
#
# [93 rows x 3 columns]
# INFO:__main__:main: Merging aggregated data with token details...
# INFO:__main__:main: Formatting dollar values with comma as decimal separator...
# INFO:__main__:main: Writing final aggregated token details to Excel file at '../data/final_aggregated_token_details_20250209_171426.xlsx'...
# INFO:__main__:main: Final Excel file written successfully.
# INFO:__main__:main: Database connection closed.
#                                            token dollars_sold dollars_bought  \
# 0   27G8MtK7VtTcCHkpASjSDdkWWYfoqT6ggEuKidVJidD4     19854,66        4903,87
# 1   2mhszy8YHwqs1fxruVHQQAUmNcfq31mtkmYYtNZNpump         0,00       19067,00
# 2   2nCeHpECQvnMfzjU5fDMAKws1vBxMzxvWr6qqLpApump      1039,19           0,00
# 3   2qWN2BMi8C8rkpRghLN6eaWzp76KKQBS9JGRVVdA1BC3         7,30           0,00
# 4   2yd2Suus3YY4Sa7LHhn1PSHkjXj3XKrars4cCog2tGU8      9566,33        3042,16
# ..                                           ...          ...            ...
# 88   USDSwr9ApdHk5bvJKMjzff41FfuX8bSxdKcR81vTwcA     14999,18           0,00
# 89   eL5fUxj2J4CiQsmW85k5FG9DvuQjjUoBHoQBi2Kpump      4164,43        4974,89
# 90   jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v       103,00         207,10
# 91   mo7mapMrCsyci5w1td1wgrKPtNeCfjfkKi96DknWi5N         0,00           0,00
# 92   vPtS4ywrbEuufwPkBXsCYkeTBfpzCd6hF52p8kJGt9b         0,00        2028,81
#
#                                          address  decimals   symbol  \
# 0   27G8MtK7VtTcCHkpASjSDdkWWYfoqT6ggEuKidVJidD4         6      JLP
# 1   2mhszy8YHwqs1fxruVHQQAUmNcfq31mtkmYYtNZNpump         6   CAINAM
# 2   2nCeHpECQvnMfzjU5fDMAKws1vBxMzxvWr6qqLpApump         6    SUEDE
# 3   2qWN2BMi8C8rkpRghLN6eaWzp76KKQBS9JGRVVdA1BC3         6     USDC
# 4   2yd2Suus3YY4Sa7LHhn1PSHkjXj3XKrars4cCog2tGU8         6     $INA
# ..                                           ...       ...      ...
# 88   USDSwr9ApdHk5bvJKMjzff41FfuX8bSxdKcR81vTwcA         6     USDS
# 89   eL5fUxj2J4CiQsmW85k5FG9DvuQjjUoBHoQBi2Kpump         6      UFD
# 90   jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v         9   JupSOL
# 91   mo7mapMrCsyci5w1td1wgrKPtNeCfjfkKi96DknWi5N         9   CATBAT
# 92   vPtS4ywrbEuufwPkBXsCYkeTBfpzCd6hF52p8kJGt9b         6  Unknown
#
#                   name                                         extensions  \
# 0     Jupiter Perps LP  {'coingeckoId': 'jupiter-perpetuals-liquidity-...
# 1      Cainam Ventures  {'twitter': 'https://x.com/cainamventures', 'd...
# 2         Johnny Suede  {'description': 'That guy! No chill for this g...
# 3                 USDC                             {'description': 'pff'}
# 4           pepeinatux  {'coingeckoId': 'pepeinatux', 'description': '...
# ..                 ...                                                ...
# 88                USDS  {'coingeckoId': 'usds', 'twitter': 'https://tw...
# 89   Unicorn Fart Dust  {'description': 'It's a Meme Coin
# It's worthl...
# 90  Jupiter Staked SOL  {'coingeckoId': 'jupiter-staked-sol', 'twitter...
# 91              CATBAT  {'description': 'CATBAT is on a mission to fig...
# 92             Unknown                                               None
#
#                                               logoURI     liquidity  ...  \
# 0                  https://static.jup.ag/jlp/icon.png  4.639811e+07  ...
# 1   https://ipfs.io/ipfs/QmVaxyFEb8NPAj7FPsuQ2Tdax...  3.665796e+05  ...
# 2   https://ipfs.io/ipfs/QmRoXFc2ujeTrezySzZTkYjHv...  5.741592e+05  ...
# 3   https://i.degencdn.com/ipfs/bafkreigm5o72t6kdb...  0.000000e+00  ...
# 4   https://pump.mypinata.cloud/ipfs/QmcQ2MzNzhkqK...  5.104026e+05  ...
# ..                                                ...           ...  ...
# 88  https://ipfs.io/ipfs/QmTW9HWfb2wsQqEVJiixkQ73N...  7.092772e+07  ...
# 89  https://ipfs.io/ipfs/QmSPYBXsBnoDuUctoaW8DFLmU...  3.697853e+06  ...
# 90              https://static.jup.ag/jupSOL/icon.png  8.126116e+06  ...
# 91  https://cdn.dexscreener.com/cms/images/XmlS5vS...  2.049079e+05  ...
# 92                                               None  5.914530e+04  ...
#
#       vBuy24hUSD vBuyHistory24h  vBuyHistory24hUSD  vBuy24hChangePercent  \
# 0   5.165532e+07   1.498458e+07       6.567057e+07            -22.430589
# 1   4.144935e+05   1.015585e+08       4.115429e+05             11.772914
# 2   1.445847e+04   2.127379e+06       2.951396e+04            -52.505459
# 3   9.308835e+06   9.423739e+06       9.424324e+06             -1.225434
# 4   8.121614e+04   4.928704e+06       5.767690e+04             37.355953
# ..           ...            ...                ...                   ...
# 88  6.377947e+06   7.003768e+06       7.004671e+06             -9.022636
# 89  5.972390e+06   8.684282e+07       4.863433e+06             41.206910
# 90  8.238565e+06   6.382473e+04       1.334098e+07            -40.615593
# 91  4.628092e+04   5.261024e+06       1.550031e+04            275.939988
# 92  1.001700e+03   1.043368e+06       1.394107e+03            -28.320001
#
#         vSell24h   vSell24hUSD  vSellHistory24h  vSellHistory24hUSD  \
# 0   1.191526e+07  5.295492e+07     1.541831e+07        6.756594e+07
# 1   1.010007e+08  3.644168e+05     1.179478e+08        4.811845e+05
# 2   2.149330e+06  3.045143e+04     2.701628e+06        3.744478e+04
# 3   9.283576e+06  9.284153e+06     9.400942e+06        9.401526e+06
# 4   6.833932e+06  8.155043e+04     4.487586e+06        5.233487e+04
# ..           ...           ...              ...                 ...
# 88  6.784841e+06  6.784953e+06     6.592434e+06        6.592571e+06
# 89  1.343125e+08  6.476357e+06     9.476876e+07        5.350244e+06
# 90  2.734610e+04  5.965006e+06     3.584699e+04        7.437308e+06
# 91  2.795144e+07  6.596020e+04     7.439929e+06        2.167074e+04
# 92  2.712075e+05  3.276104e+02     1.084880e+06        1.308080e+03
#
#     vSell24hChangePercent  numberMarkets
# 0              -22.720038            135
# 1              -14.368298              4
# 2              -20.443181              2
# 3               -1.248444              1
# 4               52.285258              2
# ..                    ...            ...
# 88               2.918601             15
# 89              41.726565             56
# 90             -23.714386             47
# 91             275.695035              4
# 92             -75.001141              3
#
# [93 rows x 197 columns]
