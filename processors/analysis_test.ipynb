# %%
import logging
import requests
import pandas as pd
import time
from time import sleep
from tqdm import tqdm  # progress bar package
from processors.update_tokens import main as update_tokens_main
import sys
from db.connection import DatabaseConnection
from db.queries import DatabaseQueries
from config import load_config
import random
import os
from datetime import datetime

# Configure logging globally
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")
logger = logging.getLogger(__name__)

# -------------------------------------------------------------------
def fetch_historical_price(token_mint, api_key):
    """
    Fetch the historical price data for a given token using the Birdeye API endpoint
    /defi/history_price. The API call requests the price history from:
        time_from = now - 188700 (seconds)
        time_to   = now

    Returns a DataFrame with historical snapshots sorted by unixTime or None if not found.
    """
    now = int(time.time())
    time_from = now - 188700  # 188700 seconds before now
    url = f"https://public-api.birdeye.so/defi/history_price?address={token_mint}&address_type=token&type=5m&time_from={time_from}&time_to={now}"
    logger.info(f"fetch_historical_price: Requesting history for token '{token_mint}' from {time_from} to {now}.")
    headers = {
        "accept": "application/json",
        "x-chain": "solana",
        "X-API-KEY": api_key
    }
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        data = response.json()
        if data.get("success") is True:
            items = data.get("data", {}).get("items", [])
            if items:
                df = pd.DataFrame(items)
                df = df.sort_values("unixTime")
                logger.info(f"fetch_historical_price: Retrieved {len(df)} price snapshots for token '{token_mint}'.")
                return df
            else:
                logger.error(f"fetch_historical_price: No items found in API response for token '{token_mint}'. Response: {data}")
                return None
        else:
            logger.error(f"fetch_historical_price: API returned error for token '{token_mint}'. Response: {data}")
            return None
    except requests.RequestException as e:
        logger.error(f"fetch_historical_price: Request error for token '{token_mint}': {e}")
        return None

# -------------------------------------------------------------------
def fetch_token_details(chain_id, token_addresses, api_key):
    """
    Fetch token details from the Birdeye token overview endpoint.
    For each token address, it sends a GET request to:
      https://public-api.birdeye.so/defi/token_overview?address={token}
    The chain is specified in the request headers.

    Returns a DataFrame containing the details for all tokens.
    """
    logger.info(f"fetch_token_details: Starting to fetch details for {len(token_addresses)} tokens on chain '{chain_id}' using Birdeye API.")
    token_details_list = []
    # Filter out any None values
    token_addresses = [address for address in token_addresses if address is not None]
    for token in tqdm(token_addresses, desc='Fetching token details', unit='token'):
        url = f"https://public-api.birdeye.so/defi/token_overview?address={token}"
        headers = {
            "accept": "application/json",
            "x-chain": chain_id,
            "X-API-KEY": api_key
        }
        logger.info(f"fetch_token_details: Fetching details for token: {token}")
        try:
            response = requests.get(url, headers=headers)
            response.raise_for_status()
            data = response.json()
            if data.get("success") is True:
                token_data = data.get("data", {})
                # Ensure the 'address' field exists for merging later.
                if "address" not in token_data:
                    token_data["address"] = token
                token_details_list.append(token_data)
                logger.info(f"fetch_token_details: Retrieved details for token: {token}")
            else:
                logger.error(f"fetch_token_details: API returned error for token {token}. Response: {data}")
            sleep(0.2)  # avoid rate limiting
        except requests.RequestException as e:
            logger.error(f"fetch_token_details: Request error for token {token}: {e}")
            sleep(0.2)
    token_details_df = pd.DataFrame(token_details_list)
    logger.info("fetch_token_details: Finished fetching all token details.")
    return token_details_df

# -------------------------------------------------------------------
def get_closest_price(token, block_time, token_history_data):
    """
    Given a token and a block_time, look up the historical price data for that token
    (as returned by fetch_historical_price) and return the price ('value') from the
    snapshot with the smallest time difference to block_time.
    """
    df = token_history_data.get(token)
    if df is None or df.empty:
        logger.warning(f"get_closest_price: No historical data available for token {token}.")
        return None
    # Calculate the absolute time difference between block_time and all snapshots
    time_diffs = (df["unixTime"] - block_time).abs()
    closest_idx = time_diffs.idxmin()
    closest_price = df.loc[closest_idx, "value"]
    return closest_price

# -------------------------------------------------------------------
def main():
    # Initialize configuration and database connections
    config = load_config()
    db_connection = DatabaseConnection(config.db)
    db_queries = DatabaseQueries(db_connection)

    try:
        logger.info("main: Starting main function execution.")

        # (1) Optionally update token information
        # logger.info("main: Calling update_tokens.main()...")
        # update_tokens_main()

        # (2) Fetch recent transactions (e.g., from the past 6 hours)
        logger.info("main: Fetching recent transactions...")
        transactions_df = db_queries.get_recent_transactions(n=6)
        logger.info(f"main: Fetched {len(transactions_df)} transactions.")

        # (3) Fetch token details once using the Birdeye API
        token_columns = ["open_input_mint", "open_output_mint", "close_input_mint", "close_output_mint"]
        unique_tokens = pd.unique(transactions_df[token_columns].values.ravel())
        logger.info(f"main: Found {len(unique_tokens)} unique token addresses for details.")
        chain_id = "solana"
        token_details_df = fetch_token_details(chain_id, unique_tokens, config.birdeye.api_key)

        # (4) Add new columns for tokens and their historical prices
        transactions_df["input_token"] = None
        transactions_df["output_token"] = None
        transactions_df["input_price"] = None
        transactions_df["output_price"] = None

        # (5) For each distinct token, fetch its historical price snapshots once
        logger.info("main: Fetching historical price data for each unique token...")
        token_history_data = {}
        for token in tqdm(unique_tokens, desc="Fetching token historical prices", unit="token"):
            df_history = fetch_historical_price(token, config.birdeye.api_key)
            if df_history is not None:
                token_history_data[token] = df_history
            else:
                logger.warning(f"main: No historical data found for token {token}.")
            sleep(0.2)  # To avoid rate limiting

        # (6) Process each transaction to look up the closest historical price for both input and output tokens
        logger.info("main: Processing transactions to calculate historical prices...")
        for index, row in tqdm(transactions_df.iterrows(), total=len(transactions_df), desc="Processing transactions"):
            if pd.notnull(row["open_input_mint"]):
                input_token = row["open_input_mint"]
                output_token = row["open_output_mint"]
                block_time = row["open_block_time"]
            else:
                input_token = row["close_input_mint"]
                output_token = row["close_output_mint"]
                block_time = row["close_block_time"]

            transactions_df.at[index, "input_token"] = input_token
            transactions_df.at[index, "output_token"] = output_token

            # Look up the closest price snapshot for each token based on block_time
            input_price = get_closest_price(input_token, block_time, token_history_data)
            output_price = get_closest_price(output_token, block_time, token_history_data)

            transactions_df.at[index, "input_price"] = input_price
            transactions_df.at[index, "output_price"] = output_price

        # (7) Calculate per-transaction dollar amounts
        logger.info("main: Calculating per-transaction dollar values...")
        transactions_df["dollars_sold"] = (
                transactions_df["in_amount"].astype(float) *
                transactions_df["input_price"].astype(float)
        )
        transactions_df["dollars_bought"] = (
                transactions_df["out_amount"].astype(float) *
                transactions_df["output_price"].astype(float)
        )

        # (8) Aggregate dollar amounts per token
        logger.info("main: Aggregating dollar values per token...")
        aggregated_sold = (
            transactions_df.groupby("input_token")["dollars_sold"]
            .sum()
            .reset_index()
            .rename(columns={"input_token": "token"})
        )
        aggregated_bought = (
            transactions_df.groupby("output_token")["dollars_bought"]
            .sum()
            .reset_index()
            .rename(columns={"output_token": "token"})
        )
        aggregated = pd.merge(aggregated_sold, aggregated_bought, on="token", how="outer")
        aggregated["dollars_sold"] = aggregated["dollars_sold"].fillna(0)
        aggregated["dollars_bought"] = aggregated["dollars_bought"].fillna(0)
        logger.info("main: Aggregated token values:")
        logger.info(aggregated)

        # (9) Merge aggregated data with token details
        # We merge on the token address field ("address") from the Birdeye API data.
        logger.info("main: Merging aggregated data with token details...")
        final_df = pd.merge(aggregated, token_details_df, left_on="token", right_on="address", how="left")

        # (10) Format dollars columns to use a comma as the decimal separator
        logger.info("main: Formatting dollar values with comma as decimal separator...")
        final_df["dollars_sold"] = final_df["dollars_sold"].apply(lambda x: f"{x:.2f}".replace('.',','))
        final_df["dollars_bought"] = final_df["dollars_bought"].apply(lambda x: f"{x:.2f}".replace('.',','))

        # (11) Remove timezone information for Excel compatibility
        for col in transactions_df.select_dtypes(include=["datetimetz"]).columns:
            transactions_df[col] = transactions_df[col].dt.tz_localize(None)
        for col in final_df.select_dtypes(include=["datetimetz"]).columns:
            final_df[col] = final_df[col].dt.tz_localize(None)

        # (12) Create a folder to store generated Excel files (if not exists) and write the final merged output to an Excel file.
        output_folder = "../data/"
        if not os.path.exists(output_folder):
            os.makedirs(output_folder)
            logger.info(f"main: Created output folder '{output_folder}'.")

        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        excel_filename = f"final_aggregated_token_details_{timestamp}.xlsx"
        output_path = os.path.join(output_folder, excel_filename)

        logger.info(f"main: Writing final aggregated token details to Excel file at '{output_path}'...")
        final_df.to_excel(output_path, index=False)
        logger.info("main: Final Excel file written successfully.")
        print(final_df)

    except Exception as e:
        logger.error(f"main: An error occurred: {e}", exc_info=True)
    finally:
        db_connection.close()
        logger.info("main: Database connection closed.")

if __name__ == "__main__":
    main()

# %%
import logging
import requests
import time
from tqdm import tqdm  # Progress bar
from db.connection import DatabaseConnection
from db.queries import DatabaseQueries
from config import load_config

# Configure logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")
logger = logging.getLogger(__name__)

# Constants
API_URL = "https://public-api.birdeye.so/defi/token_security"
MAX_RETRIES = 3
RETRY_DELAY = 5  # seconds
RATE_LIMIT_DELAY = 1  # seconds (Birdeye's rate limit)

def fetch_and_store_security_data():
    logger.info("Initializing database connection...")
    config = load_config()
    db_connection = DatabaseConnection(config.db)
    db_queries = DatabaseQueries(db_connection)

    try:
        logger.info("Fetching distinct tokens not already in `token_security`...")
        with db_connection.get_cursor() as cursor:
            cursor.execute("""
                SELECT DISTINCT ti.token
                FROM token_info ti
                LEFT JOIN token_security ts ON ti.token = ts.token
                WHERE ts.token IS NULL;
            """)
            tokens = [row['token'] for row in cursor.fetchall()]

        if not tokens:
            logger.warning("No new tokens found to process.")
            return

        logger.info(f"Found {len(tokens)} new tokens to process.")

        # Process tokens in batches
        batch_size = 100
        for i in range(0, len(tokens), batch_size):
            batch = tokens[i:i + batch_size]
            logger.info(f"Processing batch {i // batch_size + 1}: {len(batch)} tokens")
            logger.debug(f"Token batch: {batch}")  # Debug log: List of tokens being processed

            success = db_queries.fetch_and_store_token_security(batch, config.birdeye.api_key)

            if success:
                logger.info(f"Batch {i // batch_size + 1} successfully inserted into DB.")
            else:
                logger.warning(f"Batch {i // batch_size + 1} had issues, check logs for details.")

            logger.info("Sleeping for 1 second to avoid DB overload...")
            time.sleep(1)

    except Exception as e:
        logger.error(f"Unexpected error: {e}", exc_info=True)

    finally:
        db_connection.close()
        logger.info("Database connection closed.")
def fetch_and_store_security_data():
    logger.info("Initializing database connection...")
    config = load_config()
    db_connection = DatabaseConnection(config.db)
    db_queries = DatabaseQueries(db_connection)

    try:
        logger.info("Fetching distinct tokens not already in `token_security`...")
        with db_connection.get_cursor() as cursor:
            cursor.execute("""
                SELECT DISTINCT ti.token
                FROM token_info ti
                LEFT JOIN token_security ts ON ti.token = ts.token
                WHERE ts.token IS NULL;
            """)
            tokens = [row['token'] for row in cursor.fetchall()]

        if not tokens:
            logger.warning("No new tokens found to process.")
            return

        logger.info(f"Found {len(tokens)} new tokens to process.")

        # Process tokens in batches
        batch_size = 100
        for i in range(0, len(tokens), batch_size):
            batch = tokens[i:i + batch_size]
            logger.info(f"Processing batch {i // batch_size + 1}: {len(batch)} tokens")
            logger.debug(f"Token batch: {batch}")  # Debug log: List of tokens being processed

            success = db_queries.fetch_and_store_token_security(batch, config.birdeye.api_key)

            if success:
                logger.info(f"Batch {i // batch_size + 1} successfully inserted into DB.")
            else:
                logger.warning(f"Batch {i // batch_size + 1} had issues, check logs for details.")

            logger.info("Sleeping for 1 second to avoid DB overload...")
            time.sleep(1)

    except Exception as e:
        logger.error(f"Unexpected error: {e}", exc_info=True)

    finally:
        db_connection.close()
        logger.info("Database connection closed.")




if __name__ == "__main__":
    fetch_and_store_security_data()
# Out:
# INFO:__main__:Initializing database connection...
# INFO:__main__:Fetching distinct tokens not already in `token_security`...
# INFO:__main__:Found 3295 new tokens to process.
# INFO:__main__:Processing batch 1: 100 tokens
# DEBUG:__main__:Token batch: ['A3JhdVyyLCdmzJQFs5hREUQruvVizyiKpwer6mFCqLuM', 'e1U5yfZtSemWQdxtHubW3PRnPi2Vhw7Czy9cqfupump', 'ECsNXvrbGLm1SRL13qvdT2MCjjx4bZqsC1wTNRGZpump', 'EcUbB6wMZ92gesoZG1KvJTBmppJQs1g86ivuU8Vspump', 'EcUgGEve9YX7Na4AtdqLH27V51iRZnoisDShQEGfpump', 'ECutGg12PNhqhkvnH1s1FcuXgCDzKDNhSf5aLtANioR7', 'ECvrjwkiubyuWyKLuPVWn2iJdtQw2ZgP5EACspHS5Msu', 'EcWxnKp1UjsEGcmJ1kbFWPHq3biSToZadKEeTj9Mpump', 'EcxZmftSHGs8NYQijdfi7ZtTeQj7VegSi9dPfrkHpump', 'ECY31gWwxy4s2VnMkYhmqDkrV75KrwR2yTtsnrnSpump', 'EcYK2XNG4wWr2vDg2M2Hrts6SrU2QB4NzXLBf888pump', 'ECZxKmKGEkyKhYUau7WkUE1L9Jp2yLebwX4SnKc1pump', 'ED1dK5W9aAPqnCp63D16aXSu2koyCgFhCJfvr5ahpump', 'Ed1yisBEAo8UXToSswvVFgzyJKpF48HEdq5kvz2zpump', 'ED2Vw9NSVEJJagsAciwRC8RNV2gbsj7NPtk1FVMgpump', 'ED5nyyWEzpPPiWimP8vYm7sD7TD3LAt3Q3gRTWHzPJBY', 'ED5TZKpKNmdcpAWA9jY4znAUSgt5CxLergdomg7Qpump', 'ED5wbeyAYtLM4WRGnohPxJEwniaikEFioVmJyZH6K31m', 'ED7V7JwufQJiPfFi5TMRkenZ9WSgEF5G2zdYkehrpump', 'EdaG8TKn36DnrXkVrJ3oSR9qw5hrUXrXS21n84B7AdLP', 'EDavhezsuNnhdoAKPExWaMtnuhq6FVqoBYnyFEJLLBqC', 'EdevXsYfsBhQY3BSs1RD6R6izKjHBhj7EBN7446apump', 'EDg2KrxTbamMXZbr6ztSf3igrMmC567h34xTrqL6pump', 'EdhTCqUxXRWQcUd5Fonyz9rapHAB6mABAuVkmPrtpump', 'EDN4nnhSYNh65wm47TNHFwRMUZ5M5PnHhcKS44p5pump', 'Edp1oxRgY4auQrmssuvUYvfP128Wwnj4a7qQU5KLpump', 'EDsuVxL6LNuuna6XPzhpVBbezVfsBYBwbeAmenWeuxxS', 'Edwwnyt7GFJCpqjq45mR5wjVUpCkZYkyfe1CMvTfpump', 'EDwziqjWSMT2U7kiScrVaC6ee4hyJBXys9zckpGg9RPB', 'EDx3uMVFdN89EiH6gCH1r7XQN1KW42HxHBjBRroVpump', 'EE3hEc8HTvVAwMeRxmqvmJpWGXx6p5YSx8DMKCTEpump', 'EE3p4nX6dXp4xQWkH37qbg1SuWnKf7pujn7HrDH4pump', 'EE7g5kmPZciS8he3dcaPf35jouHg7VxkFCybRfitCZLj', 'eEbwkEC4Bo7hsfsaechNL3nHGvHzhBUxXGPvyRypump', 'EecF37KL51B8eBoyzgxyS2VA26vbpEazWRX2dx6mpump', 'EEGQzJwzyXgW4LW7V2ZCFwcAMcbQarifCzmyhotgpump', 'EEhwAAb9SbvKSBcyxn2dKvKA8nj6Es6RBAQPsPqKXMbj', 'EemhZCaRwN7LwVHzoh8WxZh2gyRCzaZxhvoVPriwRp82', 'Een8PisdGVGUihqkPsjZAUc32WQFKQpmF3JstJqg9cck', 'EeNBJ7XS6oURREjgrqNm18wz6PLFLpHpgnoNDNYRpump', 'EENEARTgMKXQ8enXG5uyD16E47Fm7ZrPFgyDxGD6pump', 'EENevTG5pncwpyH3WH5nPCJpRdcLBVZsfiSdr2Spump', 'EEoUjLzjchdpKTtCKzQqAH9TSboU1So6WzteHknFpump', 'EeoWYvaQVwCG1cWqfPSv6ne4AKc7EuTwhCkfQkpjpump', 'EeQJyuEB1gaRQPgkDkYvz2eUBQvc5YMb2TUZmyfMpump', 'EeUmPJyY9oVbZMxyPxAY6qmJuSY6FzW1zQtYXLH1pump', 'EeuQKRqghX5AvVXfcvoLsckNzGmrP1uyEEDqCURqpump', 'EEUtRoqqZYNtVuN1vqasjjs2tWoGRTMzKZdzUUBupump', 'EEvLemijM4sV6wCAVHk7wEFoEXzM5UgTZ158VqiCJm58', 'Eey5Mq1DZXqXTS9bMRL2dgK4waM2etBJqFdsA8Yopump', 'EEysidLk4sjExNcyzqK1yeBRwQXwvcKEbbjnLpnYpump', 'EF23Avq2cTPnMVTfHacZ3SG5Z8misHmFA2gbt2rKqiYH', 'Ef2uHQsBYPoH52ufaH5tKSbcHswF6wwMPKUV8ciPpump', 'EF42nCeXxYw4fG7ts8UBHxT5o1W7TZfgW8CUeGUWpump', 'EFcQixpM6eN4T6zWKBd7Rnh7YVEdFHuvSnujhcMepump', 'EFcWbGA2btWMWXhK9iPNcoHpdeGAcjiFPscKPuDqpump', 'EfDZUYHbBUVVWsa9HEeaSXrha5rzfBrjTxZDhc9P2xWB', 'EFFECT1A1R3Dz8Hg4q5SXKjkiPc6KDRUWQ7Czjvy4H7E', 'EfgEGG9PxLhyk1wqtqgGnwgfVC7JYic3vC9BCWLvpump', 'EFiwQjYFufw2qcXdXmsZgrvhxz3gcHSwafpFRZRNpump', 'EFKaNc4hj996qFk8ZaJFm9EZ25wVVzx5L4Jd4eaWpump', 'EfmqTtfcenKvBwrxSxbHVtnqWL5KqJtsA87rq4G2kVHC', 'EFnEKb6GuCw7w3JfsS2e4LqMfyEhqo6TZSPeak8mdeZm', 'EFrdzE3o3TddKTiUnnhyXr9RWXdZDA5aJrMCt1sppump', 'EFs297Ba8iPFXnkkwXXDUQM82NZALfrHGnsdG7YiQL5a', 'eFsXxtVPnSabtem8ALE5f1xdvoDsacmZphyvExWhNej', 'EFUhJ6Ra8yzaKo9tr9GAyCFXCAtN5zF4uDe27muUpump', 'EFW84Z75aBHpeqi2Bcite3T5t4hgZ8mGsZ1tyTaupump', 'EFWC2jkYZbK7X3F5uncDzCBbQ89pD5BmHKSMoANM3mXN', 'EfWqaEFxVM3od8rKNkSusbnhy1gp3ZYjT455AHSzDKA8', 'EFY8GToe4HrmpYrRpfRUgNEPmfVnUbZrsUhd2mJQpump', 'EfYpPiGb4ymcd9yUUu1sQvm75aND56bnzpp2pbDfpump', 'Eg1JbU5o6rpNNeLGrQ4CT8wyutkZDjc6eWN6J5vnVfFS', 'EG1Y8goUGa7y4iRYRgLgwBmSHc4Lxc91qL35cdDNBiRc', 'Eg62MR4n7xX5vfvCqkP8LypbYsGK7EkfDi69pkycYhat', 'EG7zHDPtmpsD99Z2mWHj3jz2eJ6FYuYAgLRKDjUMpump', 'Eg8TpAXop5jKaaCxcvm8bqPwBFXUnJLxp4uUoet8iNVm', 'EgADUQZrfT66vadw8KbXnce1zUcwtygUjap9BZNU6g8u', 'EgCEwjZtK9tXBKUrxc9CmcDmhyqrptCzzEUmHAB5pump', 'EgELbG49kr9rFpZX9Q1KWrutQXrDXNaFitPnrNcdpump', 'EgF5nwoMtN7GUbjgHMotZSSywQqDXqqpxBPmHvtTpump', 'EghVA3YJwVfo9GTC6XGiFTXY4ZrzmKBUiGBYeFtdv8W6', 'EgLMPdmBqgUXnpyaW1ETDADcd9zTD5qBkDoMqt ...
# INFO:root:Processing batch of 100 tokens...
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=A3JhdVyyLCdmzJQFs5hREUQruvVizyiKpwer6mFCqLuM HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=e1U5yfZtSemWQdxtHubW3PRnPi2Vhw7Czy9cqfupump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ECsNXvrbGLm1SRL13qvdT2MCjjx4bZqsC1wTNRGZpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EcUbB6wMZ92gesoZG1KvJTBmppJQs1g86ivuU8Vspump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EcUgGEve9YX7Na4AtdqLH27V51iRZnoisDShQEGfpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ECutGg12PNhqhkvnH1s1FcuXgCDzKDNhSf5aLtANioR7 HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ECvrjwkiubyuWyKLuPVWn2iJdtQw2ZgP5EACspHS5Msu HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EcWxnKp1UjsEGcmJ1kbFWPHq3biSToZadKEeTj9Mpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EcxZmftSHGs8NYQijdfi7ZtTeQj7VegSi9dPfrkHpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ECY31gWwxy4s2VnMkYhmqDkrV75KrwR2yTtsnrnSpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EcYK2XNG4wWr2vDg2M2Hrts6SrU2QB4NzXLBf888pump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ECZxKmKGEkyKhYUau7WkUE1L9Jp2yLebwX4SnKc1pump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ED1dK5W9aAPqnCp63D16aXSu2koyCgFhCJfvr5ahpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Ed1yisBEAo8UXToSswvVFgzyJKpF48HEdq5kvz2zpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ED2Vw9NSVEJJagsAciwRC8RNV2gbsj7NPtk1FVMgpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ED5nyyWEzpPPiWimP8vYm7sD7TD3LAt3Q3gRTWHzPJBY HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ED5TZKpKNmdcpAWA9jY4znAUSgt5CxLergdomg7Qpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ED5wbeyAYtLM4WRGnohPxJEwniaikEFioVmJyZH6K31m HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ED7V7JwufQJiPfFi5TMRkenZ9WSgEF5G2zdYkehrpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EdaG8TKn36DnrXkVrJ3oSR9qw5hrUXrXS21n84B7AdLP HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EDavhezsuNnhdoAKPExWaMtnuhq6FVqoBYnyFEJLLBqC HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EdevXsYfsBhQY3BSs1RD6R6izKjHBhj7EBN7446apump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EDg2KrxTbamMXZbr6ztSf3igrMmC567h34xTrqL6pump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EdhTCqUxXRWQcUd5Fonyz9rapHAB6mABAuVkmPrtpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EDN4nnhSYNh65wm47TNHFwRMUZ5M5PnHhcKS44p5pump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Edp1oxRgY4auQrmssuvUYvfP128Wwnj4a7qQU5KLpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EDsuVxL6LNuuna6XPzhpVBbezVfsBYBwbeAmenWeuxxS HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Edwwnyt7GFJCpqjq45mR5wjVUpCkZYkyfe1CMvTfpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EDwziqjWSMT2U7kiScrVaC6ee4hyJBXys9zckpGg9RPB HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EDx3uMVFdN89EiH6gCH1r7XQN1KW42HxHBjBRroVpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EE3hEc8HTvVAwMeRxmqvmJpWGXx6p5YSx8DMKCTEpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EE3p4nX6dXp4xQWkH37qbg1SuWnKf7pujn7HrDH4pump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EE7g5kmPZciS8he3dcaPf35jouHg7VxkFCybRfitCZLj HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=eEbwkEC4Bo7hsfsaechNL3nHGvHzhBUxXGPvyRypump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EecF37KL51B8eBoyzgxyS2VA26vbpEazWRX2dx6mpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EEGQzJwzyXgW4LW7V2ZCFwcAMcbQarifCzmyhotgpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EEhwAAb9SbvKSBcyxn2dKvKA8nj6Es6RBAQPsPqKXMbj HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EemhZCaRwN7LwVHzoh8WxZh2gyRCzaZxhvoVPriwRp82 HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Een8PisdGVGUihqkPsjZAUc32WQFKQpmF3JstJqg9cck HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EeNBJ7XS6oURREjgrqNm18wz6PLFLpHpgnoNDNYRpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EENEARTgMKXQ8enXG5uyD16E47Fm7ZrPFgyDxGD6pump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EENevTG5pncwpyH3WH5nPCJpRdcLBVZsfiSdr2Spump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EEoUjLzjchdpKTtCKzQqAH9TSboU1So6WzteHknFpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EeoWYvaQVwCG1cWqfPSv6ne4AKc7EuTwhCkfQkpjpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EeQJyuEB1gaRQPgkDkYvz2eUBQvc5YMb2TUZmyfMpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EeUmPJyY9oVbZMxyPxAY6qmJuSY6FzW1zQtYXLH1pump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EeuQKRqghX5AvVXfcvoLsckNzGmrP1uyEEDqCURqpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EEUtRoqqZYNtVuN1vqasjjs2tWoGRTMzKZdzUUBupump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EEvLemijM4sV6wCAVHk7wEFoEXzM5UgTZ158VqiCJm58 HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Eey5Mq1DZXqXTS9bMRL2dgK4waM2etBJqFdsA8Yopump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EEysidLk4sjExNcyzqK1yeBRwQXwvcKEbbjnLpnYpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EF23Avq2cTPnMVTfHacZ3SG5Z8misHmFA2gbt2rKqiYH HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Ef2uHQsBYPoH52ufaH5tKSbcHswF6wwMPKUV8ciPpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EF42nCeXxYw4fG7ts8UBHxT5o1W7TZfgW8CUeGUWpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EFcQixpM6eN4T6zWKBd7Rnh7YVEdFHuvSnujhcMepump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EFcWbGA2btWMWXhK9iPNcoHpdeGAcjiFPscKPuDqpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EfDZUYHbBUVVWsa9HEeaSXrha5rzfBrjTxZDhc9P2xWB HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EFFECT1A1R3Dz8Hg4q5SXKjkiPc6KDRUWQ7Czjvy4H7E HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EfgEGG9PxLhyk1wqtqgGnwgfVC7JYic3vC9BCWLvpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EFiwQjYFufw2qcXdXmsZgrvhxz3gcHSwafpFRZRNpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EFKaNc4hj996qFk8ZaJFm9EZ25wVVzx5L4Jd4eaWpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EfmqTtfcenKvBwrxSxbHVtnqWL5KqJtsA87rq4G2kVHC HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EFnEKb6GuCw7w3JfsS2e4LqMfyEhqo6TZSPeak8mdeZm HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EFrdzE3o3TddKTiUnnhyXr9RWXdZDA5aJrMCt1sppump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EFs297Ba8iPFXnkkwXXDUQM82NZALfrHGnsdG7YiQL5a HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=eFsXxtVPnSabtem8ALE5f1xdvoDsacmZphyvExWhNej HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EFUhJ6Ra8yzaKo9tr9GAyCFXCAtN5zF4uDe27muUpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EFW84Z75aBHpeqi2Bcite3T5t4hgZ8mGsZ1tyTaupump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EFWC2jkYZbK7X3F5uncDzCBbQ89pD5BmHKSMoANM3mXN HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EfWqaEFxVM3od8rKNkSusbnhy1gp3ZYjT455AHSzDKA8 HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EFY8GToe4HrmpYrRpfRUgNEPmfVnUbZrsUhd2mJQpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EfYpPiGb4ymcd9yUUu1sQvm75aND56bnzpp2pbDfpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Eg1JbU5o6rpNNeLGrQ4CT8wyutkZDjc6eWN6J5vnVfFS HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EG1Y8goUGa7y4iRYRgLgwBmSHc4Lxc91qL35cdDNBiRc HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Eg62MR4n7xX5vfvCqkP8LypbYsGK7EkfDi69pkycYhat HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EG7zHDPtmpsD99Z2mWHj3jz2eJ6FYuYAgLRKDjUMpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Eg8TpAXop5jKaaCxcvm8bqPwBFXUnJLxp4uUoet8iNVm HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EgADUQZrfT66vadw8KbXnce1zUcwtygUjap9BZNU6g8u HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EgCEwjZtK9tXBKUrxc9CmcDmhyqrptCzzEUmHAB5pump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EgELbG49kr9rFpZX9Q1KWrutQXrDXNaFitPnrNcdpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EgF5nwoMtN7GUbjgHMotZSSywQqDXqqpxBPmHvtTpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EghVA3YJwVfo9GTC6XGiFTXY4ZrzmKBUiGBYeFtdv8W6 HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EgLMPdmBqgUXnpyaW1ETDADcd9zTD5qBkDoMqtnYw1hX HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EGLTPncv1XCj93YvC7tc9Qwj9L77hZ42eU3dowxSzqXs HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Egm7ju6j3wvmdXMyWZY9fdotaWJH3nqAXGfDN3MDpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EgMF2iEbKv984fWtqakZ12k4VQvJubTNnU2Y9durpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EGMuM8qhWTzTEa9P75DuT3G4DNVsexWww7fp1vo8pump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Egoq56vzmVYbvyzNQ1aNLAuc39jghV5cU4MfMv4R4U2C HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EGTDETHmMB7MaxNmFgFF7X8yeZdCsf56CUszn7evBEao HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Egtoetiw3pKRNSzwgXZRWgMCbUSZmb2qPVwP2w8BoAzw HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EGXE6rBFFpuxKFbmJMB3sfnM4Y7BqjcWkZZkt46Vpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EgXEPr5i9gYtWVBK9dVNfzQpfPBLFC2faernT41Wpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=egy3LC9ndbxo8LzL8W3s8FzwS3H6gT7t73uUP2Mpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Eh1fXbAipe4k7CYR9UMb2bbWmBcpU3HcyX3LWuRVFBLz HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EH2Tirg1sQ5ayJaEg25nruCkY7rt64c86hoBU9SpKwhA HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Eh69i9hMus7NSvkykyG9j16Q34huu7HpaoUZ3pncmyHc HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Eh6XEPhSwoLv5wFApukmnaVSHQ6sAnoD9BmgmwQoN2sN HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EH9QxCx4WP9Lt43s5h6BQJHFSzFWUSYaaxEipFVRbsEN HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EhA7GAmqLpFSe8zXwnJNu8hHZn8RJrX6kkqftJUtpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EhbAzVRVkDf7CrWVEroaX6P3vyHE13dmjZyRqvRypump HTTP/1.1" 200 None
# INFO:root:Inserted 100 tokens into the database.
# INFO:root:Sleeping for 1 second to prevent DB overload...
# WARNING:__main__:Batch 1 had issues, check logs for details.
# INFO:__main__:Sleeping for 1 second to avoid DB overload...
# INFO:__main__:Processing batch 2: 100 tokens
# DEBUG:__main__:Token batch: ['EHbH3sGYJRK68MKwLgcXdoGVNknrrxELiu174uTGpump', 'EHdaa5TRmbHF9EGyEDXvmGpPbQ7PZqzLs7Ww4Bxxpump', 'EhE1SimJaqU2neTrbTqZF2TBVFjr6GRhzEEESpfXpump', 'EHf9xmuXHBL9QgF4Frgcs8xMxqYDR8F5tuR53pjVpump', 'EHgph1Mj1PGgD1GBzHUwDNN9d9MbUUA2c7iCG348pump', 'EHHAKzPZJhQy4fc7CTaJPFsetPgKnC6JNCdv6pqsQ7Ma', 'Ehk7QXFVqHkyqSpcfmUTCm5mJ9wE5b2axkC6Emcv7Qh1', 'EhkDgP8e5sz16AFCWUCYJzVug1zvpDLTEHxH4WAFpBFA', 'EhnkvA1qSXksF3ymqSSo9Psf6Qw8P4v18pp9rdbXpump', 'EHoYEWdMucFfXMVMR8sn7KXT3JCpqJPU73QodQKnawjg', 'EHRZ7UTweF6uoeVWtKCRXatss9nwbSPDY1tPBt2fpump', 'EHrzxSHzvac2FzMmWfoLUmLP9A2cs2wGCZ3HtjJYw94r', 'EHSGBgBkEv6qQAzF4BvhC83EysrsedAzGVuXtw5epump', 'EHupsSUrj1fNGP4RNHUGeKu17fTMe9LzxWDuNGBcpump', 'EhVaKyet1Aq1WKWAoBy6NaaBgQXAv9cu1CNVq2uVpump', 'ei4iaEcXx51X2hwVrMR1dkuetiaZNYGqEp7CCbDag3K', 'Ei9W7n8w3skQgpC6ve1V2Qd7q4voW4rU7ecB252FeDY5', 'EiaPeMrCYbGtTZRMZduSSri97yF8ppAUahYnojjFxs44', 'EiCdWDaUUGsASnsSjuDwATtVpCQKxWDwnYo6N4SPC4Au', 'EicUtdKGp9RJbktvzd9kjhc1ZkRVVucb3iHAWeoxpump', 'EipfVR2ncU3RCje3vrxo88KEc3EMy1hbq7wBgmRXpump', 'EiR1zbDb9fNy3FrNd8eTMbCaST5HZu3AwFFM1t8Rpump', 'EiRfZeWLW1NymAfjKUePz3jwtq5rZ69XM3zLDS1Npump', 'eiu9KULXfswbCoZSQQLpTPnWRkvp1Fq3i8gRnsvpFPW', 'EiVMQrvdDYK77eK6N6cyh5sGBe5Y1MQWVA7YaURVpump', 'EiZp9d8vp44ogR5NzeMCHARK9nnnXMZkiQKf4Gtpump', 'EiZSoC8gPUWn4TmeoU2yxLXzciJ4d4vjEWCiMQjPpump', 'Ej5gPuHcRjjvN4T1RGYHG7kpjrUAUaFdz64xU7T8pump', 'EjarweaCTzxT1pXB2jCXmjLcgDc4q2KPwYoCGEQRpump', 'EjBbePabjEctGVKXjq72DNejMRwoxHJnkhcyPzc4pump', 'Ejbt97e6n8VkHLs8r2hs43d6zHobVsqGJxeFyJ1Upump', 'EJbWj47sFCcezJ82S4MzRhsWrhRTjsnrVG84QphWpump', 'EJcgopv77hGASLrLXyhyMfb3q2feL1VY26gMmAhkmoon', 'EJeYyXPLpR9AvdhEYExRuAUGEfewq3KzjqpU1ZP5inYJ', 'EjJhYzvz2vhmZrq8fP7offFpeuTxdP1dWJuW1q6w8cHH', 'EJjuKCfWtK4wUWWjxsmvmXAgrTqgEc8FfKD2Pn6ppump', 'EjkkxYpfSwS6TAtKKuiJuNMMngYvumc1t1v9ZX1WJKMp', 'EjmDTt8G3T725eFSV7oWmGD8J848guo3LZ1EB3RfwGSw', 'EjmyN6qEC1Tf1JxiG1ae7UTJhUxSwk1TCWNWqxWV4J6o', 'EJPtJEDogxzDbvM8qvAsqYbLmPj5n1vQeqoAzj9Yfv3q', 'Ejq4Xr7KwHtLPkfGr3DGkKSgyGCuZvsndeyj92yXpump', 'EJqcyLxZZUpYFUT5S4zeJzep4oh1bzqHcLjCyuTapump', 'eJqHomKmy4iVcPAPEvtcXGxAg6cFtzbZwyRbwUjpump', 'ejwq461PCRjhh69sGjkow4Pgw6zqRDB7fYsydVFpump', 'EjyM5MRg3oTRE4dwGFwkZUyNGKq72yV7UWxnEegNpump', 'EjynwKCVPa4MH9sJfufadKazjZ2txdvn7zbv3oeP3Nqq', 'EjyzyFCkB8dZ4MR9aQrYvdRNzMQonNFjNsP3UYBEscL8', 'EjzzyCSiLqjFDprpZj8e1zjXmcTG5HPGFRSEoWcJWHh9', 'Ek3mnJ5aLjGsGcn38d1hQsfE7G3WDzkdrXrdhcdh6ZPo', 'Ekb5irBr6S4fBz2eTc9GoMHGmtLFzPPADhfJkydHrWHc', 'EkcFJGEkCQ7mhD5CF92CPoQhbP2wgCuBaEuguVZ3pump', 'EKEWAk7hfnwfR8DBb1cTayPPambqyC7pwNiYkaYQKQHp', 'EkHfvx6vRqpN1nK7M7JYRvTPUmzTKVTWUaXN2WTdpump', 'EkHr62PC6Y1axrLS7cR8YC4BZeW19mtHxQLCLMrf9vnq', 'Eki94NkJ2xwFzKQ4Pdyq6FbAyeePzAyAKnvQWr6mic2V', 'EKjfcPynz8r4JVWtu1BKC3VNoqCzy95Xzy1EQhKTtpGk', 'EKJtWN2pqCareRrS9KnhJJoyH7Vj24xJ8fEtS4Topump', 'EKLMf7wBHDthh5n2yXtk5CW1YeSUKWgtDSLYxQbCpump', 'EkNMMRhj2zArFyGAxsRhYy5UyeE3kwQSgMQpUfoYpump', 'EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm', 'EKRBZrcu3rKiT1T5kUGRe9S7aCLq3GFYqsqkin9Qpump', 'EKRfVTXTtq27BstXzKWVN8SGmgtEw6DMrGUScazjpump', 'eKRmDZ42Tw73pgKoWzehYSU4kdjTQhx5w69dvEcpump', 'Ekv25wBDprSCtd9xxFqx8jyQQVTcJ1hA4wMVJ7DMpump', 'EkVYMGehJKAFowTQpGoxiCpDTRNEoGanwvNUYXhqpump', 'EkY1JVyMn9noBVHpMpyDAzuhFTVN9RDCg7TRaKiN7Fo7', 'EkYEVGrEc6JrXFfcULE5QvTqpyjnX3Hk4VPjQGQMpump', 'EkzaxBnBmPtrdLJeE8hbzw5eiUen2HcaQAdBMyWxpump', 'EL19SJzQCGGyCqxSdRVV1tVm439vqVWmqQ6DxrnSo4A4', 'EL4Cm7iEnhgPwAmeJ9Kg1of7woyqiiafhjP1bpHcpump', 'eL5fUxj2J4CiQsmW85k5FG9DvuQjjUoBHoQBi2Kpump', 'EL9FuDNNUyjjmQ4U8a1Aazjzq5sDz4krhvBjesAfpump', 'ELdqGtj2MhejZzudGfz7b798si2Av5Asuw9ryEQSpump', 'ELEbLjEwBKU7LAuwSp89HZbGMtnJJjzBCXaPPyk5W8KQ', 'ELFhzsQPVnDcfbLUC96qPT4xTK28YUktJDuvfsgBhDK6', 'ELGkYHvXa4dAu2JT6GQSCt3aXNS9w1Gw4rX2bjSpump', 'ELhdvcfH7u5JRxQbRa7KDNRQFaqe16D4JzWMkd99pump', 'ELkdkY9bxSgFCMHNGhxd9A3ajhKtB47gaNvRm3MtrumP', 'ELn4HUMwhFBPD1EVck3WaGHAk1jYmVrioDRrS1TCpump', 'ELnAjNJJRBaG9MnnZqUXLsbBjkVA19szcduNeD5RCqdo', 'ELnn1dNLseAVLex3U6uULoAjA3gLvyiyFhUFmynEV7Tk', 'ELonMuskaTsLsnzRdNmhErfv8rQeAJaMbeKLZ1nJSC8M', 'ELST1oAp3czkRRRWGeTgttGsEqkD2qjDRJXR4Asmkk ...
# INFO:root:Processing batch of 100 tokens...
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EHbH3sGYJRK68MKwLgcXdoGVNknrrxELiu174uTGpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EHdaa5TRmbHF9EGyEDXvmGpPbQ7PZqzLs7Ww4Bxxpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EhE1SimJaqU2neTrbTqZF2TBVFjr6GRhzEEESpfXpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EHf9xmuXHBL9QgF4Frgcs8xMxqYDR8F5tuR53pjVpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EHgph1Mj1PGgD1GBzHUwDNN9d9MbUUA2c7iCG348pump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EHHAKzPZJhQy4fc7CTaJPFsetPgKnC6JNCdv6pqsQ7Ma HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Ehk7QXFVqHkyqSpcfmUTCm5mJ9wE5b2axkC6Emcv7Qh1 HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EhkDgP8e5sz16AFCWUCYJzVug1zvpDLTEHxH4WAFpBFA HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EhnkvA1qSXksF3ymqSSo9Psf6Qw8P4v18pp9rdbXpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EHoYEWdMucFfXMVMR8sn7KXT3JCpqJPU73QodQKnawjg HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EHRZ7UTweF6uoeVWtKCRXatss9nwbSPDY1tPBt2fpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EHrzxSHzvac2FzMmWfoLUmLP9A2cs2wGCZ3HtjJYw94r HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EHSGBgBkEv6qQAzF4BvhC83EysrsedAzGVuXtw5epump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EHupsSUrj1fNGP4RNHUGeKu17fTMe9LzxWDuNGBcpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EhVaKyet1Aq1WKWAoBy6NaaBgQXAv9cu1CNVq2uVpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ei4iaEcXx51X2hwVrMR1dkuetiaZNYGqEp7CCbDag3K HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Ei9W7n8w3skQgpC6ve1V2Qd7q4voW4rU7ecB252FeDY5 HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EiaPeMrCYbGtTZRMZduSSri97yF8ppAUahYnojjFxs44 HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EiCdWDaUUGsASnsSjuDwATtVpCQKxWDwnYo6N4SPC4Au HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EicUtdKGp9RJbktvzd9kjhc1ZkRVVucb3iHAWeoxpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EipfVR2ncU3RCje3vrxo88KEc3EMy1hbq7wBgmRXpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EiR1zbDb9fNy3FrNd8eTMbCaST5HZu3AwFFM1t8Rpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EiRfZeWLW1NymAfjKUePz3jwtq5rZ69XM3zLDS1Npump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=eiu9KULXfswbCoZSQQLpTPnWRkvp1Fq3i8gRnsvpFPW HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EiVMQrvdDYK77eK6N6cyh5sGBe5Y1MQWVA7YaURVpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EiZp9d8vp44ogR5NzeMCHARK9nnnXMZkiQKf4Gtpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EiZSoC8gPUWn4TmeoU2yxLXzciJ4d4vjEWCiMQjPpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Ej5gPuHcRjjvN4T1RGYHG7kpjrUAUaFdz64xU7T8pump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EjarweaCTzxT1pXB2jCXmjLcgDc4q2KPwYoCGEQRpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EjBbePabjEctGVKXjq72DNejMRwoxHJnkhcyPzc4pump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Ejbt97e6n8VkHLs8r2hs43d6zHobVsqGJxeFyJ1Upump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EJbWj47sFCcezJ82S4MzRhsWrhRTjsnrVG84QphWpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EJcgopv77hGASLrLXyhyMfb3q2feL1VY26gMmAhkmoon HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EJeYyXPLpR9AvdhEYExRuAUGEfewq3KzjqpU1ZP5inYJ HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EjJhYzvz2vhmZrq8fP7offFpeuTxdP1dWJuW1q6w8cHH HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EJjuKCfWtK4wUWWjxsmvmXAgrTqgEc8FfKD2Pn6ppump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EjkkxYpfSwS6TAtKKuiJuNMMngYvumc1t1v9ZX1WJKMp HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EjmDTt8G3T725eFSV7oWmGD8J848guo3LZ1EB3RfwGSw HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EjmyN6qEC1Tf1JxiG1ae7UTJhUxSwk1TCWNWqxWV4J6o HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EJPtJEDogxzDbvM8qvAsqYbLmPj5n1vQeqoAzj9Yfv3q HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Ejq4Xr7KwHtLPkfGr3DGkKSgyGCuZvsndeyj92yXpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EJqcyLxZZUpYFUT5S4zeJzep4oh1bzqHcLjCyuTapump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=eJqHomKmy4iVcPAPEvtcXGxAg6cFtzbZwyRbwUjpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ejwq461PCRjhh69sGjkow4Pgw6zqRDB7fYsydVFpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EjyM5MRg3oTRE4dwGFwkZUyNGKq72yV7UWxnEegNpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EjynwKCVPa4MH9sJfufadKazjZ2txdvn7zbv3oeP3Nqq HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EjyzyFCkB8dZ4MR9aQrYvdRNzMQonNFjNsP3UYBEscL8 HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EjzzyCSiLqjFDprpZj8e1zjXmcTG5HPGFRSEoWcJWHh9 HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Ek3mnJ5aLjGsGcn38d1hQsfE7G3WDzkdrXrdhcdh6ZPo HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Ekb5irBr6S4fBz2eTc9GoMHGmtLFzPPADhfJkydHrWHc HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EkcFJGEkCQ7mhD5CF92CPoQhbP2wgCuBaEuguVZ3pump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EKEWAk7hfnwfR8DBb1cTayPPambqyC7pwNiYkaYQKQHp HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EkHfvx6vRqpN1nK7M7JYRvTPUmzTKVTWUaXN2WTdpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EkHr62PC6Y1axrLS7cR8YC4BZeW19mtHxQLCLMrf9vnq HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Eki94NkJ2xwFzKQ4Pdyq6FbAyeePzAyAKnvQWr6mic2V HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EKjfcPynz8r4JVWtu1BKC3VNoqCzy95Xzy1EQhKTtpGk HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=EKJtWN2pqCareRrS9KnhJJoyH7Vj24xJ8fEtS4Topump HTTP/1.1" 200 None
# ...
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=xzerazCXmKiaqDPoQrztFx6k3qUSJBWQVE4VV39pump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=xZs8kZquprir9rkpmQT3iEnkg5oqrzufVhHBfqVpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=y1AZt42vceCmStjW4zetK3VoNarC1VxJ5iDjpiupump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=y1k9ZRqLwKLbyUe5LfQf53jYXeSyvrFi7URt4FWpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=y2DHD7DjfMGqShKJ93fAQiiyoPs8r94oWEF2hBmpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Y9AcSzX8r5UD5XRwqD5FbPMyw1NP6vy9iC3rdDzB1Hj HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=yA62zLicT9LyfZVxZ15YT4LXGLuX2Ut7eeReXPsWPvF HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=yA7eWYp5Lh8h9EsR9MrJyCH9VoT4iJ7hJRn9LAzpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=YAFAJvjUv9MVAKcTE7Y8ouo45QNKVK6fCMzdxt2tjPs HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=yCYSJATPJiFgtE1Up7LFGQEV8XLZ5Ma7Y53JnXKpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=YeYY8x7gQ2yT156QrpsWXcCgivFcAXqh3dWFYnwpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=yfDzpGCkNj6Dq6wnraVcAfGEBC8ERwBPEWM5ynvpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=yfrEYheD79wT32pVBb2MzDShMoSPYf63qBwa7e5MMai HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=yfVhKobAgpFt3cP7fcbqbY8UdRHz2XRHw8ibPpBpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=yG6bXPEFaUnGAEHHqH9H7t1VSfaK7YrggCqHy35pump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=yHTmmKUrmnQ9UegC4n38R52cH6GYBcQWGAH8u1upump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=yJcC48AWnaFQxb4CfZY6U19aQr3Pw6RKVhuGCLVpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=yJm88Z8xVV5CbZ5cvMisiuQCN8FysNyft7t9nkmpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=yLAzQjGuqArJJGiHvMSPj18Tex4SLpdrHyNMFMbpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=yLUD35WTiPLEY6DUqEj5W2JVXF2DfKB5arPkKJXpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=YmHQjqxwdaZP6p1nMJzVuCAZ592vAjyH8FRM5Gypump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=YMhzCzmvWhnU15BGq8FYj41XvQzphvtqEUQosCppump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=YmmJAazPFQzoodwCfwphWQ2449gqncDTqvC5TtJpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=YntfLjcUR3bpq5dc4kAqipmpA2vfXajzcFLZztGpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=yomFPUqz1wJwYSfD5tZJUtS3bNb8xs8mx9XzBv8RL39 HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ypKVdyGm6i98mJbrjZK4MTZXKjRFiHnodBY4kPDpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=yso11zxLbHA3wBJ9HAtVu6wnesqz9A2qxnhxanasZ4N HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=yTUhC665zWuUuA9KgGzWbtFFM61aDYMorLZmqmjpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=yUdhhWLhiX7M9JMydEQMKBCvkMux5Kdp9JkHsnrpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=yUSDX7W89jXWn4zzDPLnhykDymSjQSmpaJ8e4fjC1fg HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=YyX2UX1Xy8QifWH3wCmBPgK2tq8vpN1tY3FtQuEpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=YzqMHJuXU4xXk25JqaPSzuCozTS76Vxm6PaMML6pump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=yzxKPfrQ13MLQV2afnKWRg8RwxoYUDmCSxfWNcspump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=z2H5voMVaszFgeNFm5sT2dZfrJF35pvVj6wvXfRpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Z3Qxvk11ZE4DZwRCnREQV7nmFqqDBuan8p3J3hzpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=z9ysNwXCYrh4xXRyQG9ujWqxNrdcChoicoJA9ebd7iF HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ZA4vqAcejc8TwDbgqd4gMmr1FpubUwzSGmhLYhgLaHE HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=zAgSwaSC2XjeM545v4YT4ifMpnxkuEE1f8Fq2Ygpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ZBCNpuD7YMXzTHB2fhGkGi78MNsHGLRXUhRewNRm9RU HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=Zc4uJVrHC2APe9qKwBD11Gg4BbvQr3naM8f7Wiopump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ZdkCNn5JuE3m5FQD9zcxZuZHH5HdF3wJH5tWijSpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ZEkZrD9QtD1aLhBiJqhETMXsc5up9W7uMkiL7Wtrump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ZEUS1aR7aX8DFFJf5QjWj2ftDDdNTroMNGo8YoQm3Gq HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ZEXy1pqteRu3n13kdyh4LwPQknkFk3GzmMYMuNadWPo HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=zFCN2vUTXjhy5wTpGzysqfPYHbK8SZymSuTnSKjpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=zGh48JtNHVBb5evgoZLXwgPD2Qu4MhkWdJLGDAupump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=zi87E9xtFPRQ2o9qqerFxUDQLZgEkHrhpHDxxZhYi9a HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ZiTjZ8FrWaTYY9p6ANmVeX5PZUpKwwe26joHpqbpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ZK92f6zeaxSdKhmpgANLNjUFVd3XLAn8M7Dp5wRpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ZNjDcVppJQV8Z9NECsuUhoM1VdJ3fvRtdFhDEaZpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ZNLe8EYJDMbz6HYwdKq5z3FWi2UktTNPGsthDTdpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=zPf8M7V2YznAvLzsnauyBb3gefYpYbrMotzifXJpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=zrvL3iuAqoBdfwAmaUYrYcS8UjUk6LbKrexT7aepump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ZScHuTtqZukUrtZS43teTKGs2VqkKL8k4QCouR2n6Uo HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=zSyuawLybV374Fiufx4bQnLnwfFRxX2cFsQ6kwKpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=zU8tExwzx522Px3wXn5rHumQtEgBnNb3vQwiBDXbSXK HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=zur5h6yc2x7vuzrwk5Nm5c15v1yPoLtg71mNKT4pump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ZW8saVXD4AtNs9E2orLkGA3Vd7Nhsp6qXoL43cJpump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ZxBon4vcf3DVcrt63fJU52ywYm9BKZC6YuXDhb3fomo HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=ZYDWbrsVbaE83FVXvdHoUVcKRrDN9S2Jskyhsuypump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=zZJcBxq1guSSFjhJZZaeuyasyMZpdsZfptwT1v6pump HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=zZRRHGndBuUsbn4VM47RuagdYt57hBbskQ2Ba6K5775 HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_security?address=zZxKYWvPm669u65hKq6FQaBT87RjXqVhE7HjEhApump HTTP/1.1" 200 None
# INFO:root:Inserted 95 tokens into the database.
# INFO:root:Sleeping for 1 second to prevent DB overload...
# WARNING:__main__:Batch 33 had issues, check logs for details.
# INFO:__main__:Sleeping for 1 second to avoid DB overload...
# INFO:__main__:Database connection closed.
