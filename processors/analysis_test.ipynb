# %%
from processors.update_tokens import main as update_tokens_main
import sys
from db.connection import DatabaseConnection
from db.queries import DatabaseQueries
from config import load_config
import logging
import random
import requests
from time import sleep
import pandas as pd


# Logging setup
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    handlers=[
        logging.FileHandler("token_update.log"),
        logging.StreamHandler(sys.stdout),
    ],
)
logger = logging.getLogger(__name__)

# %%
# Load configuration
logger.info("Loading configuration...")
config = load_config()

# Initialize database connection and queries
logger.info("Initializing database connection...")
db_connection = DatabaseConnection(config.db)
db_queries = DatabaseQueries(db_connection)

# %%
logger.info("Calling update_tokens.main()...")
update_tokens_main()

# Get recent transactions
logger.info("Fetching recent transactions...")
hourly_transactions_df = db_queries.get_recent_transactions(n=4)

# Extract unique token addresses
logger.info("Extracting unique token addresses from transactions...")
token_columns = [
    "open_input_mint",
    "open_output_mint",
    "close_input_mint",
    "close_output_mint",
]
unique_tokens = pd.unique(hourly_transactions_df[token_columns].values.ravel())
logger.info(f"Found {len(unique_tokens)} unique token addresses.")

# %%
unique_tokens

# %%
def fetch_token_details(chain_id, token_addresses, api_url):
    """
    Fetch token details from Dexscreener API in batches and parse the response into a DataFrame.

    Args:
        chain_id (str): The chain ID (e.g., "solana").
        token_addresses (list): List of token addresses.
        api_url (str): Base URL of the Dexscreener API.

    Returns:
        pd.DataFrame: DataFrame containing token details.
    """
    token_details_list = []

    # Filter out None values from token_addresses
    token_addresses = [address for address in token_addresses if address is not None]

    # Process addresses in batches of 30
    for i in range(0, len(token_addresses), 30):
        batch_addresses = token_addresses[i:i+30]
        try:
            response = requests.get(f"{api_url}/tokens/v1/{chain_id}/{','.join(batch_addresses)}")
            response.raise_for_status()
            data = response.json()

            # Parse each token's details in the batch
            for token_data in data:
                token_details = {
                    'chainId': token_data.get('chainId', ''),
                    'dexId': token_data.get('dexId', ''),
                    'url': token_data.get('url', ''),
                    'pairAddress': token_data.get('pairAddress', ''),
                    'labels': token_data.get('labels', []),
                    'baseToken_address': token_data.get('baseToken', {}).get('address', ''),
                    'baseToken_name': token_data.get('baseToken', {}).get('name', ''),
                    'baseToken_symbol': token_data.get('baseToken', {}).get('symbol', ''),
                    'quoteToken_address': token_data.get('quoteToken', {}).get('address', ''),
                    'quoteToken_name': token_data.get('quoteToken', {}).get('name', ''),
                    'quoteToken_symbol': token_data.get('quoteToken', {}).get('symbol', ''),
                    'priceNative': token_data.get('priceNative', 0.0),
                    'priceUsd': token_data.get('priceUsd', 0.0),
                    'txns_m5_buys': token_data.get('txns', {}).get('m5', {}).get('buys', 0),
                    'txns_m5_sells': token_data.get('txns', {}).get('m5', {}).get('sells', 0),
                    'txns_h1_buys': token_data.get('txns', {}).get('h1', {}).get('buys', 0),
                    'txns_h1_sells': token_data.get('txns', {}).get('h1', {}).get('sells', 0),
                    'txns_h6_buys': token_data.get('txns', {}).get('h6', {}).get('buys', 0),
                    'txns_h6_sells': token_data.get('txns', {}).get('h6', {}).get('sells', 0),
                    'txns_h24_buys': token_data.get('txns', {}).get('h24', {}).get('buys', 0),
                    'txns_h24_sells': token_data.get('txns', {}).get('h24', {}).get('sells', 0),
                    'volume_h24': token_data.get('volume', {}).get('h24', 0.0),
                    'volume_h6': token_data.get('volume', {}).get('h6', 0.0),
                    'volume_h1': token_data.get('volume', {}).get('h1', 0.0),
                    'volume_m5': token_data.get('volume', {}).get('m5', 0.0),
                    'priceChange_m5': token_data.get('priceChange', {}).get('m5', 0.0),
                    'priceChange_h1': token_data.get('priceChange', {}).get('h1', 0.0),
                    'priceChange_h6': token_data.get('priceChange', {}).get('h6', 0.0),
                    'priceChange_h24': token_data.get('priceChange', {}).get('h24', 0.0),
                    'liquidity_usd': token_data.get('liquidity', {}).get('usd', 0.0),
                    'liquidity_base': token_data.get('liquidity', {}).get('base', 0.0),
                    'liquidity_quote': token_data.get('liquidity', {}).get('quote', 0.0),
                    'pairCreatedAt': token_data.get('pairCreatedAt', '')
                }
                token_details_list.append(token_details)
            sleep(1)
        except requests.RequestException as e:
            print(f"Error fetching details for batch {batch_addresses}: {e}")
            sleep(1)

    # Convert list of token details to DataFrame
    token_details = pd.DataFrame(token_details_list)
    return token_details

# %%
# Example usage
chain_id = "solana"
token_addresses = unique_tokens.copy()  # Replace with actual token addresses
api_url = "https://api.dexscreener.com"

token_details_df = fetch_token_details(chain_id, token_addresses, api_url)
print(token_details_df)

# %%
token_details_df

# %%
# Configure logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")
logger = logging.getLogger(__name__)

# BirdEye API base URL
BIRDEYE_API_URL = "https://public-api.birdeye.so/defi/historical-price/unix"

# Flag to determine whether to use the mock API
USE_MOCK_API = True

def fetch_historical_price(token_mint, timestamp, api_key):
    """
    Fetch historical price for a given token at a specific timestamp.
    If USE_MOCK_API is True, return a random number between 0.00001 and 2.00000.
    Otherwise, call the actual BirdEye API.
    """
    if USE_MOCK_API:
        # Generate a random price between 0.00001 and 2.00000, rounded to 5 decimal places
        random_price = round(random.uniform(0.00001, 2.00000), 5)
        logger.info(f"Mock fetch for {token_mint} at {timestamp}: {random_price}")
        return random_price
    else:
        params = {"address": token_mint, "timestamp": timestamp, "apikey": api_key}
        try:
            response = requests.get(BIRDEYE_API_URL, params=params)
            response.raise_for_status()
            data = response.json()
            return data.get("price", None)
        except requests.RequestException as e:
            logger.error(f"Error fetching price for {token_mint} at {timestamp}: {e}")
            return None

def main():
    # Assume load_config, DatabaseConnection, and DatabaseQueries are defined elsewhere
    config = load_config()
    db_connection = DatabaseConnection(config.db)
    db_queries = DatabaseQueries(db_connection)

    try:
        # Fetch recent transactions
        logger.info("Fetching recent transactions...")
        transactions_df = db_queries.get_recent_transactions(n=2)

        # Add new columns for prices
        transactions_df["open_input_price"] = None
        transactions_df["close_output_price"] = None

        # Fetch historical prices (using the mocked API when USE_MOCK_API is True)
        for index, row in transactions_df.iterrows():
            if row["open_input_mint"]:
                transactions_df.at[index, "open_input_price"] = fetch_historical_price(
                    row["open_input_mint"], row["open_block_time"], config.birdeye.api_key
                )
            if row["close_output_mint"]:
                transactions_df.at[index, "close_output_price"] = fetch_historical_price(
                    row["close_output_mint"], row["close_block_time"], config.birdeye.api_key
                )
            sleep(0.2)  # Avoid hitting rate limits (if not in mock mode)

        # Extract unique token addresses
        unique_tokens = pd.unique(
            transactions_df[["open_input_mint", "open_output_mint", "close_input_mint", "close_output_mint"]].values.ravel()
        )
        unique_tokens = [token for token in unique_tokens if pd.notnull(token)]

        # Fetch token details from database
        logger.info("Fetching token details...")
        token_info_df = db_queries.get_token_info(unique_tokens)

        # Merge transactions with token info
        transactions_df = transactions_df.merge(token_info_df, left_on="open_input_mint", right_on="token", how="left")
        transactions_df = transactions_df.rename(columns={
            "decimals": "open_input_decimals",
            "creation_time": "open_input_creation_time",
            "is_suspicious": "open_input_is_suspicious"
        })

        transactions_df = transactions_df.merge(token_info_df, left_on="close_output_mint", right_on="token", how="left", suffixes=("", "_close"))
        transactions_df = transactions_df.rename(columns={
            "decimals_close": "close_output_decimals",
            "creation_time_close": "close_output_creation_time",
            "is_suspicious_close": "close_output_is_suspicious"
        })

        # Save the final dataframe
        output_file = "updated_transactions.xlsx"
        transactions_df.to_excel(output_file, index=False)
        logger.info(f"Updated transactions saved to {output_file}")

    except Exception as e:
        logger.error(f"An error occurred: {e}")
    finally:
        db_connection.close()

if __name__ == "__main__":
    main()

# %%
import logging
import requests
import pandas as pd
from time import sleep
from tqdm import tqdm  # progress bar package
from processors.update_tokens import main as update_tokens_main
import sys
from db.connection import DatabaseConnection
from db.queries import DatabaseQueries
from config import load_config
import logging
import random
import requests
from time import sleep
import pandas as pd

# Configure logging globally
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")
logger = logging.getLogger(__name__)

# -------------------------------------------------------------------
# Updated fetch_historical_price function (as previously defined)
def fetch_historical_price(token_mint, timestamp, api_key):
    """
    Fetch the historical price for a given token at a specific timestamp using the Birdeye API.
    Constructs the URL with the required query parameters (address and unixtime) and headers.

    Expected API response schema:
    {
      "success": true,
      "data": {
        "value": 128.09276765626564,
        "updateUnixTime": 1726675897,
        "priceChange24h": -4.924324221890145
      }
    }

    Returns the 'value' (price) if successful, otherwise None.
    """
    try:
        # Ensure timestamp is an integer
        timestamp_int = int(timestamp)
    except Exception as e:
        logger.error(f"fetch_historical_price: Could not convert timestamp '{timestamp}' to int: {e}")
        return None

    # Construct URL with required parameters
    url = f"https://public-api.birdeye.so/defi/historical_price_unix?address={token_mint}&unixtime={timestamp_int}"
    logger.info(f"fetch_historical_price: Requesting price for token '{token_mint}' at timestamp '{timestamp_int}'.")

    headers = {
        "accept": "application/json",
        "x-chain": "solana",
        "X-API-KEY": api_key
    }

    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        data = response.json()

        if data.get("success") is True:
            token_data = data.get("data")
            if token_data is not None:
                price = token_data.get("value")
                logger.info(f"fetch_historical_price: Received price {price} for token '{token_mint}' at timestamp '{timestamp_int}'.")
                return price
            else:
                logger.error(f"fetch_historical_price: API returned success but data is None for token '{token_mint}' at timestamp '{timestamp_int}'. Response: {data}")
                return None
        else:
            logger.error(f"fetch_historical_price: API returned error for token '{token_mint}' at timestamp '{timestamp_int}'. Response: {data}")
            return None
    except requests.RequestException as e:
        logger.error(f"fetch_historical_price: Request error for token '{token_mint}' at timestamp '{timestamp_int}': {e}")
        return None

# -------------------------------------------------------------------
def fetch_token_details(chain_id, token_addresses, api_url):
    """
    Fetch token details from the Dexscreener API in batches and return a DataFrame.

    Processes token addresses in batches of 30 and uses a progress bar for visibility.

    The function now also extracts the 'fdv' and 'marketCap' fields from the API response.

    Example API response for each token:
    [
      {
        "chainId": "solana",
        "dexId": "meteora",
        "url": "https://dexscreener.com/solana/...",
        "pairAddress": "BwE7MRPusY...",
        "labels": ["DLMM"],
        "baseToken": {
          "address": "2RBko3xoz56aH69isQMUpzZd9NYHahhwC23A5F3Spkin",
          "name": "PUMPKIN",
          "symbol": "PKIN"
        },
        "quoteToken": {
          "address": "So11111111111111111111111111111111111111112",
          "name": "Wrapped SOL",
          "symbol": "SOL"
        },
        "priceNative": "0.00006499",
        "priceUsd": "0.01328",
        "txns": { ... },
        "volume": { ... },
        "priceChange": { ... },
        "liquidity": { "usd": 19529.75, "base": 829331, "quote": 41.6679 },
        "fdv": 13281688,
        "marketCap": 12484039,
        "pairCreatedAt": 1738140160000,
        "info": { ... }
      }
    ]

    Returns:
        pd.DataFrame: A DataFrame containing token details, including the new 'fdv' and 'marketCap' fields.
    """
    logger.info(f"fetch_token_details: Starting to fetch details for {len(token_addresses)} tokens on chain '{chain_id}'.")
    token_details_list = []

    # Filter out any None values from token_addresses
    token_addresses = [address for address in token_addresses if address is not None]

    # Process addresses in batches of 30 with a progress bar
    total_batches = (len(token_addresses) + 29) // 30
    for i in tqdm(range(0, len(token_addresses), 30), desc='Processing token batches', unit='batch', total=total_batches):
        batch_addresses = token_addresses[i:i+30]
        logger.info(f"fetch_token_details: Processing batch {i//30 + 1} with tokens: {batch_addresses}")
        try:
            response = requests.get(f"{api_url}/tokens/v1/{chain_id}/{','.join(batch_addresses)}")
            response.raise_for_status()
            data = response.json()

            for token_data in data:
                token_details = {
                    'chainId': token_data.get('chainId', ''),
                    'dexId': token_data.get('dexId', ''),
                    'url': token_data.get('url', ''),
                    'pairAddress': token_data.get('pairAddress', ''),
                    'labels': token_data.get('labels', []),
                    'baseToken_address': token_data.get('baseToken', {}).get('address', ''),
                    'baseToken_name': token_data.get('baseToken', {}).get('name', ''),
                    'baseToken_symbol': token_data.get('baseToken', {}).get('symbol', ''),
                    'quoteToken_address': token_data.get('quoteToken', {}).get('address', ''),
                    'quoteToken_name': token_data.get('quoteToken', {}).get('name', ''),
                    'quoteToken_symbol': token_data.get('quoteToken', {}).get('symbol', ''),
                    'priceNative': token_data.get('priceNative', 0.0),
                    'priceUsd': token_data.get('priceUsd', 0.0),
                    'txns_m5_buys': token_data.get('txns', {}).get('m5', {}).get('buys', 0),
                    'txns_m5_sells': token_data.get('txns', {}).get('m5', {}).get('sells', 0),
                    'txns_h1_buys': token_data.get('txns', {}).get('h1', {}).get('buys', 0),
                    'txns_h1_sells': token_data.get('txns', {}).get('h1', {}).get('sells', 0),
                    'txns_h6_buys': token_data.get('txns', {}).get('h6', {}).get('buys', 0),
                    'txns_h6_sells': token_data.get('txns', {}).get('h6', {}).get('sells', 0),
                    'txns_h24_buys': token_data.get('txns', {}).get('h24', {}).get('buys', 0),
                    'txns_h24_sells': token_data.get('txns', {}).get('h24', {}).get('sells', 0),
                    'volume_h24': token_data.get('volume', {}).get('h24', 0.0),
                    'volume_h6': token_data.get('volume', {}).get('h6', 0.0),
                    'volume_h1': token_data.get('volume', {}).get('h1', 0.0),
                    'volume_m5': token_data.get('volume', {}).get('m5', 0.0),
                    'priceChange_m5': token_data.get('priceChange', {}).get('m5', 0.0),
                    'priceChange_h1': token_data.get('priceChange', {}).get('h1', 0.0),
                    'priceChange_h6': token_data.get('priceChange', {}).get('h6', 0.0),
                    'priceChange_h24': token_data.get('priceChange', {}).get('h24', 0.0),
                    'liquidity_usd': token_data.get('liquidity', {}).get('usd', 0.0),
                    'liquidity_base': token_data.get('liquidity', {}).get('base', 0.0),
                    'liquidity_quote': token_data.get('liquidity', {}).get('quote', 0.0),
                    # New fields:
                    'fdv': token_data.get('fdv', 0),
                    'marketCap': token_data.get('marketCap', 0),
                    'pairCreatedAt': token_data.get('pairCreatedAt', '')
                }
                token_details_list.append(token_details)
            logger.info(f"fetch_token_details: Completed processing batch {i//30 + 1}.")
            sleep(1)  # avoid rate limiting
        except requests.RequestException as e:
            logger.error(f"fetch_token_details: Error fetching batch {batch_addresses}: {e}")
            sleep(1)

    token_details = pd.DataFrame(token_details_list)
    logger.info("fetch_token_details: Finished fetching all token details.")
    return token_details


# -------------------------------------------------------------------
# Main function with progress bars for transactions and tokens processing
def main():
    # Initialize configuration and database connections
    config = load_config()
    db_connection = DatabaseConnection(config.db)
    db_queries = DatabaseQueries(db_connection)

    try:
        logger.info("main: Starting main function execution.")

        # (1) Update token information (e.g., current prices)
        # Uncomment the following lines if you want to update tokens
        # logger.info("main: Calling update_tokens.main()...")
        # update_tokens_main()

        # (2) Fetch recent transactions (e.g., from the past 6 hours)
        logger.info("main: Fetching recent transactions...")
        transactions_df = db_queries.get_recent_transactions(n=1)
        logger.info(f"main: Fetched {len(transactions_df)} transactions.")

        # (3) Fetch token details once
        token_columns = [
            "open_input_mint", "open_output_mint", "close_input_mint", "close_output_mint"
        ]
        unique_tokens = pd.unique(transactions_df[token_columns].values.ravel())
        logger.info(f"main: Found {len(unique_tokens)} unique token addresses for details.")
        chain_id = "solana"
        api_url = "https://api.dexscreener.com"
        token_details_df = fetch_token_details(chain_id, unique_tokens, api_url)

        # (4) Add new columns for chosen tokens and their historical prices
        transactions_df["input_token"] = None
        transactions_df["output_token"] = None
        transactions_df["input_price"] = None
        transactions_df["output_price"] = None

        # (5) Use a cache to avoid duplicate API calls for the same (token, block_time) combination
        price_cache = {}
        logger.info("main: Processing transactions to fetch historical prices...")
        # Wrap the transactions iteration with tqdm for progress reporting
        for index, row in tqdm(transactions_df.iterrows(), total=len(transactions_df), desc="Processing transactions"):
            if pd.notnull(row["open_input_mint"]):
                input_token = row["open_input_mint"]
                output_token = row["open_output_mint"]
                block_time = row["open_block_time"]
            else:
                input_token = row["close_input_mint"]
                output_token = row["close_output_mint"]
                block_time = row["close_block_time"]

            transactions_df.at[index, "input_token"] = input_token
            transactions_df.at[index, "output_token"] = output_token

            # Fetch historical price for input token using caching
            key_input = (input_token, block_time)
            if key_input in price_cache:
                input_price = price_cache[key_input]
                logger.debug(f"main: Using cached price for input token '{input_token}' at {block_time}.")
            else:
                input_price = fetch_historical_price(input_token, block_time, config.birdeye.api_key)
                price_cache[key_input] = input_price
                logger.debug(f"main: Cached price {input_price} for input token '{input_token}' at {block_time}.")

            # Fetch historical price for output token using caching
            key_output = (output_token, block_time)
            if key_output in price_cache:
                output_price = price_cache[key_output]
                logger.debug(f"main: Using cached price for output token '{output_token}' at {block_time}.")
            else:
                output_price = fetch_historical_price(output_token, block_time, config.birdeye.api_key)
                price_cache[key_output] = output_price
                logger.debug(f"main: Cached price {output_price} for output token '{output_token}' at {block_time}.")

            transactions_df.at[index, "input_price"] = input_price
            transactions_df.at[index, "output_price"] = output_price

            sleep(0.2)  # Avoid rate limiting

        # (6) Calculate per-transaction dollar amounts:
        logger.info("main: Calculating per-transaction dollar values...")
        transactions_df["dollars_sold"] = (
                transactions_df["in_amount"].astype(float) *
                transactions_df["input_price"].astype(float)
        )
        transactions_df["dollars_bought"] = (
                transactions_df["out_amount"].astype(float) *
                transactions_df["output_price"].astype(float)
        )

        # (7) Aggregate dollar amounts per token:
        logger.info("main: Aggregating dollar values per token...")
        aggregated_sold = (
            transactions_df.groupby("input_token")["dollars_sold"]
            .sum()
            .reset_index()
            .rename(columns={"input_token": "token"})
        )
        aggregated_bought = (
            transactions_df.groupby("output_token")["dollars_bought"]
            .sum()
            .reset_index()
            .rename(columns={"output_token": "token"})
        )
        aggregated = pd.merge(aggregated_sold, aggregated_bought, on="token", how="outer")
        aggregated["dollars_sold"] = aggregated["dollars_sold"].fillna(0)
        aggregated["dollars_bought"] = aggregated["dollars_bought"].fillna(0)
        logger.info("main: Aggregated token values:")
        logger.info(aggregated)

        # (8) Merge aggregated data with token details
        logger.info("main: Merging aggregated data with token details...")
        final_df = pd.merge(aggregated, token_details_df, left_on="token", right_on="baseToken_address", how="left")

        # (9) Format dollars columns to use a comma as the decimal separator.
        logger.info("main: Formatting dollar values with comma as decimal separator...")
        final_df["dollars_sold"] = final_df["dollars_sold"].apply(lambda x: f"{x:.2f}".replace('.',','))
        final_df["dollars_bought"] = final_df["dollars_bought"].apply(lambda x: f"{x:.2f}".replace('.',','))

        # (10) Remove timezone information for Excel compatibility.
        for col in transactions_df.select_dtypes(include=["datetimetz"]).columns:
            transactions_df[col] = transactions_df[col].dt.tz_localize(None)
        for col in final_df.select_dtypes(include=["datetimetz"]).columns:
            final_df[col] = final_df[col].dt.tz_localize(None)

        # (11) Write the final merged output to an Excel file.
        logger.info("main: Writing final aggregated token details to Excel file...")
        final_df.to_excel("final_aggregated_token_details.xlsx", index=False)
        logger.info("main: Final Excel file written successfully.")
        print(final_df)

    except Exception as e:
        logger.error(f"main: An error occurred: {e}", exc_info=True)
    finally:
        db_connection.close()
        logger.info("main: Database connection closed.")

if __name__ == "__main__":
    main()
# Out:
# 2025-02-05 18:06:27,773 - INFO - main: Starting main function execution.
# 2025-02-05 18:06:27,775 - INFO - main: Fetching recent transactions...
# 2025-02-05 18:06:27,776 - INFO - Fetching recent transactions for the past 1 hours.
# 2025-02-05 18:06:28,500 - INFO - Fetched 80 rows of transactions.
# 2025-02-05 18:06:28,502 - INFO - main: Fetched 80 transactions.
# 2025-02-05 18:06:28,503 - INFO - main: Found 60 unique token addresses for details.
# 2025-02-05 18:06:28,504 - INFO - fetch_token_details: Starting to fetch details for 60 tokens on chain 'solana'.
# Processing token batches:   0%|          | 0/2 [00:00<?, ?batch/s]2025-02-05 18:06:28,507 - INFO - fetch_token_details: Processing batch 1 with tokens: ['EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v', 'jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v', '9bNUjxEvygayUE2ZRN5zh9Hhjh6cN6GPK4zoHzXXpump', '2zMMhcVQEXDtdE6vsFS7S7D5oUodfJHE8vd1gnBouauv', '3ufbSaVQSGeoCbgVp45YYYWKygbYFXAUZ7n7AP4CUWg6', 'So11111111111111111111111111111111111111112', '63LfDmNb3MQ8mw9MtZ2To9bEA2M71kZUUGq5tiJxcqj9', 'CNyMaRR4krm1yAxfCvPXevNMArZZZk7sRqKwX68uCeJk', 'Bv8q9VYwyU3QCiHWMdko7pZx8BW1zERhvANNN8P7uvnH', '2yd2Suus3YY4Sa7LHhn1PSHkjXj3XKrars4cCog2tGU8', '2z1p8xCEjRzpBHjXWrx4tJnz7BFL6z7NnvbCxH7bpump', 'C8cNX2D1y3jqKpMFkQhP1gGbfvTEdeckZXLBKSN5z5KF', 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB', '7XJiwLDrjzxDYdZipnJXzpr1iDTmK55XixSFAa7JgNEL', '2Vnei1LAmrBpbL8fNCiCpaYcQTCSodiE51wab6qaQJAq', 'A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump', '4mbdysBik3jmzD7mt6FGPDsMxnYcxExSQRFjPucdpump', 'FasH397CeZLNYWkd3wWK9vrmjd1z93n3b59DssRXpump', 'BCQRnuZEYw6z4AedaJRpDnQzpmqUgK8PPeLnqaNcpump', '3NZ9JMVBmGAqocybic2c7LQCJScmgsAZ6vQqTDzcqmJh', '9DHe3pycTuymFk4H4bbPoAJ4hQrr2kaLDF6J6aAKpump', 'DriFtupJYLTosbwoN8koMbEYSx54aFAVLddWsbksjwg7', '98mb39tPFKQJ4Bif8iVg9mYb9wsfPZgpgN1sxoVTpump', 'J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn', 'eL5fUxj2J4CiQsmW85k5FG9DvuQjjUoBHoQBi2Kpump', 'CuxbDwNU9q8uLVU8E4drMPzrXQ3ipzH3Fai7Bfoepump', '9McvH6w97oewLmPxqQEoHUAv3u5iYMyQ9AeZZhguYf1T', 'F9TgEJLLRUKDRF16HgjUCdJfJ5BK6ucyiW8uJxVPpump', 'G25rCkrGqTf1hL5U8aq5niJDHccuBFLZSAbQNaCNpump', 'ELdqGtj2MhejZzudGfz7b798si2Av5Asuw9ryEQSpump']
# 2025-02-05 18:07:10,614 - ERROR - fetch_token_details: Error fetching batch ['EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v', 'jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v', '9bNUjxEvygayUE2ZRN5zh9Hhjh6cN6GPK4zoHzXXpump', '2zMMhcVQEXDtdE6vsFS7S7D5oUodfJHE8vd1gnBouauv', '3ufbSaVQSGeoCbgVp45YYYWKygbYFXAUZ7n7AP4CUWg6', 'So11111111111111111111111111111111111111112', '63LfDmNb3MQ8mw9MtZ2To9bEA2M71kZUUGq5tiJxcqj9', 'CNyMaRR4krm1yAxfCvPXevNMArZZZk7sRqKwX68uCeJk', 'Bv8q9VYwyU3QCiHWMdko7pZx8BW1zERhvANNN8P7uvnH', '2yd2Suus3YY4Sa7LHhn1PSHkjXj3XKrars4cCog2tGU8', '2z1p8xCEjRzpBHjXWrx4tJnz7BFL6z7NnvbCxH7bpump', 'C8cNX2D1y3jqKpMFkQhP1gGbfvTEdeckZXLBKSN5z5KF', 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB', '7XJiwLDrjzxDYdZipnJXzpr1iDTmK55XixSFAa7JgNEL', '2Vnei1LAmrBpbL8fNCiCpaYcQTCSodiE51wab6qaQJAq', 'A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump', '4mbdysBik3jmzD7mt6FGPDsMxnYcxExSQRFjPucdpump', 'FasH397CeZLNYWkd3wWK9vrmjd1z93n3b59DssRXpump', 'BCQRnuZEYw6z4AedaJRpDnQzpmqUgK8PPeLnqaNcpump', '3NZ9JMVBmGAqocybic2c7LQCJScmgsAZ6vQqTDzcqmJh', '9DHe3pycTuymFk4H4bbPoAJ4hQrr2kaLDF6J6aAKpump', 'DriFtupJYLTosbwoN8koMbEYSx54aFAVLddWsbksjwg7', '98mb39tPFKQJ4Bif8iVg9mYb9wsfPZgpgN1sxoVTpump', 'J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn', 'eL5fUxj2J4CiQsmW85k5FG9DvuQjjUoBHoQBi2Kpump', 'CuxbDwNU9q8uLVU8E4drMPzrXQ3ipzH3Fai7Bfoepump', '9McvH6w97oewLmPxqQEoHUAv3u5iYMyQ9AeZZhguYf1T', 'F9TgEJLLRUKDRF16HgjUCdJfJ5BK6ucyiW8uJxVPpump', 'G25rCkrGqTf1hL5U8aq5niJDHccuBFLZSAbQNaCNpump', 'ELdqGtj2MhejZzudGfz7b798si2Av5Asuw9ryEQSpump']: HTTPSConnectionPool(host='api.dexscreener.com', port=443): Max retries exceeded with url: /tokens/v1/solana/EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v,jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v,9bNUjxEvygayUE2ZRN5zh9Hhjh6cN6GPK4zoHzXXpump,2zMMhcVQEXDtdE6vsFS7S7D5oUodfJHE8vd1gnBouauv,3ufbSaVQSGeoCbgVp45YYYWKygbYFXAUZ7n7AP4CUWg6,So11111111111111111111111111111111111111112,63LfDmNb3MQ8mw9MtZ2To9bEA2M71kZUUGq5tiJxcqj9,CNyMaRR4krm1yAxfCvPXevNMArZZZk7sRqKwX68uCeJk,Bv8q9VYwyU3QCiHWMdko7pZx8BW1zERhvANNN8P7uvnH,2yd2Suus3YY4Sa7LHhn1PSHkjXj3XKrars4cCog2tGU8,2z1p8xCEjRzpBHjXWrx4tJnz7BFL6z7NnvbCxH7bpump,C8cNX2D1y3jqKpMFkQhP1gGbfvTEdeckZXLBKSN5z5KF,Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB,7XJiwLDrjzxDYdZipnJXzpr1iDTmK55XixSFAa7JgNEL,2Vnei1LAmrBpbL8fNCiCpaYcQTCSodiE51wab6qaQJAq,A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump,4mbdysBik3jmzD7mt6FGPDsMxnYcxExSQRFjPucdpump,FasH397CeZLNYWkd3wWK9vrmjd1z93n3b59DssRXpump,BCQRnuZEYw6z4AedaJRpDnQzpmqUgK8PPeLnqaNcpump,3NZ9JMVBmGAqocybic2c7LQCJScmgsAZ6vQqTDzcqmJh,9DHe3pycTuymFk4H4bbPoAJ4hQrr2kaLDF6J6aAKpump,DriFtupJYLTosbwoN8koMbEYSx54aFAVLddWsbksjwg7,98mb39tPFKQJ4Bif8iVg9mYb9wsfPZgpgN1sxoVTpump,J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn,eL5fUxj2J4CiQsmW85k5FG9DvuQjjUoBHoQBi2Kpump,CuxbDwNU9q8uLVU8E4drMPzrXQ3ipzH3Fai7Bfoepump,9McvH6w97oewLmPxqQEoHUAv3u5iYMyQ9AeZZhguYf1T,F9TgEJLLRUKDRF16HgjUCdJfJ5BK6ucyiW8uJxVPpump,G25rCkrGqTf1hL5U8aq5niJDHccuBFLZSAbQNaCNpump,ELdqGtj2MhejZzudGfz7b798si2Av5Asuw9ryEQSpump (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001A6AF21E510>, 'Connection to api.dexscreener.com timed out. (connect timeout=None)'))
# Processing token batches:  50%|█████     | 1/2 [00:43<00:43, 43.11s/batch]2025-02-05 18:07:11,617 - INFO - fetch_token_details: Processing batch 2 with tokens: ['GekTNfm84QfyP2GdAHZ5AgACBRd69aNmgA5FDhZupump', 'EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm', 'JUPyiwrYJFskUPiHa7hkeR8VUtAeFoSYbKedZNsDvCN', 'KENJSUYLASHUMfHyy5o4Hp2FdNqZg1AsUPhfH2kYvEP', '76PsEyML7UV9uiBDWMdG3itRRuupDuRs6nNpjNBpump', 'jUpa2aDCzvdR9EF4fqDXmuyMUkonPTohphABLmRkRFj', '6p6xgHyF7AeE6TZkSmFsko444wqoP15icUSqi2jfGiPN', '83iBDw3ZpxqJ3pEzrbttr9fGA57tttehDAxoFyR1moon', 'ED5nyyWEzpPPiWimP8vYm7sD7TD3LAt3Q3gRTWHzPJBY', '9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump', 'Grass7B4RdKfBCjTKgSqnXkqjwiGvQyFbuSCUJr3XXjs', 'C7heQqfNzdMbUFQwcHkL9FvdwsFsDRBnfwZDDyWYCLTZ', 'A6YRaK4toMe2qZY7KLNCugXBrsjCG4fAjAR8uZUBeUek', 'h5NciPdMZ5QCB5BYETJMYBMpVx9ZuitR6HcVjyBhood', 'HZNnmhAY6xfq2iKRyBTEvTVeoTYJzpkK8mfnfG8Ppump', '3BgwJ8b7b9hHX4sgfZ2KJhv9496CoVfsMK2YePevsBRw', 'FSTRgYfDaudjDwFg5A9LQpDMq5vxqhskHq4rkjUMwERE', '5jfBtU75jk4q8xYPtnuR9GZx5YMsTQR1YyS5GuPcpump', 'CZBYBV2e1x1ZuZ2qkwU5mPNVLFKfVvjSssSNHzSepump', '8tSeXYSXzFvaDX1nbWrEFFaFuPHuWqpzksKYxQPvpump', 'J7tYmq2JnQPvxyhcXpCDrvJnc9R5ts8rv7tgVHDPsw7U', 'FLJYGHpCCcfYUdzhcfHSeSd2peb5SMajNWaCsRnhpump', 'M3M3pSFptfpZYnWNUgAbyWzKKgPo5d1eWmX6tbiSF2K', 'mSoLzYCxHdYgdzU16g5QSh3i5K3z3KZK7ytfqcJm7So', '6ZHaDajZnN9tu62eGD1VVGMKqkEix3GaES6fEXMsPdnd', '4FfTcjSySNCK5FMncfPYMFyp4QpFR4GERDKnfECr7ntg', '7D1iYWfhw2cr9yBZBFE6nZaaSUvXHqG5FizFFEZwpump', '3N2ETvNpPNAxhcaXgkhKoY1yDnQfs41Wnxsx5qNJpump', '5YqckGEkWHJmp9LW5aUF2uJrdUbMJaHcYnGjA8M7Ebw8']
# 2025-02-05 18:07:53,692 - ERROR - fetch_token_details: Error fetching batch ['GekTNfm84QfyP2GdAHZ5AgACBRd69aNmgA5FDhZupump', 'EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm', 'JUPyiwrYJFskUPiHa7hkeR8VUtAeFoSYbKedZNsDvCN', 'KENJSUYLASHUMfHyy5o4Hp2FdNqZg1AsUPhfH2kYvEP', '76PsEyML7UV9uiBDWMdG3itRRuupDuRs6nNpjNBpump', 'jUpa2aDCzvdR9EF4fqDXmuyMUkonPTohphABLmRkRFj', '6p6xgHyF7AeE6TZkSmFsko444wqoP15icUSqi2jfGiPN', '83iBDw3ZpxqJ3pEzrbttr9fGA57tttehDAxoFyR1moon', 'ED5nyyWEzpPPiWimP8vYm7sD7TD3LAt3Q3gRTWHzPJBY', '9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump', 'Grass7B4RdKfBCjTKgSqnXkqjwiGvQyFbuSCUJr3XXjs', 'C7heQqfNzdMbUFQwcHkL9FvdwsFsDRBnfwZDDyWYCLTZ', 'A6YRaK4toMe2qZY7KLNCugXBrsjCG4fAjAR8uZUBeUek', 'h5NciPdMZ5QCB5BYETJMYBMpVx9ZuitR6HcVjyBhood', 'HZNnmhAY6xfq2iKRyBTEvTVeoTYJzpkK8mfnfG8Ppump', '3BgwJ8b7b9hHX4sgfZ2KJhv9496CoVfsMK2YePevsBRw', 'FSTRgYfDaudjDwFg5A9LQpDMq5vxqhskHq4rkjUMwERE', '5jfBtU75jk4q8xYPtnuR9GZx5YMsTQR1YyS5GuPcpump', 'CZBYBV2e1x1ZuZ2qkwU5mPNVLFKfVvjSssSNHzSepump', '8tSeXYSXzFvaDX1nbWrEFFaFuPHuWqpzksKYxQPvpump', 'J7tYmq2JnQPvxyhcXpCDrvJnc9R5ts8rv7tgVHDPsw7U', 'FLJYGHpCCcfYUdzhcfHSeSd2peb5SMajNWaCsRnhpump', 'M3M3pSFptfpZYnWNUgAbyWzKKgPo5d1eWmX6tbiSF2K', 'mSoLzYCxHdYgdzU16g5QSh3i5K3z3KZK7ytfqcJm7So', '6ZHaDajZnN9tu62eGD1VVGMKqkEix3GaES6fEXMsPdnd', '4FfTcjSySNCK5FMncfPYMFyp4QpFR4GERDKnfECr7ntg', '7D1iYWfhw2cr9yBZBFE6nZaaSUvXHqG5FizFFEZwpump', '3N2ETvNpPNAxhcaXgkhKoY1yDnQfs41Wnxsx5qNJpump', '5YqckGEkWHJmp9LW5aUF2uJrdUbMJaHcYnGjA8M7Ebw8']: HTTPSConnectionPool(host='api.dexscreener.com', port=443): Max retries exceeded with url: /tokens/v1/solana/GekTNfm84QfyP2GdAHZ5AgACBRd69aNmgA5FDhZupump,EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm,JUPyiwrYJFskUPiHa7hkeR8VUtAeFoSYbKedZNsDvCN,KENJSUYLASHUMfHyy5o4Hp2FdNqZg1AsUPhfH2kYvEP,76PsEyML7UV9uiBDWMdG3itRRuupDuRs6nNpjNBpump,jUpa2aDCzvdR9EF4fqDXmuyMUkonPTohphABLmRkRFj,6p6xgHyF7AeE6TZkSmFsko444wqoP15icUSqi2jfGiPN,83iBDw3ZpxqJ3pEzrbttr9fGA57tttehDAxoFyR1moon,ED5nyyWEzpPPiWimP8vYm7sD7TD3LAt3Q3gRTWHzPJBY,9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump,Grass7B4RdKfBCjTKgSqnXkqjwiGvQyFbuSCUJr3XXjs,C7heQqfNzdMbUFQwcHkL9FvdwsFsDRBnfwZDDyWYCLTZ,A6YRaK4toMe2qZY7KLNCugXBrsjCG4fAjAR8uZUBeUek,h5NciPdMZ5QCB5BYETJMYBMpVx9ZuitR6HcVjyBhood,HZNnmhAY6xfq2iKRyBTEvTVeoTYJzpkK8mfnfG8Ppump,3BgwJ8b7b9hHX4sgfZ2KJhv9496CoVfsMK2YePevsBRw,FSTRgYfDaudjDwFg5A9LQpDMq5vxqhskHq4rkjUMwERE,5jfBtU75jk4q8xYPtnuR9GZx5YMsTQR1YyS5GuPcpump,CZBYBV2e1x1ZuZ2qkwU5mPNVLFKfVvjSssSNHzSepump,8tSeXYSXzFvaDX1nbWrEFFaFuPHuWqpzksKYxQPvpump,J7tYmq2JnQPvxyhcXpCDrvJnc9R5ts8rv7tgVHDPsw7U,FLJYGHpCCcfYUdzhcfHSeSd2peb5SMajNWaCsRnhpump,M3M3pSFptfpZYnWNUgAbyWzKKgPo5d1eWmX6tbiSF2K,mSoLzYCxHdYgdzU16g5QSh3i5K3z3KZK7ytfqcJm7So,6ZHaDajZnN9tu62eGD1VVGMKqkEix3GaES6fEXMsPdnd,4FfTcjSySNCK5FMncfPYMFyp4QpFR4GERDKnfECr7ntg,7D1iYWfhw2cr9yBZBFE6nZaaSUvXHqG5FizFFEZwpump,3N2ETvNpPNAxhcaXgkhKoY1yDnQfs41Wnxsx5qNJpump,5YqckGEkWHJmp9LW5aUF2uJrdUbMJaHcYnGjA8M7Ebw8 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001A6AEDF6DE0>, 'Connection to api.dexscreener.com timed out. (connect timeout=None)'))
# Processing token batches: 100%|██████████| 2/2 [01:26<00:00, 43.09s/batch]
# 2025-02-05 18:07:54,696 - INFO - fetch_token_details: Finished fetching all token details.
# 2025-02-05 18:07:54,698 - INFO - main: Processing transactions to fetch historical prices...
# Processing transactions:   0%|          | 0/80 [00:00<?, ?it/s]2025-02-05 18:07:54,702 - INFO - fetch_historical_price: Requesting price for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1736217418'.
# 2025-02-05 18:07:55,146 - INFO - fetch_historical_price: Received price 0.9999336 for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1736217418'.
# 2025-02-05 18:07:55,148 - INFO - fetch_historical_price: Requesting price for token 'jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v' at timestamp '1736217418'.
# 2025-02-05 18:07:55,330 - INFO - fetch_historical_price: Received price 232.51661368959117 for token 'jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v' at timestamp '1736217418'.
# Processing transactions:   1%|▏         | 1/80 [00:00<01:05,  1.20it/s]2025-02-05 18:07:55,534 - INFO - fetch_historical_price: Requesting price for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738575381'.
# 2025-02-05 18:07:55,693 - INFO - fetch_historical_price: Received price 1.00001387 for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738575381'.
# 2025-02-05 18:07:55,694 - INFO - fetch_historical_price: Requesting price for token '9bNUjxEvygayUE2ZRN5zh9Hhjh6cN6GPK4zoHzXXpump' at timestamp '1738575381'.
# 2025-02-05 18:07:55,829 - INFO - fetch_historical_price: Received price 0.003629560429782409 for token '9bNUjxEvygayUE2ZRN5zh9Hhjh6cN6GPK4zoHzXXpump' at timestamp '1738575381'.
# Processing transactions:   2%|▎         | 2/80 [00:01<00:49,  1.57it/s]2025-02-05 18:07:56,033 - INFO - fetch_historical_price: Requesting price for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738599617'.
# 2025-02-05 18:07:56,164 - INFO - fetch_historical_price: Received price 1.0000999 for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738599617'.
# 2025-02-05 18:07:56,165 - INFO - fetch_historical_price: Requesting price for token '2zMMhcVQEXDtdE6vsFS7S7D5oUodfJHE8vd1gnBouauv' at timestamp '1738599617'.
# 2025-02-05 18:07:56,309 - INFO - fetch_historical_price: Received price 0.013409125066858858 for token '2zMMhcVQEXDtdE6vsFS7S7D5oUodfJHE8vd1gnBouauv' at timestamp '1738599617'.
# Processing transactions:   4%|▍         | 3/80 [00:01<00:43,  1.77it/s]2025-02-05 18:07:56,512 - INFO - fetch_historical_price: Requesting price for token '3ufbSaVQSGeoCbgVp45YYYWKygbYFXAUZ7n7AP4CUWg6' at timestamp '1738691147'.
# 2025-02-05 18:07:56,640 - INFO - fetch_historical_price: Received price 0.00028754967546114926 for token '3ufbSaVQSGeoCbgVp45YYYWKygbYFXAUZ7n7AP4CUWg6' at timestamp '1738691147'.
# 2025-02-05 18:07:56,642 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738691147'.
# 2025-02-05 18:07:56,783 - INFO - fetch_historical_price: Received price 213.45620046891216 for token 'So11111111111111111111111111111111111111112' at timestamp '1738691147'.
# Processing transactions:   5%|▌         | 4/80 [00:02<00:40,  1.89it/s]2025-02-05 18:07:56,987 - INFO - fetch_historical_price: Requesting price for token '63LfDmNb3MQ8mw9MtZ2To9bEA2M71kZUUGq5tiJxcqj9' at timestamp '1738707388'.
# 2025-02-05 18:07:57,125 - INFO - fetch_historical_price: Received price 0.042127045096973174 for token '63LfDmNb3MQ8mw9MtZ2To9bEA2M71kZUUGq5tiJxcqj9' at timestamp '1738707388'.
# 2025-02-05 18:07:57,126 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738707388'.
# 2025-02-05 18:07:57,250 - INFO - fetch_historical_price: Received price 203.5344259098795 for token 'So11111111111111111111111111111111111111112' at timestamp '1738707388'.
# Processing transactions:   6%|▋         | 5/80 [00:02<00:37,  1.98it/s]2025-02-05 18:07:57,453 - INFO - fetch_historical_price: Requesting price for token 'CNyMaRR4krm1yAxfCvPXevNMArZZZk7sRqKwX68uCeJk' at timestamp '1738710454'.
# 2025-02-05 18:07:57,594 - INFO - fetch_historical_price: Received price 0.03309038791758671 for token 'CNyMaRR4krm1yAxfCvPXevNMArZZZk7sRqKwX68uCeJk' at timestamp '1738710454'.
# 2025-02-05 18:07:57,595 - INFO - fetch_historical_price: Requesting price for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738710454'.
# 2025-02-05 18:07:57,728 - INFO - fetch_historical_price: Received price 1.00002925 for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738710454'.
# Processing transactions:   8%|▊         | 6/80 [00:03<00:36,  2.01it/s]2025-02-05 18:07:57,934 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738726591'.
# 2025-02-05 18:07:58,071 - INFO - fetch_historical_price: Received price 208.04722870461313 for token 'So11111111111111111111111111111111111111112' at timestamp '1738726591'.
# 2025-02-05 18:07:58,073 - INFO - fetch_historical_price: Requesting price for token 'Bv8q9VYwyU3QCiHWMdko7pZx8BW1zERhvANNN8P7uvnH' at timestamp '1738726591'.
# 2025-02-05 18:07:58,216 - INFO - fetch_historical_price: Received price 1.685627485380398e-05 for token 'Bv8q9VYwyU3QCiHWMdko7pZx8BW1zERhvANNN8P7uvnH' at timestamp '1738726591'.
# Processing transactions:   9%|▉         | 7/80 [00:03<00:36,  2.02it/s]2025-02-05 18:07:58,419 - INFO - fetch_historical_price: Requesting price for token 'Bv8q9VYwyU3QCiHWMdko7pZx8BW1zERhvANNN8P7uvnH' at timestamp '1738726531'.
# 2025-02-05 18:07:58,555 - INFO - fetch_historical_price: Received price 1.706562422609763e-05 for token 'Bv8q9VYwyU3QCiHWMdko7pZx8BW1zERhvANNN8P7uvnH' at timestamp '1738726531'.
# 2025-02-05 18:07:58,556 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738726531'.
# 2025-02-05 18:07:58,691 - INFO - fetch_historical_price: Received price 208.08358480979433 for token 'So11111111111111111111111111111111111111112' at timestamp '1738726531'.
# Processing transactions:  10%|█         | 8/80 [00:04<00:35,  2.05it/s]2025-02-05 18:07:58,894 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738729818'.
# 2025-02-05 18:07:59,031 - INFO - fetch_historical_price: Received price 205.68299587489787 for token 'So11111111111111111111111111111111111111112' at timestamp '1738729818'.
# 2025-02-05 18:07:59,032 - INFO - fetch_historical_price: Requesting price for token '2yd2Suus3YY4Sa7LHhn1PSHkjXj3XKrars4cCog2tGU8' at timestamp '1738729818'.
# 2025-02-05 18:07:59,161 - INFO - fetch_historical_price: Received price 0.011619014720768046 for token '2yd2Suus3YY4Sa7LHhn1PSHkjXj3XKrars4cCog2tGU8' at timestamp '1738729818'.
# Processing transactions:  11%|█▏        | 9/80 [00:04<00:34,  2.07it/s]2025-02-05 18:07:59,364 - INFO - fetch_historical_price: Requesting price for token '2yd2Suus3YY4Sa7LHhn1PSHkjXj3XKrars4cCog2tGU8' at timestamp '1738731481'.
# 2025-02-05 18:07:59,485 - INFO - fetch_historical_price: Received price 0.011911278643869351 for token '2yd2Suus3YY4Sa7LHhn1PSHkjXj3XKrars4cCog2tGU8' at timestamp '1738731481'.
# 2025-02-05 18:07:59,486 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738731481'.
# 2025-02-05 18:07:59,663 - INFO - fetch_historical_price: Received price 204.85608201225645 for token 'So11111111111111111111111111111111111111112' at timestamp '1738731481'.
# Processing transactions:  12%|█▎        | 10/80 [00:05<00:34,  2.05it/s]2025-02-05 18:07:59,867 - INFO - fetch_historical_price: Requesting price for token '2z1p8xCEjRzpBHjXWrx4tJnz7BFL6z7NnvbCxH7bpump' at timestamp '1738733158'.
# 2025-02-05 18:08:00,071 - INFO - fetch_historical_price: Received price 0.016545183137956148 for token '2z1p8xCEjRzpBHjXWrx4tJnz7BFL6z7NnvbCxH7bpump' at timestamp '1738733158'.
# 2025-02-05 18:08:00,073 - INFO - fetch_historical_price: Requesting price for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738733158'.
# 2025-02-05 18:08:00,216 - INFO - fetch_historical_price: Received price 0.99998064 for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738733158'.
# Processing transactions:  14%|█▍        | 11/80 [00:05<00:35,  1.97it/s]2025-02-05 18:08:00,420 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738737118'.
# 2025-02-05 18:08:00,600 - INFO - fetch_historical_price: Received price 205.20716056046152 for token 'So11111111111111111111111111111111111111112' at timestamp '1738737118'.
# 2025-02-05 18:08:00,601 - INFO - fetch_historical_price: Requesting price for token 'C8cNX2D1y3jqKpMFkQhP1gGbfvTEdeckZXLBKSN5z5KF' at timestamp '1738737118'.
# 2025-02-05 18:08:00,739 - INFO - fetch_historical_price: Received price 0.0005559668616640712 for token 'C8cNX2D1y3jqKpMFkQhP1gGbfvTEdeckZXLBKSN5z5KF' at timestamp '1738737118'.
# Processing transactions:  15%|█▌        | 12/80 [00:06<00:34,  1.95it/s]2025-02-05 18:08:00,942 - INFO - fetch_historical_price: Requesting price for token 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB' at timestamp '1738738331'.
# 2025-02-05 18:08:01,081 - INFO - fetch_historical_price: Received price 1.00033 for token 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB' at timestamp '1738738331'.
# 2025-02-05 18:08:01,082 - INFO - fetch_historical_price: Requesting price for token '7XJiwLDrjzxDYdZipnJXzpr1iDTmK55XixSFAa7JgNEL' at timestamp '1738738331'.
# 2025-02-05 18:08:01,223 - INFO - fetch_historical_price: Received price 0.09774353622090726 for token '7XJiwLDrjzxDYdZipnJXzpr1iDTmK55XixSFAa7JgNEL' at timestamp '1738738331'.
# Processing transactions:  16%|█▋        | 13/80 [00:06<00:33,  1.98it/s]2025-02-05 18:08:01,427 - INFO - fetch_historical_price: Requesting price for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738760665'.
# 2025-02-05 18:08:01,573 - INFO - fetch_historical_price: Received price 0.99998683 for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738760665'.
# 2025-02-05 18:08:01,575 - INFO - fetch_historical_price: Requesting price for token '2Vnei1LAmrBpbL8fNCiCpaYcQTCSodiE51wab6qaQJAq' at timestamp '1738760665'.
# 2025-02-05 18:08:01,720 - INFO - fetch_historical_price: Received price 0.009988689771635759 for token '2Vnei1LAmrBpbL8fNCiCpaYcQTCSodiE51wab6qaQJAq' at timestamp '1738760665'.
# Processing transactions:  18%|█▊        | 14/80 [00:07<00:33,  1.99it/s]2025-02-05 18:08:01,924 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738772993'.
# 2025-02-05 18:08:02,071 - INFO - fetch_historical_price: Received price 199.3895121057227 for token 'So11111111111111111111111111111111111111112' at timestamp '1738772993'.
# 2025-02-05 18:08:02,072 - INFO - fetch_historical_price: Requesting price for token 'A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump' at timestamp '1738772993'.
# 2025-02-05 18:08:02,204 - INFO - fetch_historical_price: Received price 0.08975408825401447 for token 'A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump' at timestamp '1738772993'.
# Processing transactions:  19%|█▉        | 15/80 [00:07<00:32,  2.02it/s]2025-02-05 18:08:02,406 - INFO - fetch_historical_price: Requesting price for token '4mbdysBik3jmzD7mt6FGPDsMxnYcxExSQRFjPucdpump' at timestamp '1738771622'.
# 2025-02-05 18:08:02,529 - INFO - fetch_historical_price: Received price 0.016654844985851545 for token '4mbdysBik3jmzD7mt6FGPDsMxnYcxExSQRFjPucdpump' at timestamp '1738771622'.
# 2025-02-05 18:08:02,530 - INFO - fetch_historical_price: Requesting price for token 'FasH397CeZLNYWkd3wWK9vrmjd1z93n3b59DssRXpump' at timestamp '1738771622'.
# 2025-02-05 18:08:02,672 - INFO - fetch_historical_price: Received price 0.0171066793814759 for token 'FasH397CeZLNYWkd3wWK9vrmjd1z93n3b59DssRXpump' at timestamp '1738771622'.
# Processing transactions:  20%|██        | 16/80 [00:08<00:31,  2.05it/s]2025-02-05 18:08:02,876 - INFO - fetch_historical_price: Requesting price for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738771878'.
# 2025-02-05 18:08:03,017 - INFO - fetch_historical_price: Received price 1.00000585 for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738771878'.
# 2025-02-05 18:08:03,018 - INFO - fetch_historical_price: Requesting price for token 'BCQRnuZEYw6z4AedaJRpDnQzpmqUgK8PPeLnqaNcpump' at timestamp '1738771878'.
# 2025-02-05 18:08:03,140 - INFO - fetch_historical_price: Received price 0.0003412985823794125 for token 'BCQRnuZEYw6z4AedaJRpDnQzpmqUgK8PPeLnqaNcpump' at timestamp '1738771878'.
# Processing transactions:  21%|██▏       | 17/80 [00:08<00:30,  2.08it/s]2025-02-05 18:08:03,342 - INFO - fetch_historical_price: Requesting price for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738772675'.
# 2025-02-05 18:08:03,532 - INFO - fetch_historical_price: Received price 0.99993706 for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738772675'.
# 2025-02-05 18:08:03,533 - INFO - fetch_historical_price: Requesting price for token '3NZ9JMVBmGAqocybic2c7LQCJScmgsAZ6vQqTDzcqmJh' at timestamp '1738772675'.
# 2025-02-05 18:08:03,654 - INFO - fetch_historical_price: Received price 97384.63357999673 for token '3NZ9JMVBmGAqocybic2c7LQCJScmgsAZ6vQqTDzcqmJh' at timestamp '1738772675'.
# Processing transactions:  22%|██▎       | 18/80 [00:09<00:30,  2.03it/s]2025-02-05 18:08:03,858 - INFO - fetch_historical_price: Requesting price for token 'A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump' at timestamp '1738772343'.
# 2025-02-05 18:08:04,006 - INFO - fetch_historical_price: Received price 0.08747607601181286 for token 'A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump' at timestamp '1738772343'.
# 2025-02-05 18:08:04,007 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738772343'.
# 2025-02-05 18:08:04,143 - INFO - fetch_historical_price: Received price 198.76583298930305 for token 'So11111111111111111111111111111111111111112' at timestamp '1738772343'.
# Processing transactions:  24%|██▍       | 19/80 [00:09<00:29,  2.04it/s]2025-02-05 18:08:04,346 - INFO - fetch_historical_price: Requesting price for token '9DHe3pycTuymFk4H4bbPoAJ4hQrr2kaLDF6J6aAKpump' at timestamp '1738771609'.
# 2025-02-05 18:08:04,472 - INFO - fetch_historical_price: Received price 0.03767659493533248 for token '9DHe3pycTuymFk4H4bbPoAJ4hQrr2kaLDF6J6aAKpump' at timestamp '1738771609'.
# 2025-02-05 18:08:04,473 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738771609'.
# 2025-02-05 18:08:04,596 - INFO - fetch_historical_price: Received price 200.7276611775699 for token 'So11111111111111111111111111111111111111112' at timestamp '1738771609'.
# Processing transactions:  25%|██▌       | 20/80 [00:10<00:28,  2.09it/s]2025-02-05 18:08:04,801 - INFO - fetch_historical_price: Requesting price for token 'DriFtupJYLTosbwoN8koMbEYSx54aFAVLddWsbksjwg7' at timestamp '1738772163'.
# 2025-02-05 18:08:04,957 - INFO - fetch_historical_price: Received price 0.7380721320711903 for token 'DriFtupJYLTosbwoN8koMbEYSx54aFAVLddWsbksjwg7' at timestamp '1738772163'.
# 2025-02-05 18:08:04,958 - INFO - fetch_historical_price: Requesting price for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738772163'.
# 2025-02-05 18:08:05,108 - INFO - fetch_historical_price: Received price 1.00000163 for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738772163'.
# Processing transactions:  26%|██▋       | 21/80 [00:10<00:28,  2.04it/s]2025-02-05 18:08:05,312 - INFO - fetch_historical_price: Requesting price for token '98mb39tPFKQJ4Bif8iVg9mYb9wsfPZgpgN1sxoVTpump' at timestamp '1738774394'.
# 2025-02-05 18:08:05,432 - INFO - fetch_historical_price: Received price 0.005232152376767053 for token '98mb39tPFKQJ4Bif8iVg9mYb9wsfPZgpgN1sxoVTpump' at timestamp '1738774394'.
# 2025-02-05 18:08:05,433 - INFO - fetch_historical_price: Requesting price for token 'J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn' at timestamp '1738774394'.
# 2025-02-05 18:08:05,613 - INFO - fetch_historical_price: Received price 236.2594529263246 for token 'J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn' at timestamp '1738774394'.
# Processing transactions:  28%|██▊       | 22/80 [00:11<00:28,  2.02it/s]2025-02-05 18:08:05,817 - INFO - fetch_historical_price: Requesting price for token 'eL5fUxj2J4CiQsmW85k5FG9DvuQjjUoBHoQBi2Kpump' at timestamp '1738771541'.
# 2025-02-05 18:08:05,968 - INFO - fetch_historical_price: Received price 0.08001278915265553 for token 'eL5fUxj2J4CiQsmW85k5FG9DvuQjjUoBHoQBi2Kpump' at timestamp '1738771541'.
# 2025-02-05 18:08:05,969 - INFO - fetch_historical_price: Requesting price for token 'FasH397CeZLNYWkd3wWK9vrmjd1z93n3b59DssRXpump' at timestamp '1738771541'.
# 2025-02-05 18:08:06,110 - INFO - fetch_historical_price: Received price 0.0174850915497334 for token 'FasH397CeZLNYWkd3wWK9vrmjd1z93n3b59DssRXpump' at timestamp '1738771541'.
# Processing transactions:  29%|██▉       | 23/80 [00:11<00:28,  2.02it/s]2025-02-05 18:08:06,314 - INFO - fetch_historical_price: Requesting price for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738772614'.
# 2025-02-05 18:08:06,462 - INFO - fetch_historical_price: Received price 0.99998151 for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738772614'.
# 2025-02-05 18:08:06,464 - INFO - fetch_historical_price: Requesting price for token 'A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump' at timestamp '1738772614'.
# 2025-02-05 18:08:06,610 - INFO - fetch_historical_price: Received price 0.08611795376851689 for token 'A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump' at timestamp '1738772614'.
# Processing transactions:  30%|███       | 24/80 [00:12<00:27,  2.02it/s]2025-02-05 18:08:06,813 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738772167'.
# 2025-02-05 18:08:06,932 - INFO - fetch_historical_price: Received price 199.99995318139895 for token 'So11111111111111111111111111111111111111112' at timestamp '1738772167'.
# 2025-02-05 18:08:06,934 - INFO - fetch_historical_price: Requesting price for token 'CuxbDwNU9q8uLVU8E4drMPzrXQ3ipzH3Fai7Bfoepump' at timestamp '1738772167'.
# 2025-02-05 18:08:07,064 - INFO - fetch_historical_price: Received price 8.532031354016838e-06 for token 'CuxbDwNU9q8uLVU8E4drMPzrXQ3ipzH3Fai7Bfoepump' at timestamp '1738772167'.
# Processing transactions:  31%|███▏      | 25/80 [00:12<00:26,  2.07it/s]2025-02-05 18:08:07,267 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738772746'.
# 2025-02-05 18:08:07,400 - INFO - fetch_historical_price: Received price 198.8442014562208 for token 'So11111111111111111111111111111111111111112' at timestamp '1738772746'.
# 2025-02-05 18:08:07,401 - INFO - fetch_historical_price: Requesting price for token 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB' at timestamp '1738772746'.
# 2025-02-05 18:08:07,523 - INFO - fetch_historical_price: Received price 1.00019362 for token 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB' at timestamp '1738772746'.
# Processing transactions:  32%|███▎      | 26/80 [00:13<00:25,  2.10it/s]2025-02-05 18:08:07,727 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738770907'.
# 2025-02-05 18:08:07,852 - INFO - fetch_historical_price: Received price 202.18002460504525 for token 'So11111111111111111111111111111111111111112' at timestamp '1738770907'.
# 2025-02-05 18:08:07,853 - INFO - fetch_historical_price: Requesting price for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738770907'.
# 2025-02-05 18:08:07,973 - INFO - fetch_historical_price: Received price 0.99998718 for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738770907'.
# Processing transactions:  34%|███▍      | 27/80 [00:13<00:24,  2.14it/s]2025-02-05 18:08:08,176 - INFO - fetch_historical_price: Requesting price for token '9McvH6w97oewLmPxqQEoHUAv3u5iYMyQ9AeZZhguYf1T' at timestamp '1738774347'.
# 2025-02-05 18:08:08,334 - INFO - fetch_historical_price: Received price 11.48076417676873 for token '9McvH6w97oewLmPxqQEoHUAv3u5iYMyQ9AeZZhguYf1T' at timestamp '1738774347'.
# 2025-02-05 18:08:08,335 - INFO - fetch_historical_price: Requesting price for token 'J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn' at timestamp '1738774347'.
# 2025-02-05 18:08:08,481 - INFO - fetch_historical_price: Received price 236.61675076730023 for token 'J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn' at timestamp '1738774347'.
# Processing transactions:  35%|███▌      | 28/80 [00:13<00:24,  2.08it/s]2025-02-05 18:08:08,684 - INFO - fetch_historical_price: Requesting price for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738774309'.
# 2025-02-05 18:08:08,810 - INFO - fetch_historical_price: Received price 0.99996518 for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738774309'.
# 2025-02-05 18:08:08,812 - INFO - fetch_historical_price: Requesting price for token 'J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn' at timestamp '1738774309'.
# 2025-02-05 18:08:08,935 - INFO - fetch_historical_price: Received price 236.50924137269217 for token 'J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn' at timestamp '1738774309'.
# Processing transactions:  36%|███▋      | 29/80 [00:14<00:24,  2.12it/s]2025-02-05 18:08:09,138 - INFO - fetch_historical_price: Requesting price for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738771174'.
# 2025-02-05 18:08:09,269 - INFO - fetch_historical_price: Received price 1.00003228 for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738771174'.
# 2025-02-05 18:08:09,270 - INFO - fetch_historical_price: Requesting price for token 'F9TgEJLLRUKDRF16HgjUCdJfJ5BK6ucyiW8uJxVPpump' at timestamp '1738771174'.
# 2025-02-05 18:08:09,398 - INFO - fetch_historical_price: Received price 0.008357232816310092 for token 'F9TgEJLLRUKDRF16HgjUCdJfJ5BK6ucyiW8uJxVPpump' at timestamp '1738771174'.
# Processing transactions:  38%|███▊      | 30/80 [00:14<00:23,  2.13it/s]2025-02-05 18:08:09,601 - INFO - fetch_historical_price: Requesting price for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738771537'.
# 2025-02-05 18:08:09,744 - INFO - fetch_historical_price: Received price 0.999985 for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738771537'.
# 2025-02-05 18:08:09,745 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738771537'.
# 2025-02-05 18:08:09,868 - INFO - fetch_historical_price: Received price 200.68450162602016 for token 'So11111111111111111111111111111111111111112' at timestamp '1738771537'.
# Processing transactions:  39%|███▉      | 31/80 [00:15<00:23,  2.13it/s]2025-02-05 18:08:10,071 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738772048'.
# 2025-02-05 18:08:10,218 - INFO - fetch_historical_price: Received price 200.05303800072969 for token 'So11111111111111111111111111111111111111112' at timestamp '1738772048'.
# 2025-02-05 18:08:10,219 - INFO - fetch_historical_price: Requesting price for token 'G25rCkrGqTf1hL5U8aq5niJDHccuBFLZSAbQNaCNpump' at timestamp '1738772048'.
# 2025-02-05 18:08:10,404 - INFO - fetch_historical_price: Received price 9.626834065443452e-05 for token 'G25rCkrGqTf1hL5U8aq5niJDHccuBFLZSAbQNaCNpump' at timestamp '1738772048'.
# Processing transactions:  40%|████      | 32/80 [00:15<00:23,  2.04it/s]2025-02-05 18:08:10,607 - INFO - fetch_historical_price: Requesting price for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738772588'.
# 2025-02-05 18:08:10,768 - INFO - fetch_historical_price: Received price 0.99997147 for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738772588'.
# 2025-02-05 18:08:10,769 - INFO - fetch_historical_price: Requesting price for token 'ELdqGtj2MhejZzudGfz7b798si2Av5Asuw9ryEQSpump' at timestamp '1738772588'.
# 2025-02-05 18:08:10,909 - INFO - fetch_historical_price: Received price 0.0025595695129648635 for token 'ELdqGtj2MhejZzudGfz7b798si2Av5Asuw9ryEQSpump' at timestamp '1738772588'.
# Processing transactions:  41%|████▏     | 33/80 [00:16<00:23,  2.02it/s]2025-02-05 18:08:11,112 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738772587'.
# 2025-02-05 18:08:11,243 - INFO - fetch_historical_price: Received price 199.28863018785046 for token 'So11111111111111111111111111111111111111112' at timestamp '1738772587'.
# 2025-02-05 18:08:11,244 - INFO - fetch_historical_price: Requesting price for token 'FasH397CeZLNYWkd3wWK9vrmjd1z93n3b59DssRXpump' at timestamp '1738772587'.
# 2025-02-05 18:08:11,380 - INFO - fetch_historical_price: Received price 0.019170578423581316 for token 'FasH397CeZLNYWkd3wWK9vrmjd1z93n3b59DssRXpump' at timestamp '1738772587'.
# Processing transactions:  42%|████▎     | 34/80 [00:16<00:22,  2.05it/s]2025-02-05 18:08:11,583 - INFO - fetch_historical_price: Requesting price for token 'GekTNfm84QfyP2GdAHZ5AgACBRd69aNmgA5FDhZupump' at timestamp '1738774486'.
# 2025-02-05 18:08:11,706 - INFO - fetch_historical_price: Received price 0.04020980643270987 for token 'GekTNfm84QfyP2GdAHZ5AgACBRd69aNmgA5FDhZupump' at timestamp '1738774486'.
# 2025-02-05 18:08:11,707 - INFO - fetch_historical_price: Requesting price for token 'J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn' at timestamp '1738774486'.
# 2025-02-05 18:08:11,849 - INFO - fetch_historical_price: Received price 235.85719071222445 for token 'J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn' at timestamp '1738774486'.
# Processing transactions:  44%|████▍     | 35/80 [00:17<00:21,  2.08it/s]2025-02-05 18:08:12,053 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738771932'.
# 2025-02-05 18:08:12,181 - INFO - fetch_historical_price: Received price 200.64576115225762 for token 'So11111111111111111111111111111111111111112' at timestamp '1738771932'.
# 2025-02-05 18:08:12,183 - INFO - fetch_historical_price: Requesting price for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738771932'.
# 2025-02-05 18:08:12,323 - INFO - fetch_historical_price: Received price 0.99999991 for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738771932'.
# Processing transactions:  45%|████▌     | 36/80 [00:17<00:21,  2.09it/s]2025-02-05 18:08:12,526 - INFO - fetch_historical_price: Requesting price for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738772590'.
# 2025-02-05 18:08:12,697 - INFO - fetch_historical_price: Received price 0.99999991 for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738772590'.
# 2025-02-05 18:08:12,699 - INFO - fetch_historical_price: Requesting price for token 'EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm' at timestamp '1738772590'.
# 2025-02-05 18:08:12,926 - INFO - fetch_historical_price: Received price 0.7988547655785055 for token 'EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm' at timestamp '1738772590'.
# Processing transactions:  46%|████▋     | 37/80 [00:18<00:22,  1.93it/s]2025-02-05 18:08:13,130 - INFO - fetch_historical_price: Requesting price for token 'JUPyiwrYJFskUPiHa7hkeR8VUtAeFoSYbKedZNsDvCN' at timestamp '1738770756'.
# 2025-02-05 18:08:13,251 - INFO - fetch_historical_price: Received price 0.9220331808108349 for token 'JUPyiwrYJFskUPiHa7hkeR8VUtAeFoSYbKedZNsDvCN' at timestamp '1738770756'.
# 2025-02-05 18:08:13,252 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738770756'.
# 2025-02-05 18:08:13,392 - INFO - fetch_historical_price: Received price 201.78379085168493 for token 'So11111111111111111111111111111111111111112' at timestamp '1738770756'.
# Processing transactions:  48%|████▊     | 38/80 [00:18<00:21,  1.99it/s]2025-02-05 18:08:13,596 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738773623'.
# 2025-02-05 18:08:13,741 - INFO - fetch_historical_price: Received price 198.8497512127617 for token 'So11111111111111111111111111111111111111112' at timestamp '1738773623'.
# 2025-02-05 18:08:13,742 - INFO - fetch_historical_price: Requesting price for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738773623'.
# 2025-02-05 18:08:13,887 - INFO - fetch_historical_price: Received price 0.99998 for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738773623'.
# Processing transactions:  49%|████▉     | 39/80 [00:19<00:20,  2.00it/s]2025-02-05 18:08:14,090 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738772085'.
# 2025-02-05 18:08:14,209 - INFO - fetch_historical_price: Received price 200.12701818609005 for token 'So11111111111111111111111111111111111111112' at timestamp '1738772085'.
# 2025-02-05 18:08:14,210 - INFO - fetch_historical_price: Requesting price for token 'KENJSUYLASHUMfHyy5o4Hp2FdNqZg1AsUPhfH2kYvEP' at timestamp '1738772085'.
# 2025-02-05 18:08:14,344 - INFO - fetch_historical_price: Received price 0.18392049929368848 for token 'KENJSUYLASHUMfHyy5o4Hp2FdNqZg1AsUPhfH2kYvEP' at timestamp '1738772085'.
# Processing transactions:  50%|█████     | 40/80 [00:19<00:19,  2.05it/s]2025-02-05 18:08:14,548 - INFO - fetch_historical_price: Requesting price for token '76PsEyML7UV9uiBDWMdG3itRRuupDuRs6nNpjNBpump' at timestamp '1738774371'.
# 2025-02-05 18:08:14,690 - INFO - fetch_historical_price: Received price 0.005767592837515453 for token '76PsEyML7UV9uiBDWMdG3itRRuupDuRs6nNpjNBpump' at timestamp '1738774371'.
# 2025-02-05 18:08:14,691 - INFO - fetch_historical_price: Requesting price for token 'J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn' at timestamp '1738774371'.
# 2025-02-05 18:08:14,827 - INFO - fetch_historical_price: Received price 236.5043135395253 for token 'J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn' at timestamp '1738774371'.
# Processing transactions:  51%|█████▏    | 41/80 [00:20<00:18,  2.06it/s]2025-02-05 18:08:15,031 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738773719'.
# 2025-02-05 18:08:15,158 - INFO - fetch_historical_price: Received price 199.43700729244466 for token 'So11111111111111111111111111111111111111112' at timestamp '1738773719'.
# 2025-02-05 18:08:15,159 - INFO - fetch_historical_price: Requesting price for token 'jUpa2aDCzvdR9EF4fqDXmuyMUkonPTohphABLmRkRFj' at timestamp '1738773719'.
# 2025-02-05 18:08:15,280 - INFO - fetch_historical_price: Received price 0.021045184269402474 for token 'jUpa2aDCzvdR9EF4fqDXmuyMUkonPTohphABLmRkRFj' at timestamp '1738773719'.
# Processing transactions:  52%|█████▎    | 42/80 [00:20<00:18,  2.10it/s]2025-02-05 18:08:15,483 - INFO - fetch_historical_price: Requesting price for token '4mbdysBik3jmzD7mt6FGPDsMxnYcxExSQRFjPucdpump' at timestamp '1738770464'.
# 2025-02-05 18:08:15,628 - INFO - fetch_historical_price: Received price 0.01687197862535912 for token '4mbdysBik3jmzD7mt6FGPDsMxnYcxExSQRFjPucdpump' at timestamp '1738770464'.
# 2025-02-05 18:08:15,629 - INFO - fetch_historical_price: Requesting price for token 'FasH397CeZLNYWkd3wWK9vrmjd1z93n3b59DssRXpump' at timestamp '1738770464'.
# 2025-02-05 18:08:15,757 - INFO - fetch_historical_price: Received price 0.013869578157939915 for token 'FasH397CeZLNYWkd3wWK9vrmjd1z93n3b59DssRXpump' at timestamp '1738770464'.
# Processing transactions:  54%|█████▍    | 43/80 [00:21<00:17,  2.10it/s]2025-02-05 18:08:15,960 - INFO - fetch_historical_price: Requesting price for token 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB' at timestamp '1738773211'.
# 2025-02-05 18:08:16,106 - INFO - fetch_historical_price: Received price 1.00019082 for token 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB' at timestamp '1738773211'.
# 2025-02-05 18:08:16,107 - INFO - fetch_historical_price: Requesting price for token '6p6xgHyF7AeE6TZkSmFsko444wqoP15icUSqi2jfGiPN' at timestamp '1738773211'.
# 2025-02-05 18:08:16,237 - INFO - fetch_historical_price: Received price 19.01757955266381 for token '6p6xgHyF7AeE6TZkSmFsko444wqoP15icUSqi2jfGiPN' at timestamp '1738773211'.
# Processing transactions:  55%|█████▌    | 44/80 [00:21<00:17,  2.09it/s]2025-02-05 18:08:16,441 - INFO - fetch_historical_price: Requesting price for token '4mbdysBik3jmzD7mt6FGPDsMxnYcxExSQRFjPucdpump' at timestamp '1738771594'.
# 2025-02-05 18:08:16,572 - INFO - fetch_historical_price: Received price 0.01675617305812848 for token '4mbdysBik3jmzD7mt6FGPDsMxnYcxExSQRFjPucdpump' at timestamp '1738771594'.
# 2025-02-05 18:08:16,574 - INFO - fetch_historical_price: Requesting price for token 'FasH397CeZLNYWkd3wWK9vrmjd1z93n3b59DssRXpump' at timestamp '1738771594'.
# 2025-02-05 18:08:16,712 - INFO - fetch_historical_price: Received price 0.01775501390833353 for token 'FasH397CeZLNYWkd3wWK9vrmjd1z93n3b59DssRXpump' at timestamp '1738771594'.
# Processing transactions:  56%|█████▋    | 45/80 [00:22<00:16,  2.09it/s]2025-02-05 18:08:16,921 - INFO - fetch_historical_price: Requesting price for token '9DHe3pycTuymFk4H4bbPoAJ4hQrr2kaLDF6J6aAKpump' at timestamp '1738771954'.
# 2025-02-05 18:08:17,082 - INFO - fetch_historical_price: Received price 0.0370856788911512 for token '9DHe3pycTuymFk4H4bbPoAJ4hQrr2kaLDF6J6aAKpump' at timestamp '1738771954'.
# 2025-02-05 18:08:17,084 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738771954'.
# 2025-02-05 18:08:17,210 - INFO - fetch_historical_price: Received price 200.4160231325806 for token 'So11111111111111111111111111111111111111112' at timestamp '1738771954'.
# Processing transactions:  57%|█████▊    | 46/80 [00:22<00:16,  2.07it/s]2025-02-05 18:08:17,414 - INFO - fetch_historical_price: Requesting price for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738771454'.
# 2025-02-05 18:08:17,558 - INFO - fetch_historical_price: Received price 0.99999551 for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738771454'.
# 2025-02-05 18:08:17,559 - INFO - fetch_historical_price: Requesting price for token '83iBDw3ZpxqJ3pEzrbttr9fGA57tttehDAxoFyR1moon' at timestamp '1738771454'.
# 2025-02-05 18:08:17,682 - INFO - fetch_historical_price: Received price 0.04281955473415874 for token '83iBDw3ZpxqJ3pEzrbttr9fGA57tttehDAxoFyR1moon' at timestamp '1738771454'.
# Processing transactions:  59%|█████▉    | 47/80 [00:23<00:15,  2.09it/s]2025-02-05 18:08:17,885 - INFO - fetch_historical_price: Requesting price for token 'ED5nyyWEzpPPiWimP8vYm7sD7TD3LAt3Q3gRTWHzPJBY' at timestamp '1738772174'.
# 2025-02-05 18:08:18,120 - INFO - fetch_historical_price: Received price 0.07460029438239371 for token 'ED5nyyWEzpPPiWimP8vYm7sD7TD3LAt3Q3gRTWHzPJBY' at timestamp '1738772174'.
# 2025-02-05 18:08:18,122 - INFO - fetch_historical_price: Requesting price for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738772174'.
# 2025-02-05 18:08:18,261 - INFO - fetch_historical_price: Received price 0.99999884 for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738772174'.
# Processing transactions:  60%|██████    | 48/80 [00:23<00:16,  1.96it/s]2025-02-05 18:08:18,464 - INFO - fetch_historical_price: Requesting price for token '9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump' at timestamp '1738770453'.
# 2025-02-05 18:08:18,586 - INFO - fetch_historical_price: Received price 0.6472139989818341 for token '9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump' at timestamp '1738770453'.
# 2025-02-05 18:08:18,588 - INFO - fetch_historical_price: Requesting price for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738770453'.
# 2025-02-05 18:08:18,726 - INFO - fetch_historical_price: Received price 1.00001 for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738770453'.
# Processing transactions:  61%|██████▏   | 49/80 [00:24<00:15,  2.02it/s]2025-02-05 18:08:18,929 - INFO - fetch_historical_price: Requesting price for token 'Grass7B4RdKfBCjTKgSqnXkqjwiGvQyFbuSCUJr3XXjs' at timestamp '1738771891'.
# 2025-02-05 18:08:19,055 - INFO - fetch_historical_price: Received price 1.3906906833500678 for token 'Grass7B4RdKfBCjTKgSqnXkqjwiGvQyFbuSCUJr3XXjs' at timestamp '1738771891'.
# 2025-02-05 18:08:19,056 - INFO - fetch_historical_price: Requesting price for token 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB' at timestamp '1738771891'.
# 2025-02-05 18:08:19,219 - INFO - fetch_historical_price: Received price 1.0003467236979502 for token 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB' at timestamp '1738771891'.
# Processing transactions:  62%|██████▎   | 50/80 [00:24<00:14,  2.02it/s]2025-02-05 18:08:19,422 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738770211'.
# 2025-02-05 18:08:19,562 - INFO - fetch_historical_price: Received price 204.06539348601612 for token 'So11111111111111111111111111111111111111112' at timestamp '1738770211'.
# 2025-02-05 18:08:19,564 - INFO - fetch_historical_price: Requesting price for token 'C7heQqfNzdMbUFQwcHkL9FvdwsFsDRBnfwZDDyWYCLTZ' at timestamp '1738770211'.
# 2025-02-05 18:08:19,681 - INFO - fetch_historical_price: Received price 0.0039301991471786535 for token 'C7heQqfNzdMbUFQwcHkL9FvdwsFsDRBnfwZDDyWYCLTZ' at timestamp '1738770211'.
# Processing transactions:  64%|██████▍   | 51/80 [00:25<00:14,  2.06it/s]2025-02-05 18:08:19,884 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738771450'.
# 2025-02-05 18:08:20,029 - INFO - fetch_historical_price: Received price 201.71073823287804 for token 'So11111111111111111111111111111111111111112' at timestamp '1738771450'.
# ...
# Processing transactions:  85%|████████▌ | 68/80 [00:33<00:05,  2.11it/s]2025-02-05 18:08:27,913 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738731157'.
# 2025-02-05 18:08:28,079 - INFO - fetch_historical_price: Received price 205.36105897778413 for token 'So11111111111111111111111111111111111111112' at timestamp '1738731157'.
# 2025-02-05 18:08:28,080 - INFO - fetch_historical_price: Requesting price for token '2yd2Suus3YY4Sa7LHhn1PSHkjXj3XKrars4cCog2tGU8' at timestamp '1738731157'.
# 2025-02-05 18:08:28,218 - INFO - fetch_historical_price: Received price 0.011744803345625488 for token '2yd2Suus3YY4Sa7LHhn1PSHkjXj3XKrars4cCog2tGU8' at timestamp '1738731157'.
# Processing transactions:  86%|████████▋ | 69/80 [00:33<00:05,  2.07it/s]2025-02-05 18:08:28,421 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738772668'.
# 2025-02-05 18:08:28,566 - INFO - fetch_historical_price: Received price 198.88543278951178 for token 'So11111111111111111111111111111111111111112' at timestamp '1738772668'.
# 2025-02-05 18:08:28,567 - INFO - fetch_historical_price: Requesting price for token '6ZHaDajZnN9tu62eGD1VVGMKqkEix3GaES6fEXMsPdnd' at timestamp '1738772668'.
# 2025-02-05 18:08:28,682 - INFO - fetch_historical_price: Received price 0.00016720800125018115 for token '6ZHaDajZnN9tu62eGD1VVGMKqkEix3GaES6fEXMsPdnd' at timestamp '1738772668'.
# Processing transactions:  88%|████████▊ | 70/80 [00:34<00:04,  2.09it/s]2025-02-05 18:08:28,886 - INFO - fetch_historical_price: Requesting price for token '9DHe3pycTuymFk4H4bbPoAJ4hQrr2kaLDF6J6aAKpump' at timestamp '1738771658'.
# 2025-02-05 18:08:29,032 - INFO - fetch_historical_price: Received price 0.03759467946484541 for token '9DHe3pycTuymFk4H4bbPoAJ4hQrr2kaLDF6J6aAKpump' at timestamp '1738771658'.
# 2025-02-05 18:08:29,033 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738771658'.
# 2025-02-05 18:08:29,197 - INFO - fetch_historical_price: Received price 201.2813778769436 for token 'So11111111111111111111111111111111111111112' at timestamp '1738771658'.
# Processing transactions:  89%|████████▉ | 71/80 [00:34<00:04,  2.04it/s]2025-02-05 18:08:29,399 - INFO - fetch_historical_price: Requesting price for token '4FfTcjSySNCK5FMncfPYMFyp4QpFR4GERDKnfECr7ntg' at timestamp '1738773631'.
# 2025-02-05 18:08:29,537 - INFO - fetch_historical_price: Received price 0.059601037451899395 for token '4FfTcjSySNCK5FMncfPYMFyp4QpFR4GERDKnfECr7ntg' at timestamp '1738773631'.
# 2025-02-05 18:08:29,538 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738773631'.
# 2025-02-05 18:08:29,676 - INFO - fetch_historical_price: Received price 198.93136756821772 for token 'So11111111111111111111111111111111111111112' at timestamp '1738773631'.
# Processing transactions:  90%|█████████ | 72/80 [00:35<00:03,  2.06it/s]2025-02-05 18:08:29,879 - INFO - fetch_historical_price: Requesting price for token 'DriFtupJYLTosbwoN8koMbEYSx54aFAVLddWsbksjwg7' at timestamp '1738772137'.
# 2025-02-05 18:08:29,996 - INFO - fetch_historical_price: Received price 0.7391437106092223 for token 'DriFtupJYLTosbwoN8koMbEYSx54aFAVLddWsbksjwg7' at timestamp '1738772137'.
# 2025-02-05 18:08:29,997 - INFO - fetch_historical_price: Requesting price for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738772137'.
# 2025-02-05 18:08:30,165 - INFO - fetch_historical_price: Received price 0.99999713 for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738772137'.
# Processing transactions:  91%|█████████▏| 73/80 [00:35<00:03,  2.05it/s]2025-02-05 18:08:30,369 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738773002'.
# 2025-02-05 18:08:30,508 - INFO - fetch_historical_price: Received price 199.44035284709108 for token 'So11111111111111111111111111111111111111112' at timestamp '1738773002'.
# 2025-02-05 18:08:30,510 - INFO - fetch_historical_price: Requesting price for token 'A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump' at timestamp '1738773002'.
# 2025-02-05 18:08:30,651 - INFO - fetch_historical_price: Received price 0.08975278936484364 for token 'A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump' at timestamp '1738773002'.
# Processing transactions:  92%|█████████▎| 74/80 [00:36<00:02,  2.05it/s]2025-02-05 18:08:30,855 - INFO - fetch_historical_price: Requesting price for token '7D1iYWfhw2cr9yBZBFE6nZaaSUvXHqG5FizFFEZwpump' at timestamp '1738774452'.
# 2025-02-05 18:08:30,981 - INFO - fetch_historical_price: Received price 0.04089094151129468 for token '7D1iYWfhw2cr9yBZBFE6nZaaSUvXHqG5FizFFEZwpump' at timestamp '1738774452'.
# 2025-02-05 18:08:30,982 - INFO - fetch_historical_price: Requesting price for token 'J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn' at timestamp '1738774452'.
# 2025-02-05 18:08:31,149 - INFO - fetch_historical_price: Received price 235.89380501853122 for token 'J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn' at timestamp '1738774452'.
# Processing transactions:  94%|█████████▍| 75/80 [00:36<00:02,  2.04it/s]2025-02-05 18:08:31,352 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738772985'.
# 2025-02-05 18:08:31,479 - INFO - fetch_historical_price: Received price 199.33486907296185 for token 'So11111111111111111111111111111111111111112' at timestamp '1738772985'.
# 2025-02-05 18:08:31,480 - INFO - fetch_historical_price: Requesting price for token 'A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump' at timestamp '1738772985'.
# 2025-02-05 18:08:31,601 - INFO - fetch_historical_price: Received price 0.0892487618944176 for token 'A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump' at timestamp '1738772985'.
# Processing transactions:  95%|█████████▌| 76/80 [00:37<00:01,  2.09it/s]2025-02-05 18:08:31,806 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738771773'.
# 2025-02-05 18:08:31,951 - INFO - fetch_historical_price: Received price 200.88876042984757 for token 'So11111111111111111111111111111111111111112' at timestamp '1738771773'.
# 2025-02-05 18:08:31,952 - INFO - fetch_historical_price: Requesting price for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738771773'.
# 2025-02-05 18:08:32,089 - INFO - fetch_historical_price: Received price 0.99999315 for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' at timestamp '1738771773'.
# Processing transactions:  96%|█████████▋| 77/80 [00:37<00:01,  2.08it/s]2025-02-05 18:08:32,292 - INFO - fetch_historical_price: Requesting price for token '3N2ETvNpPNAxhcaXgkhKoY1yDnQfs41Wnxsx5qNJpump' at timestamp '1738774462'.
# 2025-02-05 18:08:32,421 - INFO - fetch_historical_price: Received price 0.01636209428038532 for token '3N2ETvNpPNAxhcaXgkhKoY1yDnQfs41Wnxsx5qNJpump' at timestamp '1738774462'.
# 2025-02-05 18:08:32,422 - INFO - fetch_historical_price: Requesting price for token 'J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn' at timestamp '1738774462'.
# 2025-02-05 18:08:32,555 - INFO - fetch_historical_price: Received price 235.85719071222445 for token 'J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn' at timestamp '1738774462'.
# Processing transactions:  98%|█████████▊| 78/80 [00:38<00:00,  2.10it/s]2025-02-05 18:08:32,759 - INFO - fetch_historical_price: Requesting price for token 'A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump' at timestamp '1738772794'.
# 2025-02-05 18:08:32,893 - INFO - fetch_historical_price: Received price 0.08647221734902281 for token 'A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump' at timestamp '1738772794'.
# 2025-02-05 18:08:32,895 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738772794'.
# 2025-02-05 18:08:33,052 - INFO - fetch_historical_price: Received price 199.4171168811018 for token 'So11111111111111111111111111111111111111112' at timestamp '1738772794'.
# Processing transactions:  99%|█████████▉| 79/80 [00:38<00:00,  2.07it/s]2025-02-05 18:08:33,257 - INFO - fetch_historical_price: Requesting price for token '5YqckGEkWHJmp9LW5aUF2uJrdUbMJaHcYnGjA8M7Ebw8' at timestamp '1738772374'.
# 2025-02-05 18:08:33,384 - INFO - fetch_historical_price: Received price 0.0020798158364021616 for token '5YqckGEkWHJmp9LW5aUF2uJrdUbMJaHcYnGjA8M7Ebw8' at timestamp '1738772374'.
# 2025-02-05 18:08:33,385 - INFO - fetch_historical_price: Requesting price for token 'So11111111111111111111111111111111111111112' at timestamp '1738772374'.
# 2025-02-05 18:08:33,502 - INFO - fetch_historical_price: Received price 199.23954539801957 for token 'So11111111111111111111111111111111111111112' at timestamp '1738772374'.
# Processing transactions: 100%|██████████| 80/80 [00:39<00:00,  2.05it/s]
# 2025-02-05 18:08:33,706 - INFO - main: Calculating per-transaction dollar values...
# 2025-02-05 18:08:33,708 - INFO - main: Aggregating dollar values per token...
# 2025-02-05 18:08:33,714 - INFO - main: Aggregated token values:
# 2025-02-05 18:08:33,715 - INFO -                                            token   dollars_sold  \
# 0   2Vnei1LAmrBpbL8fNCiCpaYcQTCSodiE51wab6qaQJAq       0.000000
# 1   2yd2Suus3YY4Sa7LHhn1PSHkjXj3XKrars4cCog2tGU8    1618.467542
# 2   2z1p8xCEjRzpBHjXWrx4tJnz7BFL6z7NnvbCxH7bpump  132361.465104
# 3   2zMMhcVQEXDtdE6vsFS7S7D5oUodfJHE8vd1gnBouauv       0.000000
# 4   3BgwJ8b7b9hHX4sgfZ2KJhv9496CoVfsMK2YePevsBRw       0.000000
# 5   3N2ETvNpPNAxhcaXgkhKoY1yDnQfs41Wnxsx5qNJpump       0.000000
# 6   3NZ9JMVBmGAqocybic2c7LQCJScmgsAZ6vQqTDzcqmJh       0.000000
# 7   3ufbSaVQSGeoCbgVp45YYYWKygbYFXAUZ7n7AP4CUWg6    2300.397404
# 8   4FfTcjSySNCK5FMncfPYMFyp4QpFR4GERDKnfECr7ntg    4635.589890
# 9   4mbdysBik3jmzD7mt6FGPDsMxnYcxExSQRFjPucdpump   28955.213528
# 10  5YqckGEkWHJmp9LW5aUF2uJrdUbMJaHcYnGjA8M7Ebw8     101.327273
# 11  5jfBtU75jk4q8xYPtnuR9GZx5YMsTQR1YyS5GuPcpump     696.515555
# 12  63LfDmNb3MQ8mw9MtZ2To9bEA2M71kZUUGq5tiJxcqj9   12638.113529
# 13  6ZHaDajZnN9tu62eGD1VVGMKqkEix3GaES6fEXMsPdnd       0.000000
# 14  6p6xgHyF7AeE6TZkSmFsko444wqoP15icUSqi2jfGiPN  198308.759090
# 15   76PsEyML7UV9uiBDWMdG3itRRuupDuRs6nNpjNBpump       0.000000
# 16  7D1iYWfhw2cr9yBZBFE6nZaaSUvXHqG5FizFFEZwpump       0.000000
# 17  7XJiwLDrjzxDYdZipnJXzpr1iDTmK55XixSFAa7JgNEL       0.000000
# 18  83iBDw3ZpxqJ3pEzrbttr9fGA57tttehDAxoFyR1moon       0.000000
# 19  8tSeXYSXzFvaDX1nbWrEFFaFuPHuWqpzksKYxQPvpump       0.000000
# 20  98mb39tPFKQJ4Bif8iVg9mYb9wsfPZgpgN1sxoVTpump       0.000000
# 21  9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump  194833.135918
# 22  9DHe3pycTuymFk4H4bbPoAJ4hQrr2kaLDF6J6aAKpump     692.897382
# 23  9McvH6w97oewLmPxqQEoHUAv3u5iYMyQ9AeZZhguYf1T       0.000000
# 24  9bNUjxEvygayUE2ZRN5zh9Hhjh6cN6GPK4zoHzXXpump       0.000000
# 25  A6YRaK4toMe2qZY7KLNCugXBrsjCG4fAjAR8uZUBeUek       0.000000
# 26  A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump    2651.903671
# 27  BCQRnuZEYw6z4AedaJRpDnQzpmqUgK8PPeLnqaNcpump       0.000000
# 28  Bv8q9VYwyU3QCiHWMdko7pZx8BW1zERhvANNN8P7uvnH    1006.871829
# 29  C7heQqfNzdMbUFQwcHkL9FvdwsFsDRBnfwZDDyWYCLTZ       0.000000
# 30  C8cNX2D1y3jqKpMFkQhP1gGbfvTEdeckZXLBKSN5z5KF       0.000000
# 31  CNyMaRR4krm1yAxfCvPXevNMArZZZk7sRqKwX68uCeJk    1025.802025
# 32  CZBYBV2e1x1ZuZ2qkwU5mPNVLFKfVvjSssSNHzSepump    1403.261248
# 33  CuxbDwNU9q8uLVU8E4drMPzrXQ3ipzH3Fai7Bfoepump       0.000000
# 34  DriFtupJYLTosbwoN8koMbEYSx54aFAVLddWsbksjwg7   89740.259387
# 35  ED5nyyWEzpPPiWimP8vYm7sD7TD3LAt3Q3gRTWHzPJBY   28435.507876
# 36  EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm       0.000000
# 37  ELdqGtj2MhejZzudGfz7b798si2Av5Asuw9ryEQSpump       0.000000
# 38  EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v  162546.208794
# 39  Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB  101007.334457
# 40  F9TgEJLLRUKDRF16HgjUCdJfJ5BK6ucyiW8uJxVPpump       0.000000
# 41  FLJYGHpCCcfYUdzhcfHSeSd2peb5SMajNWaCsRnhpump       0.000000
# 42  FSTRgYfDaudjDwFg5A9LQpDMq5vxqhskHq4rkjUMwERE    1130.439826
# 43  FasH397CeZLNYWkd3wWK9vrmjd1z93n3b59DssRXpump       0.000000
# 44  G25rCkrGqTf1hL5U8aq5niJDHccuBFLZSAbQNaCNpump       0.000000
# 45  GekTNfm84QfyP2GdAHZ5AgACBRd69aNmgA5FDhZupump       0.000000
# 46  Grass7B4RdKfBCjTKgSqnXkqjwiGvQyFbuSCUJr3XXjs    4172.072050
# 47  HZNnmhAY6xfq2iKRyBTEvTVeoTYJzpkK8mfnfG8Ppump       0.000000
# 48  J1toso1uCk3RLmjorhTtrVwY9HJ7X8V9yYac6Y7kGCPn       0.000000
# 49  J7tYmq2JnQPvxyhcXpCDrvJnc9R5ts8rv7tgVHDPsw7U   11072.282678
# 50   JUPyiwrYJFskUPiHa7hkeR8VUtAeFoSYbKedZNsDvCN   44876.545738
# 51   KENJSUYLASHUMfHyy5o4Hp2FdNqZg1AsUPhfH2kYvEP       0.000000
# 52   M3M3pSFptfpZYnWNUgAbyWzKKgPo5d1eWmX6tbiSF2K       0.000000
# 53   So11111111111111111111111111111111111111112  198563.438562
# 54   eL5fUxj2J4CiQsmW85k5FG9DvuQjjUoBHoQBi2Kpump   12001.918373
# 55   h5NciPdMZ5QCB5BYETJMYBMpVx9ZuitR6HcVjyBhood    1935.130284
# 56   jUpa2aDCzvdR9EF4fqDXmuyMUkonPTohphABLmRkRFj       0.000000
# 57   jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v       0.000000
# 58   mSoLzYCxHdYgdzU16g5QSh3i5K3z3KZK7ytfqcJm7So   17329.520841
#
#     dollars_bought
# 0     2.030296e+03
# 1     2.538325e+03
# 2     0.000000e+00
# 3     5.033956e+02
# 4     2.011318e+04
# 5     0.000000e+00
# 6     2.887043e+04
# 7     0.000000e+00
# 8     0.000000e+00
# 9     0.000000e+00
# 10    0.000000e+00
# 11    0.000000e+00
# 12    0.000000e+00
# 13    1.257803e+02
# 14    1.016005e+05
# 15    0.000000e+00
# 16    0.000000e+00
# 17    1.138484e+03
# 18    4.366351e+04
# 19    1.349455e+03
# 20    0.000000e+00
# 21    4.981419e+03
# 22    0.000000e+00
# 23    0.000000e+00
# 24    6.076004e+02
# 25    2.013679e+02
# 26    3.057674e+03
# 27    5.231172e+02
# 28    9.958438e+02
# 29    1.762942e+03
# 30    1.011367e+03
# 31    0.000000e+00
# 32    0.000000e+00
# 33    2.830671e+02
# 34    0.000000e+00
# 35    0.000000e+00
# 36    4.989396e+03
# 37    5.600664e+02
# 38    5.423931e+05
# 39    2.051734e+05
# 40    3.188630e+02
# 41    5.792868e+02
# 42    0.000000e+00
# 43    1.164569e+05
# 44    9.919052e+01
# 45    0.000000e+00
# 46    0.000000e+00
# 47    3.030581e+02
# 48    2.677427e+03
# 49    0.000000e+00
# 50    0.000000e+00
# 51    2.006189e+03
# 52    0.000000e+00
# 53    1.189675e+14
# 54    0.000000e+00
# 55    0.000000e+00
# 56    1.972171e+02
# 57    4.944793e+03
# 58    0.000000e+00
# 2025-02-05 18:08:33,719 - INFO - main: Merging aggregated data with token details...
# 2025-02-05 18:08:33,720 - ERROR - main: An error occurred: 'baseToken_address'
# Traceback (most recent call last):
#   File "C:\Users\sandr\AppData\Local\Temp\ipykernel_9120\2376696615.py", line 300, in main
#     final_df = pd.merge(aggregated, token_details_df, left_on="token", right_on="baseToken_address", how="left")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sandr\DataspellProjects\dca_processor\venv\Lib\site-packages\pandas\core\reshape\merge.py", line 170, in merge
#     op = _MergeOperation(
#          ^^^^^^^^^^^^^^^^
#   File "C:\Users\sandr\DataspellProjects\dca_processor\venv\Lib\site-packages\pandas\core\reshape\merge.py", line 794, in __init__
#     ) = self._get_merge_keys()
#         ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sandr\DataspellProjects\dca_processor\venv\Lib\site-packages\pandas\core\reshape\merge.py", line 1297, in _get_merge_keys
#     right_keys.append(right._get_label_or_level_values(rk))
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sandr\DataspellProjects\dca_processor\venv\Lib\site-packages\pandas\core\generic.py", line 1911, in _get_label_or_level_values
#     raise KeyError(key)
# KeyError: 'baseToken_address'
# 2025-02-05 18:08:33,722 - INFO - main: Database connection closed.

# %%
import logging
import requests
import pandas as pd
import time
from time import sleep
from tqdm import tqdm  # progress bar package
from processors.update_tokens import main as update_tokens_main
import sys
from db.connection import DatabaseConnection
from db.queries import DatabaseQueries
from config import load_config
import random

# Configure logging globally
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")
logger = logging.getLogger(__name__)

# -------------------------------------------------------------------
def fetch_historical_price(token_mint, api_key):
    """
    Fetch the historical price data for a given token using the Birdeye API endpoint
    /defi/history_price. The API call requests the price history from:
        time_from = now - 188700 (seconds)
        time_to   = now

    The API is expected to return a JSON with a structure like:
    {
      "data": {
        "items": [
          {
            "address": "ZYDWbrsVbaE83FVXvdHoUVcKRrDN9S2Jskyhsuypump",
            "unixTime": 1738942800,
            "value": 0.00000610584940167204
          },
          ...
        ]
      },
      "success": true
    }

    Parameters:
        token_mint (str): The token’s mint address.
        api_key (str): The Birdeye API key.

    Returns:
        pd.DataFrame: A DataFrame containing the historical price snapshots (sorted by unixTime)
                      if the call is successful, otherwise None.
    """
    now = int(time.time())
    time_from = now - 188700  # 188700 seconds before now
    url = f"https://public-api.birdeye.so/defi/history_price?address={token_mint}&address_type=token&type=5m&time_from={time_from}&time_to={now}"
    logger.info(f"fetch_historical_price: Requesting history for token '{token_mint}' from {time_from} to {now}.")
    headers = {
        "accept": "application/json",
        "x-chain": "solana",
        "X-API-KEY": api_key
    }
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        data = response.json()
        if data.get("success") is True:
            items = data.get("data", {}).get("items", [])
            if items:
                df = pd.DataFrame(items)
                df = df.sort_values("unixTime")
                logger.info(f"fetch_historical_price: Retrieved {len(df)} price snapshots for token '{token_mint}'.")
                return df
            else:
                logger.error(f"fetch_historical_price: No items found in API response for token '{token_mint}'. Response: {data}")
                return None
        else:
            logger.error(f"fetch_historical_price: API returned error for token '{token_mint}'. Response: {data}")
            return None
    except requests.RequestException as e:
        logger.error(f"fetch_historical_price: Request error for token '{token_mint}': {e}")
        return None

# -------------------------------------------------------------------
def fetch_token_details(chain_id, token_addresses, api_url):
    """
    Fetch token details from the Dexscreener API in batches and return a DataFrame.
    (This function remains unchanged.)
    """
    logger.info(f"fetch_token_details: Starting to fetch details for {len(token_addresses)} tokens on chain '{chain_id}'.")
    token_details_list = []
    token_addresses = [address for address in token_addresses if address is not None]
    total_batches = (len(token_addresses) + 29) // 30
    for i in tqdm(range(0, len(token_addresses), 30), desc='Processing token batches', unit='batch', total=total_batches):
        batch_addresses = token_addresses[i:i+30]
        logger.info(f"fetch_token_details: Processing batch {i//30 + 1} with tokens: {batch_addresses}")
        try:
            response = requests.get(f"{api_url}/tokens/v1/{chain_id}/{','.join(batch_addresses)}")
            response.raise_for_status()
            data = response.json()
            for token_data in data:
                token_details = {
                    'chainId': token_data.get('chainId', ''),
                    'dexId': token_data.get('dexId', ''),
                    'url': token_data.get('url', ''),
                    'pairAddress': token_data.get('pairAddress', ''),
                    'labels': token_data.get('labels', []),
                    'baseToken_address': token_data.get('baseToken', {}).get('address', ''),
                    'baseToken_name': token_data.get('baseToken', {}).get('name', ''),
                    'baseToken_symbol': token_data.get('baseToken', {}).get('symbol', ''),
                    'quoteToken_address': token_data.get('quoteToken', {}).get('address', ''),
                    'quoteToken_name': token_data.get('quoteToken', {}).get('name', ''),
                    'quoteToken_symbol': token_data.get('quoteToken', {}).get('symbol', ''),
                    'priceNative': token_data.get('priceNative', 0.0),
                    'priceUsd': token_data.get('priceUsd', 0.0),
                    'txns_m5_buys': token_data.get('txns', {}).get('m5', {}).get('buys', 0),
                    'txns_m5_sells': token_data.get('txns', {}).get('m5', {}).get('sells', 0),
                    'txns_h1_buys': token_data.get('txns', {}).get('h1', {}).get('buys', 0),
                    'txns_h1_sells': token_data.get('txns', {}).get('h1', {}).get('sells', 0),
                    'txns_h6_buys': token_data.get('txns', {}).get('h6', {}).get('buys', 0),
                    'txns_h6_sells': token_data.get('txns', {}).get('h6', {}).get('sells', 0),
                    'txns_h24_buys': token_data.get('txns', {}).get('h24', {}).get('buys', 0),
                    'txns_h24_sells': token_data.get('txns', {}).get('h24', {}).get('sells', 0),
                    'volume_h24': token_data.get('volume', {}).get('h24', 0.0),
                    'volume_h6': token_data.get('volume', {}).get('h6', 0.0),
                    'volume_h1': token_data.get('volume', {}).get('h1', 0.0),
                    'volume_m5': token_data.get('volume', {}).get('m5', 0.0),
                    'priceChange_m5': token_data.get('priceChange', {}).get('m5', 0.0),
                    'priceChange_h1': token_data.get('priceChange', {}).get('h1', 0.0),
                    'priceChange_h6': token_data.get('priceChange', {}).get('h6', 0.0),
                    'priceChange_h24': token_data.get('priceChange', {}).get('h24', 0.0),
                    'liquidity_usd': token_data.get('liquidity', {}).get('usd', 0.0),
                    'liquidity_base': token_data.get('liquidity', {}).get('base', 0.0),
                    'liquidity_quote': token_data.get('liquidity', {}).get('quote', 0.0),
                    'fdv': token_data.get('fdv', 0),
                    'marketCap': token_data.get('marketCap', 0),
                    'pairCreatedAt': token_data.get('pairCreatedAt', '')
                }
                token_details_list.append(token_details)
            logger.info(f"fetch_token_details: Completed processing batch {i//30 + 1}.")
            sleep(1)  # avoid rate limiting
        except requests.RequestException as e:
            logger.error(f"fetch_token_details: Error fetching batch {batch_addresses}: {e}")
            sleep(1)
    token_details = pd.DataFrame(token_details_list)
    logger.info("fetch_token_details: Finished fetching all token details.")
    return token_details

# -------------------------------------------------------------------
def get_closest_price(token, block_time, token_history_data):
    """
    Given a token and a block_time, look up the historical price data for that token
    (as returned by fetch_historical_price) and return the price (i.e. 'value') from the
    snapshot with the smallest time difference to block_time.
    """
    df = token_history_data.get(token)
    if df is None or df.empty:
        logger.warning(f"get_closest_price: No historical data available for token {token}.")
        return None
    # Calculate the absolute time difference between block_time and all snapshots
    time_diffs = (df["unixTime"] - block_time).abs()
    closest_idx = time_diffs.idxmin()
    closest_price = df.loc[closest_idx, "value"]
    return closest_price

# -------------------------------------------------------------------
def main():
    # Initialize configuration and database connections
    config = load_config()
    db_connection = DatabaseConnection(config.db)
    db_queries = DatabaseQueries(db_connection)

    try:
        logger.info("main: Starting main function execution.")

        # (1) Optionally update token information
        # logger.info("main: Calling update_tokens.main()...")
        # update_tokens_main()

        # (2) Fetch recent transactions (e.g., from the past 6 hours)
        logger.info("main: Fetching recent transactions...")
        transactions_df = db_queries.get_recent_transactions(n=3)
        logger.info(f"main: Fetched {len(transactions_df)} transactions.")

        # (3) Fetch token details once
        token_columns = ["open_input_mint", "open_output_mint", "close_input_mint", "close_output_mint"]
        unique_tokens = pd.unique(transactions_df[token_columns].values.ravel())
        logger.info(f"main: Found {len(unique_tokens)} unique token addresses for details.")
        chain_id = "solana"
        api_url = "https://api.dexscreener.com"
        token_details_df = fetch_token_details(chain_id, unique_tokens, api_url)

        # (4) Add new columns for tokens and their historical prices
        transactions_df["input_token"] = None
        transactions_df["output_token"] = None
        transactions_df["input_price"] = None
        transactions_df["output_price"] = None

        # (5) For each distinct token, fetch its historical price snapshots once
        logger.info("main: Fetching historical price data for each unique token...")
        token_history_data = {}
        for token in tqdm(unique_tokens, desc="Fetching token historical prices", unit="token"):
            df_history = fetch_historical_price(token, config.birdeye.api_key)
            if df_history is not None:
                token_history_data[token] = df_history
            else:
                logger.warning(f"main: No historical data found for token {token}.")
            sleep(0.2)  # To avoid rate limiting

        # (6) Process each transaction to look up the closest historical price for both input and output tokens
        logger.info("main: Processing transactions to calculate historical prices...")
        for index, row in tqdm(transactions_df.iterrows(), total=len(transactions_df), desc="Processing transactions"):
            if pd.notnull(row["open_input_mint"]):
                input_token = row["open_input_mint"]
                output_token = row["open_output_mint"]
                block_time = row["open_block_time"]
            else:
                input_token = row["close_input_mint"]
                output_token = row["close_output_mint"]
                block_time = row["close_block_time"]

            transactions_df.at[index, "input_token"] = input_token
            transactions_df.at[index, "output_token"] = output_token

            # Look up the closest price snapshot for each token based on block_time
            input_price = get_closest_price(input_token, block_time, token_history_data)
            output_price = get_closest_price(output_token, block_time, token_history_data)

            transactions_df.at[index, "input_price"] = input_price
            transactions_df.at[index, "output_price"] = output_price

        # (7) Calculate per-transaction dollar amounts
        logger.info("main: Calculating per-transaction dollar values...")
        transactions_df["dollars_sold"] = (
                transactions_df["in_amount"].astype(float) *
                transactions_df["input_price"].astype(float)
        )
        transactions_df["dollars_bought"] = (
                transactions_df["out_amount"].astype(float) *
                transactions_df["output_price"].astype(float)
        )

        # (8) Aggregate dollar amounts per token
        logger.info("main: Aggregating dollar values per token...")
        aggregated_sold = (
            transactions_df.groupby("input_token")["dollars_sold"]
            .sum()
            .reset_index()
            .rename(columns={"input_token": "token"})
        )
        aggregated_bought = (
            transactions_df.groupby("output_token")["dollars_bought"]
            .sum()
            .reset_index()
            .rename(columns={"output_token": "token"})
        )
        aggregated = pd.merge(aggregated_sold, aggregated_bought, on="token", how="outer")
        aggregated["dollars_sold"] = aggregated["dollars_sold"].fillna(0)
        aggregated["dollars_bought"] = aggregated["dollars_bought"].fillna(0)
        logger.info("main: Aggregated token values:")
        logger.info(aggregated)

        # (9) Merge aggregated data with token details
        logger.info("main: Merging aggregated data with token details...")
        final_df = pd.merge(aggregated, token_details_df, left_on="token", right_on="baseToken_address", how="left")

        # (10) Format dollars columns to use a comma as the decimal separator
        logger.info("main: Formatting dollar values with comma as decimal separator...")
        final_df["dollars_sold"] = final_df["dollars_sold"].apply(lambda x: f"{x:.2f}".replace('.',','))
        final_df["dollars_bought"] = final_df["dollars_bought"].apply(lambda x: f"{x:.2f}".replace('.',','))

        # (11) Remove timezone information for Excel compatibility
        for col in transactions_df.select_dtypes(include=["datetimetz"]).columns:
            transactions_df[col] = transactions_df[col].dt.tz_localize(None)
        for col in final_df.select_dtypes(include=["datetimetz"]).columns:
            final_df[col] = final_df[col].dt.tz_localize(None)

        # (12) Write the final merged output to an Excel file.
        logger.info("main: Writing final aggregated token details to Excel file...")
        final_df.to_excel("final_aggregated_token_details.xlsx", index=False)
        logger.info("main: Final Excel file written successfully.")
        print(final_df)

    except Exception as e:
        logger.error(f"main: An error occurred: {e}", exc_info=True)
    finally:
        db_connection.close()
        logger.info("main: Database connection closed.")

if __name__ == "__main__":
    main()
# Out:
# INFO:__main__:main: Starting main function execution.
# INFO:__main__:main: Fetching recent transactions...
# INFO:db.queries:Fetching recent transactions for the past 3 hours.
# INFO:db.queries:Fetched 208 rows of transactions.
# INFO:__main__:main: Fetched 208 transactions.
# INFO:__main__:main: Found 77 unique token addresses for details.
# INFO:__main__:fetch_token_details: Starting to fetch details for 77 tokens on chain 'solana'.
# Processing token batches:   0%|          | 0/3 [00:00<?, ?batch/s]INFO:__main__:fetch_token_details: Processing batch 1 with tokens: ['AT7RRrFhBU1Dw1WghdgAqeNKNXKomDFXm77owQgppump', 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v', 'So11111111111111111111111111111111111111112', 'EqeEBGHQhQy6SqeaJcnqAsNs3qaG19sdF89Xsarpump', '27G8MtK7VtTcCHkpASjSDdkWWYfoqT6ggEuKidVJidD4', '9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump', '5oVNBeEEQvYi1cX3ir8Dx5n1P7pdxydbGF2X4TxVusJm', 'Grass7B4RdKfBCjTKgSqnXkqjwiGvQyFbuSCUJr3XXjs', 'FFgfStKwuF3DSxEeogA69FNkPrkb7XDA5Tw29TBEpump', 'CRAMvzDsSpXYsFpcoDr6vFLJMBeftez1E7277xwPpump', '9b8jL2wcVjBFpieC5TUR76BDJ6sW8Eghd3fyq5VJmzir', 'HNg5PYJmtqcmzXrv6S9zP1CDKk5BgDuyFBxbvNApump', 'jUfwXi6BWechD13bzp1R1h2AR3bSKuGkJd5qJmppump', '2RuDRx9RAcXrSoLupeMLGuBay6w5Q1nUrdPySjA3pump', 'HaP8r3ksG76PhQLTqR8FYBeNiQpejcFbQmiHbg787Ut1', '8bPDYeH2Xqmmkp2LeSvgagPzLXUnGMa2yLVVTc41YCJ9', 'CFrd1PnphJcNiGHtL3QYLb2Fvs1aBbJfah3FqgNPpump', 'DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263', 'EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm', '7GCihgDB8fe6KNjn2MYtkzZcRjQy3t9GHdC8uHYmW2hr', '69G8CpUVZAxbPMiEBrfCCCH445NwFxH6PzVL693Xpump', 'EgMF2iEbKv984fWtqakZ12k4VQvJubTNnU2Y9durpump', '6p6xgHyF7AeE6TZkSmFsko444wqoP15icUSqi2jfGiPN', '7mHCx9iXPJ7EJDbDAUGmej39Kme8cxZfeVi1EAvEpump', 'CboMcTUYUcy9E6B3yGdFn6aEsGUnYV6yWeoeukw6pump', '69kdRLyP5DTRkpHraaSZAQbWmAwzF9guKjZfzMXzcbAs', 'JUPyiwrYJFskUPiHa7hkeR8VUtAeFoSYbKedZNsDvCN', '3NZ9JMVBmGAqocybic2c7LQCJScmgsAZ6vQqTDzcqmJh', 'AxriehR6Xw3adzHopnvMn7GcpRFcD41ddpiTWMg6pump', 'Bksfke6KWgpftafmbR3E9J4wHr4bBfKDrztXN6etpump']
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.dexscreener.com:443
# DEBUG:urllib3.connectionpool:https://api.dexscreener.com:443 "GET /tokens/v1/solana/AT7RRrFhBU1Dw1WghdgAqeNKNXKomDFXm77owQgppump,EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v,So11111111111111111111111111111111111111112,EqeEBGHQhQy6SqeaJcnqAsNs3qaG19sdF89Xsarpump,27G8MtK7VtTcCHkpASjSDdkWWYfoqT6ggEuKidVJidD4,9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump,5oVNBeEEQvYi1cX3ir8Dx5n1P7pdxydbGF2X4TxVusJm,Grass7B4RdKfBCjTKgSqnXkqjwiGvQyFbuSCUJr3XXjs,FFgfStKwuF3DSxEeogA69FNkPrkb7XDA5Tw29TBEpump,CRAMvzDsSpXYsFpcoDr6vFLJMBeftez1E7277xwPpump,9b8jL2wcVjBFpieC5TUR76BDJ6sW8Eghd3fyq5VJmzir,HNg5PYJmtqcmzXrv6S9zP1CDKk5BgDuyFBxbvNApump,jUfwXi6BWechD13bzp1R1h2AR3bSKuGkJd5qJmppump,2RuDRx9RAcXrSoLupeMLGuBay6w5Q1nUrdPySjA3pump,HaP8r3ksG76PhQLTqR8FYBeNiQpejcFbQmiHbg787Ut1,8bPDYeH2Xqmmkp2LeSvgagPzLXUnGMa2yLVVTc41YCJ9,CFrd1PnphJcNiGHtL3QYLb2Fvs1aBbJfah3FqgNPpump,DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263,EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm,7GCihgDB8fe6KNjn2MYtkzZcRjQy3t9GHdC8uHYmW2hr,69G8CpUVZAxbPMiEBrfCCCH445NwFxH6PzVL693Xpump,EgMF2iEbKv984fWtqakZ12k4VQvJubTNnU2Y9durpump,6p6xgHyF7AeE6TZkSmFsko444wqoP15icUSqi2jfGiPN,7mHCx9iXPJ7EJDbDAUGmej39Kme8cxZfeVi1EAvEpump,CboMcTUYUcy9E6B3yGdFn6aEsGUnYV6yWeoeukw6pump,69kdRLyP5DTRkpHraaSZAQbWmAwzF9guKjZfzMXzcbAs,JUPyiwrYJFskUPiHa7hkeR8VUtAeFoSYbKedZNsDvCN,3NZ9JMVBmGAqocybic2c7LQCJScmgsAZ6vQqTDzcqmJh,AxriehR6Xw3adzHopnvMn7GcpRFcD41ddpiTWMg6pump,Bksfke6KWgpftafmbR3E9J4wHr4bBfKDrztXN6etpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Completed processing batch 1.
# Processing token batches:  33%|███▎      | 1/3 [00:01<00:02,  1.32s/batch]INFO:__main__:fetch_token_details: Processing batch 2 with tokens: ['5YqckGEkWHJmp9LW5aUF2uJrdUbMJaHcYnGjA8M7Ebw8', '2ru87k7yAZnDRsnqVpgJYETFgqVApuBcwB2xDb19pump', '9xb4jRNU4MYgfu87mkRFFjSZN9MTL5gayXHhxpKUpump', '8oEHKQYYYavrfVXnF8qAHmJF18DWJwnvhwz6Wqktpump', '9UEN2kKhHxnaK14ZYFvog2hezajxAke9xCiS2hnppump', '7vfCXTUXx5WJV5JADk17DUJ4ksgau7utNKj4b963voxs', 'FasH397CeZLNYWkd3wWK9vrmjd1z93n3b59DssRXpump', 'FcsgEKX5cu2xeYQeQ5GiWKvPCEYmdBtPRTvYNFrLxoxo', '22Xeo6diWfJrScaoVFzgkwzrCByPukK45fdwkJyrpump', 'A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump', '4FfTcjSySNCK5FMncfPYMFyp4QpFR4GERDKnfECr7ntg', '2z1p8xCEjRzpBHjXWrx4tJnz7BFL6z7NnvbCxH7bpump', 'BXebtR4k2WiaZ1HJmxcZkoCdxSBx1g1xnEpVra9Ppump', 'J3NKxxXZcnNiMjKw9hYb2K4LUxgwB6t1FtPtQVsv3KFr', 'nosXBVoaCTtYdLvKY6Csb4AC8JCdQKKAaWYtx2ZMoo7', '2mhszy8YHwqs1fxruVHQQAUmNcfq31mtkmYYtNZNpump', '74SBV4zDXxTRgv1pEMoECskKBkZHc2yGPnc7GYVepump', '7iagMTDPfNSR5zVcERT1To7A9eaQoz58dJAh42EMHcCC', 'J9KTtypTWfSp912harLxd9jGz8iwsnqGmD5Yqgoopump', '2zMMhcVQEXDtdE6vsFS7S7D5oUodfJHE8vd1gnBouauv', '2RBko3xoz56aH69isQMUpzZd9NYHahhwC23A5F3Spkin', '4ccF7FpjTFZBWRZogCftU5aLd5NQMgJpyvrfDfwp2hEu', '2eXamy7t3kvKhfV6aJ6Uwe3eh8cuREFcTKs1mFKZpump', '8CzPPqenpfRXvjE5DHfE3kMDgJhHwWZ1WXRzs44KsamW', '6ogzHhzdrQr9Pgv6hZ2MNze7UrzBMAFyBBWUYp1Fhitx', 'Zc4uJVrHC2APe9qKwBD11Gg4BbvQr3naM8f7Wiopump', 'whispF7G9DHaojYHe2cdhRX5EMJzGBdqq7R57kL6inL', '9DHe3pycTuymFk4H4bbPoAJ4hQrr2kaLDF6J6aAKpump', '2KchKijPuwnwC92LPWVjFjRwB3WxKtzx9bbXZ7kRpump', 'pepo1CFNU2RXf7yXX7HNXazXwxsq8WrPvDHpHriwoLY']
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.dexscreener.com:443
# DEBUG:urllib3.connectionpool:https://api.dexscreener.com:443 "GET /tokens/v1/solana/5YqckGEkWHJmp9LW5aUF2uJrdUbMJaHcYnGjA8M7Ebw8,2ru87k7yAZnDRsnqVpgJYETFgqVApuBcwB2xDb19pump,9xb4jRNU4MYgfu87mkRFFjSZN9MTL5gayXHhxpKUpump,8oEHKQYYYavrfVXnF8qAHmJF18DWJwnvhwz6Wqktpump,9UEN2kKhHxnaK14ZYFvog2hezajxAke9xCiS2hnppump,7vfCXTUXx5WJV5JADk17DUJ4ksgau7utNKj4b963voxs,FasH397CeZLNYWkd3wWK9vrmjd1z93n3b59DssRXpump,FcsgEKX5cu2xeYQeQ5GiWKvPCEYmdBtPRTvYNFrLxoxo,22Xeo6diWfJrScaoVFzgkwzrCByPukK45fdwkJyrpump,A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump,4FfTcjSySNCK5FMncfPYMFyp4QpFR4GERDKnfECr7ntg,2z1p8xCEjRzpBHjXWrx4tJnz7BFL6z7NnvbCxH7bpump,BXebtR4k2WiaZ1HJmxcZkoCdxSBx1g1xnEpVra9Ppump,J3NKxxXZcnNiMjKw9hYb2K4LUxgwB6t1FtPtQVsv3KFr,nosXBVoaCTtYdLvKY6Csb4AC8JCdQKKAaWYtx2ZMoo7,2mhszy8YHwqs1fxruVHQQAUmNcfq31mtkmYYtNZNpump,74SBV4zDXxTRgv1pEMoECskKBkZHc2yGPnc7GYVepump,7iagMTDPfNSR5zVcERT1To7A9eaQoz58dJAh42EMHcCC,J9KTtypTWfSp912harLxd9jGz8iwsnqGmD5Yqgoopump,2zMMhcVQEXDtdE6vsFS7S7D5oUodfJHE8vd1gnBouauv,2RBko3xoz56aH69isQMUpzZd9NYHahhwC23A5F3Spkin,4ccF7FpjTFZBWRZogCftU5aLd5NQMgJpyvrfDfwp2hEu,2eXamy7t3kvKhfV6aJ6Uwe3eh8cuREFcTKs1mFKZpump,8CzPPqenpfRXvjE5DHfE3kMDgJhHwWZ1WXRzs44KsamW,6ogzHhzdrQr9Pgv6hZ2MNze7UrzBMAFyBBWUYp1Fhitx,Zc4uJVrHC2APe9qKwBD11Gg4BbvQr3naM8f7Wiopump,whispF7G9DHaojYHe2cdhRX5EMJzGBdqq7R57kL6inL,9DHe3pycTuymFk4H4bbPoAJ4hQrr2kaLDF6J6aAKpump,2KchKijPuwnwC92LPWVjFjRwB3WxKtzx9bbXZ7kRpump,pepo1CFNU2RXf7yXX7HNXazXwxsq8WrPvDHpHriwoLY HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Completed processing batch 2.
# Processing token batches:  67%|██████▋   | 2/3 [00:04<00:02,  2.23s/batch]INFO:__main__:fetch_token_details: Processing batch 3 with tokens: ['BwUTq7fS6sfUmHDwAiCQZ3asSiPEapW5zDrsbwtapump', '4xieJTWvYfWGTdZYjxZNePjqGu74NexmcjLUpfFLVAPx', 'CSChJMDH1drnxaN5ZXr8ZPZtqXv2FJqNTGcSujyfmoon', 'FHKiJEg2zmhv9DEeaXMSZa7R4P8BPFX5VTRrzrtJpump', 'jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v', '4TM1ZL64KjyxeffDLzaX7Eybg125qRpLF4tuzvutCu3M', 'Ai4CL1SAxVRigxQFwBH8S2JkuL7EqrdiGwTC7JpCpump', '5z3EqYQo9HiCEs3R84RCDMu2n7anpDMxRhdK8PSWmrRC', 'eL5fUxj2J4CiQsmW85k5FG9DvuQjjUoBHoQBi2Kpump', 'H4phNbsqjV5rqk8u6FUACTLB6rNZRTAPGnBb8KXJpump', '9doRRAik5gvhbEwjbZDbZR6GxXSAfdoomyJR57xKpump', 'Hjw6bEcHtbHGpQr8onG3izfJY5DJiWdt7uk2BfdSpump', 'AaWVpk6eZbgBfVbq1UfXw3EXBmAvw4QXov1xHuG7pump', 'BEP6KhDwv7K211JtZnszNcztHBffSCgRjUuNhucopump', 'BrZmDQwbdLXme3uaea8znLhy9Bb3fucMJmcFBuRPpump', 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB', '3S8qX1MsMqRbiwKg2cQyx7nis1oHMgaCuc9c4VfvVdPN']
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.dexscreener.com:443
# DEBUG:urllib3.connectionpool:https://api.dexscreener.com:443 "GET /tokens/v1/solana/BwUTq7fS6sfUmHDwAiCQZ3asSiPEapW5zDrsbwtapump,4xieJTWvYfWGTdZYjxZNePjqGu74NexmcjLUpfFLVAPx,CSChJMDH1drnxaN5ZXr8ZPZtqXv2FJqNTGcSujyfmoon,FHKiJEg2zmhv9DEeaXMSZa7R4P8BPFX5VTRrzrtJpump,jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v,4TM1ZL64KjyxeffDLzaX7Eybg125qRpLF4tuzvutCu3M,Ai4CL1SAxVRigxQFwBH8S2JkuL7EqrdiGwTC7JpCpump,5z3EqYQo9HiCEs3R84RCDMu2n7anpDMxRhdK8PSWmrRC,eL5fUxj2J4CiQsmW85k5FG9DvuQjjUoBHoQBi2Kpump,H4phNbsqjV5rqk8u6FUACTLB6rNZRTAPGnBb8KXJpump,9doRRAik5gvhbEwjbZDbZR6GxXSAfdoomyJR57xKpump,Hjw6bEcHtbHGpQr8onG3izfJY5DJiWdt7uk2BfdSpump,AaWVpk6eZbgBfVbq1UfXw3EXBmAvw4QXov1xHuG7pump,BEP6KhDwv7K211JtZnszNcztHBffSCgRjUuNhucopump,BrZmDQwbdLXme3uaea8znLhy9Bb3fucMJmcFBuRPpump,Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB,3S8qX1MsMqRbiwKg2cQyx7nis1oHMgaCuc9c4VfvVdPN HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Completed processing batch 3.
# Processing token batches: 100%|██████████| 3/3 [00:05<00:00,  1.83s/batch]
# INFO:__main__:fetch_token_details: Finished fetching all token details.
# INFO:__main__:main: Fetching historical price data for each unique token...
# Fetching token historical prices:   0%|          | 0/77 [00:00<?, ?token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'AT7RRrFhBU1Dw1WghdgAqeNKNXKomDFXm77owQgppump' from 1738912817 to 1739101517.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=AT7RRrFhBU1Dw1WghdgAqeNKNXKomDFXm77owQgppump&address_type=token&type=5m&time_from=1738912817&time_to=1739101517 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'AT7RRrFhBU1Dw1WghdgAqeNKNXKomDFXm77owQgppump'.
# Fetching token historical prices:   1%|▏         | 1/77 [00:00<00:44,  1.70token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' from 1738912817 to 1739101517.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v&address_type=token&type=5m&time_from=1738912817&time_to=1739101517 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v'.
# Fetching token historical prices:   3%|▎         | 2/77 [00:01<00:38,  1.96token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'So11111111111111111111111111111111111111112' from 1738912818 to 1739101518.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=So11111111111111111111111111111111111111112&address_type=token&type=5m&time_from=1738912818&time_to=1739101518 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'So11111111111111111111111111111111111111112'.
# Fetching token historical prices:   4%|▍         | 3/77 [00:01<00:35,  2.10token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'EqeEBGHQhQy6SqeaJcnqAsNs3qaG19sdF89Xsarpump' from 1738912818 to 1739101518.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=EqeEBGHQhQy6SqeaJcnqAsNs3qaG19sdF89Xsarpump&address_type=token&type=5m&time_from=1738912818&time_to=1739101518 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'EqeEBGHQhQy6SqeaJcnqAsNs3qaG19sdF89Xsarpump'.
# Fetching token historical prices:   5%|▌         | 4/77 [00:01<00:33,  2.15token/s]INFO:__main__:fetch_historical_price: Requesting history for token '27G8MtK7VtTcCHkpASjSDdkWWYfoqT6ggEuKidVJidD4' from 1738912819 to 1739101519.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=27G8MtK7VtTcCHkpASjSDdkWWYfoqT6ggEuKidVJidD4&address_type=token&type=5m&time_from=1738912819&time_to=1739101519 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '27G8MtK7VtTcCHkpASjSDdkWWYfoqT6ggEuKidVJidD4'.
# Fetching token historical prices:   6%|▋         | 5/77 [00:02<00:33,  2.18token/s]INFO:__main__:fetch_historical_price: Requesting history for token '9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump' from 1738912819 to 1739101519.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump&address_type=token&type=5m&time_from=1738912819&time_to=1739101519 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump'.
# Fetching token historical prices:   8%|▊         | 6/77 [00:02<00:32,  2.21token/s]INFO:__main__:fetch_historical_price: Requesting history for token '5oVNBeEEQvYi1cX3ir8Dx5n1P7pdxydbGF2X4TxVusJm' from 1738912820 to 1739101520.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=5oVNBeEEQvYi1cX3ir8Dx5n1P7pdxydbGF2X4TxVusJm&address_type=token&type=5m&time_from=1738912820&time_to=1739101520 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '5oVNBeEEQvYi1cX3ir8Dx5n1P7pdxydbGF2X4TxVusJm'.
# Fetching token historical prices:   9%|▉         | 7/77 [00:03<00:31,  2.24token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'Grass7B4RdKfBCjTKgSqnXkqjwiGvQyFbuSCUJr3XXjs' from 1738912820 to 1739101520.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=Grass7B4RdKfBCjTKgSqnXkqjwiGvQyFbuSCUJr3XXjs&address_type=token&type=5m&time_from=1738912820&time_to=1739101520 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'Grass7B4RdKfBCjTKgSqnXkqjwiGvQyFbuSCUJr3XXjs'.
# Fetching token historical prices:  10%|█         | 8/77 [00:03<00:31,  2.22token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'FFgfStKwuF3DSxEeogA69FNkPrkb7XDA5Tw29TBEpump' from 1738912820 to 1739101520.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=FFgfStKwuF3DSxEeogA69FNkPrkb7XDA5Tw29TBEpump&address_type=token&type=5m&time_from=1738912820&time_to=1739101520 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'FFgfStKwuF3DSxEeogA69FNkPrkb7XDA5Tw29TBEpump'.
# Fetching token historical prices:  12%|█▏        | 9/77 [00:04<00:30,  2.21token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'CRAMvzDsSpXYsFpcoDr6vFLJMBeftez1E7277xwPpump' from 1738912821 to 1739101521.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=CRAMvzDsSpXYsFpcoDr6vFLJMBeftez1E7277xwPpump&address_type=token&type=5m&time_from=1738912821&time_to=1739101521 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'CRAMvzDsSpXYsFpcoDr6vFLJMBeftez1E7277xwPpump'.
# Fetching token historical prices:  13%|█▎        | 10/77 [00:04<00:30,  2.17token/s]INFO:__main__:fetch_historical_price: Requesting history for token '9b8jL2wcVjBFpieC5TUR76BDJ6sW8Eghd3fyq5VJmzir' from 1738912821 to 1739101521.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=9b8jL2wcVjBFpieC5TUR76BDJ6sW8Eghd3fyq5VJmzir&address_type=token&type=5m&time_from=1738912821&time_to=1739101521 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '9b8jL2wcVjBFpieC5TUR76BDJ6sW8Eghd3fyq5VJmzir'.
# Fetching token historical prices:  14%|█▍        | 11/77 [00:05<00:29,  2.25token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'HNg5PYJmtqcmzXrv6S9zP1CDKk5BgDuyFBxbvNApump' from 1738912822 to 1739101522.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=HNg5PYJmtqcmzXrv6S9zP1CDKk5BgDuyFBxbvNApump&address_type=token&type=5m&time_from=1738912822&time_to=1739101522 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'HNg5PYJmtqcmzXrv6S9zP1CDKk5BgDuyFBxbvNApump'.
# Fetching token historical prices:  16%|█▌        | 12/77 [00:05<00:29,  2.22token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'jUfwXi6BWechD13bzp1R1h2AR3bSKuGkJd5qJmppump' from 1738912822 to 1739101522.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=jUfwXi6BWechD13bzp1R1h2AR3bSKuGkJd5qJmppump&address_type=token&type=5m&time_from=1738912822&time_to=1739101522 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 507 price snapshots for token 'jUfwXi6BWechD13bzp1R1h2AR3bSKuGkJd5qJmppump'.
# Fetching token historical prices:  17%|█▋        | 13/77 [00:06<00:31,  2.01token/s]INFO:__main__:fetch_historical_price: Requesting history for token '2RuDRx9RAcXrSoLupeMLGuBay6w5Q1nUrdPySjA3pump' from 1738912823 to 1739101523.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=2RuDRx9RAcXrSoLupeMLGuBay6w5Q1nUrdPySjA3pump&address_type=token&type=5m&time_from=1738912823&time_to=1739101523 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 93 price snapshots for token '2RuDRx9RAcXrSoLupeMLGuBay6w5Q1nUrdPySjA3pump'.
# Fetching token historical prices:  18%|█▊        | 14/77 [00:06<00:29,  2.13token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'HaP8r3ksG76PhQLTqR8FYBeNiQpejcFbQmiHbg787Ut1' from 1738912823 to 1739101523.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=HaP8r3ksG76PhQLTqR8FYBeNiQpejcFbQmiHbg787Ut1&address_type=token&type=5m&time_from=1738912823&time_to=1739101523 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'HaP8r3ksG76PhQLTqR8FYBeNiQpejcFbQmiHbg787Ut1'.
# Fetching token historical prices:  19%|█▉        | 15/77 [00:06<00:28,  2.16token/s]INFO:__main__:fetch_historical_price: Requesting history for token '8bPDYeH2Xqmmkp2LeSvgagPzLXUnGMa2yLVVTc41YCJ9' from 1738912824 to 1739101524.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=8bPDYeH2Xqmmkp2LeSvgagPzLXUnGMa2yLVVTc41YCJ9&address_type=token&type=5m&time_from=1738912824&time_to=1739101524 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 29 price snapshots for token '8bPDYeH2Xqmmkp2LeSvgagPzLXUnGMa2yLVVTc41YCJ9'.
# Fetching token historical prices:  21%|██        | 16/77 [00:07<00:26,  2.27token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'CFrd1PnphJcNiGHtL3QYLb2Fvs1aBbJfah3FqgNPpump' from 1738912824 to 1739101524.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=CFrd1PnphJcNiGHtL3QYLb2Fvs1aBbJfah3FqgNPpump&address_type=token&type=5m&time_from=1738912824&time_to=1739101524 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'CFrd1PnphJcNiGHtL3QYLb2Fvs1aBbJfah3FqgNPpump'.
# Fetching token historical prices:  22%|██▏       | 17/77 [00:07<00:26,  2.26token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263' from 1738912825 to 1739101525.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263&address_type=token&type=5m&time_from=1738912825&time_to=1739101525 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263'.
# Fetching token historical prices:  23%|██▎       | 18/77 [00:08<00:26,  2.27token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm' from 1738912825 to 1739101525.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm&address_type=token&type=5m&time_from=1738912825&time_to=1739101525 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm'.
# Fetching token historical prices:  25%|██▍       | 19/77 [00:08<00:26,  2.20token/s]INFO:__main__:fetch_historical_price: Requesting history for token '7GCihgDB8fe6KNjn2MYtkzZcRjQy3t9GHdC8uHYmW2hr' from 1738912826 to 1739101526.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=7GCihgDB8fe6KNjn2MYtkzZcRjQy3t9GHdC8uHYmW2hr&address_type=token&type=5m&time_from=1738912826&time_to=1739101526 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '7GCihgDB8fe6KNjn2MYtkzZcRjQy3t9GHdC8uHYmW2hr'.
# Fetching token historical prices:  26%|██▌       | 20/77 [00:09<00:25,  2.22token/s]INFO:__main__:fetch_historical_price: Requesting history for token '69G8CpUVZAxbPMiEBrfCCCH445NwFxH6PzVL693Xpump' from 1738912826 to 1739101526.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=69G8CpUVZAxbPMiEBrfCCCH445NwFxH6PzVL693Xpump&address_type=token&type=5m&time_from=1738912826&time_to=1739101526 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '69G8CpUVZAxbPMiEBrfCCCH445NwFxH6PzVL693Xpump'.
# Fetching token historical prices:  27%|██▋       | 21/77 [00:09<00:26,  2.15token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'EgMF2iEbKv984fWtqakZ12k4VQvJubTNnU2Y9durpump' from 1738912826 to 1739101526.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=EgMF2iEbKv984fWtqakZ12k4VQvJubTNnU2Y9durpump&address_type=token&type=5m&time_from=1738912826&time_to=1739101526 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 281 price snapshots for token 'EgMF2iEbKv984fWtqakZ12k4VQvJubTNnU2Y9durpump'.
# Fetching token historical prices:  29%|██▊       | 22/77 [00:10<00:25,  2.17token/s]INFO:__main__:fetch_historical_price: Requesting history for token '6p6xgHyF7AeE6TZkSmFsko444wqoP15icUSqi2jfGiPN' from 1738912827 to 1739101527.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=6p6xgHyF7AeE6TZkSmFsko444wqoP15icUSqi2jfGiPN&address_type=token&type=5m&time_from=1738912827&time_to=1739101527 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '6p6xgHyF7AeE6TZkSmFsko444wqoP15icUSqi2jfGiPN'.
# Fetching token historical prices:  30%|██▉       | 23/77 [00:10<00:24,  2.19token/s]INFO:__main__:fetch_historical_price: Requesting history for token '7mHCx9iXPJ7EJDbDAUGmej39Kme8cxZfeVi1EAvEpump' from 1738912827 to 1739101527.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=7mHCx9iXPJ7EJDbDAUGmej39Kme8cxZfeVi1EAvEpump&address_type=token&type=5m&time_from=1738912827&time_to=1739101527 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '7mHCx9iXPJ7EJDbDAUGmej39Kme8cxZfeVi1EAvEpump'.
# Fetching token historical prices:  31%|███       | 24/77 [00:11<00:24,  2.21token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'CboMcTUYUcy9E6B3yGdFn6aEsGUnYV6yWeoeukw6pump' from 1738912828 to 1739101528.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=CboMcTUYUcy9E6B3yGdFn6aEsGUnYV6yWeoeukw6pump&address_type=token&type=5m&time_from=1738912828&time_to=1739101528 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'CboMcTUYUcy9E6B3yGdFn6aEsGUnYV6yWeoeukw6pump'.
# Fetching token historical prices:  32%|███▏      | 25/77 [00:11<00:24,  2.13token/s]INFO:__main__:fetch_historical_price: Requesting history for token '69kdRLyP5DTRkpHraaSZAQbWmAwzF9guKjZfzMXzcbAs' from 1738912828 to 1739101528.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=69kdRLyP5DTRkpHraaSZAQbWmAwzF9guKjZfzMXzcbAs&address_type=token&type=5m&time_from=1738912828&time_to=1739101528 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '69kdRLyP5DTRkpHraaSZAQbWmAwzF9guKjZfzMXzcbAs'.
# Fetching token historical prices:  34%|███▍      | 26/77 [00:11<00:23,  2.19token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'JUPyiwrYJFskUPiHa7hkeR8VUtAeFoSYbKedZNsDvCN' from 1738912829 to 1739101529.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=JUPyiwrYJFskUPiHa7hkeR8VUtAeFoSYbKedZNsDvCN&address_type=token&type=5m&time_from=1738912829&time_to=1739101529 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'JUPyiwrYJFskUPiHa7hkeR8VUtAeFoSYbKedZNsDvCN'.
# Fetching token historical prices:  35%|███▌      | 27/77 [00:12<00:23,  2.17token/s]INFO:__main__:fetch_historical_price: Requesting history for token '3NZ9JMVBmGAqocybic2c7LQCJScmgsAZ6vQqTDzcqmJh' from 1738912829 to 1739101529.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=3NZ9JMVBmGAqocybic2c7LQCJScmgsAZ6vQqTDzcqmJh&address_type=token&type=5m&time_from=1738912829&time_to=1739101529 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '3NZ9JMVBmGAqocybic2c7LQCJScmgsAZ6vQqTDzcqmJh'.
# Fetching token historical prices:  36%|███▋      | 28/77 [00:12<00:22,  2.19token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'AxriehR6Xw3adzHopnvMn7GcpRFcD41ddpiTWMg6pump' from 1738912830 to 1739101530.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=AxriehR6Xw3adzHopnvMn7GcpRFcD41ddpiTWMg6pump&address_type=token&type=5m&time_from=1738912830&time_to=1739101530 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 459 price snapshots for token 'AxriehR6Xw3adzHopnvMn7GcpRFcD41ddpiTWMg6pump'.
# Fetching token historical prices:  38%|███▊      | 29/77 [00:13<00:22,  2.14token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'Bksfke6KWgpftafmbR3E9J4wHr4bBfKDrztXN6etpump' from 1738912830 to 1739101530.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=Bksfke6KWgpftafmbR3E9J4wHr4bBfKDrztXN6etpump&address_type=token&type=5m&time_from=1738912830&time_to=1739101530 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'Bksfke6KWgpftafmbR3E9J4wHr4bBfKDrztXN6etpump'.
# Fetching token historical prices:  39%|███▉      | 30/77 [00:13<00:21,  2.16token/s]INFO:__main__:fetch_historical_price: Requesting history for token '5YqckGEkWHJmp9LW5aUF2uJrdUbMJaHcYnGjA8M7Ebw8' from 1738912831 to 1739101531.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=5YqckGEkWHJmp9LW5aUF2uJrdUbMJaHcYnGjA8M7Ebw8&address_type=token&type=5m&time_from=1738912831&time_to=1739101531 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '5YqckGEkWHJmp9LW5aUF2uJrdUbMJaHcYnGjA8M7Ebw8'.
# Fetching token historical prices:  40%|████      | 31/77 [00:14<00:21,  2.18token/s]INFO:__main__:fetch_historical_price: Requesting history for token '2ru87k7yAZnDRsnqVpgJYETFgqVApuBcwB2xDb19pump' from 1738912831 to 1739101531.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=2ru87k7yAZnDRsnqVpgJYETFgqVApuBcwB2xDb19pump&address_type=token&type=5m&time_from=1738912831&time_to=1739101531 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '2ru87k7yAZnDRsnqVpgJYETFgqVApuBcwB2xDb19pump'.
# Fetching token historical prices:  42%|████▏     | 32/77 [00:14<00:21,  2.10token/s]INFO:__main__:fetch_historical_price: Requesting history for token '9xb4jRNU4MYgfu87mkRFFjSZN9MTL5gayXHhxpKUpump' from 1738912832 to 1739101532.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=9xb4jRNU4MYgfu87mkRFFjSZN9MTL5gayXHhxpKUpump&address_type=token&type=5m&time_from=1738912832&time_to=1739101532 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '9xb4jRNU4MYgfu87mkRFFjSZN9MTL5gayXHhxpKUpump'.
# Fetching token historical prices:  43%|████▎     | 33/77 [00:15<00:20,  2.14token/s]INFO:__main__:fetch_historical_price: Requesting history for token '8oEHKQYYYavrfVXnF8qAHmJF18DWJwnvhwz6Wqktpump' from 1738912832 to 1739101532.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=8oEHKQYYYavrfVXnF8qAHmJF18DWJwnvhwz6Wqktpump&address_type=token&type=5m&time_from=1738912832&time_to=1739101532 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 125 price snapshots for token '8oEHKQYYYavrfVXnF8qAHmJF18DWJwnvhwz6Wqktpump'.
# Fetching token historical prices:  44%|████▍     | 34/77 [00:15<00:19,  2.22token/s]INFO:__main__:fetch_historical_price: Requesting history for token '9UEN2kKhHxnaK14ZYFvog2hezajxAke9xCiS2hnppump' from 1738912832 to 1739101532.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=9UEN2kKhHxnaK14ZYFvog2hezajxAke9xCiS2hnppump&address_type=token&type=5m&time_from=1738912832&time_to=1739101532 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '9UEN2kKhHxnaK14ZYFvog2hezajxAke9xCiS2hnppump'.
# Fetching token historical prices:  45%|████▌     | 35/77 [00:16<00:19,  2.21token/s]INFO:__main__:fetch_historical_price: Requesting history for token '7vfCXTUXx5WJV5JADk17DUJ4ksgau7utNKj4b963voxs' from 1738912833 to 1739101533.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=7vfCXTUXx5WJV5JADk17DUJ4ksgau7utNKj4b963voxs&address_type=token&type=5m&time_from=1738912833&time_to=1739101533 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '7vfCXTUXx5WJV5JADk17DUJ4ksgau7utNKj4b963voxs'.
# Fetching token historical prices:  47%|████▋     | 36/77 [00:16<00:19,  2.14token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'FasH397CeZLNYWkd3wWK9vrmjd1z93n3b59DssRXpump' from 1738912833 to 1739101533.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=FasH397CeZLNYWkd3wWK9vrmjd1z93n3b59DssRXpump&address_type=token&type=5m&time_from=1738912833&time_to=1739101533 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'FasH397CeZLNYWkd3wWK9vrmjd1z93n3b59DssRXpump'.
# Fetching token historical prices:  48%|████▊     | 37/77 [00:17<00:18,  2.14token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'FcsgEKX5cu2xeYQeQ5GiWKvPCEYmdBtPRTvYNFrLxoxo' from 1738912834 to 1739101534.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=FcsgEKX5cu2xeYQeQ5GiWKvPCEYmdBtPRTvYNFrLxoxo&address_type=token&type=5m&time_from=1738912834&time_to=1739101534 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 164 price snapshots for token 'FcsgEKX5cu2xeYQeQ5GiWKvPCEYmdBtPRTvYNFrLxoxo'.
# Fetching token historical prices:  49%|████▉     | 38/77 [00:17<00:18,  2.17token/s]INFO:__main__:fetch_historical_price: Requesting history for token '22Xeo6diWfJrScaoVFzgkwzrCByPukK45fdwkJyrpump' from 1738912834 to 1739101534.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=22Xeo6diWfJrScaoVFzgkwzrCByPukK45fdwkJyrpump&address_type=token&type=5m&time_from=1738912834&time_to=1739101534 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '22Xeo6diWfJrScaoVFzgkwzrCByPukK45fdwkJyrpump'.
# Fetching token historical prices:  51%|█████     | 39/77 [00:17<00:17,  2.14token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump' from 1738912835 to 1739101535.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump&address_type=token&type=5m&time_from=1738912835&time_to=1739101535 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump'.
# Fetching token historical prices:  52%|█████▏    | 40/77 [00:18<00:17,  2.15token/s]INFO:__main__:fetch_historical_price: Requesting history for token '4FfTcjSySNCK5FMncfPYMFyp4QpFR4GERDKnfECr7ntg' from 1738912835 to 1739101535.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=4FfTcjSySNCK5FMncfPYMFyp4QpFR4GERDKnfECr7ntg&address_type=token&type=5m&time_from=1738912835&time_to=1739101535 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '4FfTcjSySNCK5FMncfPYMFyp4QpFR4GERDKnfECr7ntg'.
# Fetching token historical prices:  53%|█████▎    | 41/77 [00:18<00:16,  2.17token/s]INFO:__main__:fetch_historical_price: Requesting history for token '2z1p8xCEjRzpBHjXWrx4tJnz7BFL6z7NnvbCxH7bpump' from 1738912836 to 1739101536.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=2z1p8xCEjRzpBHjXWrx4tJnz7BFL6z7NnvbCxH7bpump&address_type=token&type=5m&time_from=1738912836&time_to=1739101536 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '2z1p8xCEjRzpBHjXWrx4tJnz7BFL6z7NnvbCxH7bpump'.
# Fetching token historical prices:  55%|█████▍    | 42/77 [00:19<00:16,  2.06token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'BXebtR4k2WiaZ1HJmxcZkoCdxSBx1g1xnEpVra9Ppump' from 1738912836 to 1739101536.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=BXebtR4k2WiaZ1HJmxcZkoCdxSBx1g1xnEpVra9Ppump&address_type=token&type=5m&time_from=1738912836&time_to=1739101536 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'BXebtR4k2WiaZ1HJmxcZkoCdxSBx1g1xnEpVra9Ppump'.
# Fetching token historical prices:  56%|█████▌    | 43/77 [00:19<00:16,  2.09token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'J3NKxxXZcnNiMjKw9hYb2K4LUxgwB6t1FtPtQVsv3KFr' from 1738912837 to 1739101537.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=J3NKxxXZcnNiMjKw9hYb2K4LUxgwB6t1FtPtQVsv3KFr&address_type=token&type=5m&time_from=1738912837&time_to=1739101537 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'J3NKxxXZcnNiMjKw9hYb2K4LUxgwB6t1FtPtQVsv3KFr'.
# Fetching token historical prices:  57%|█████▋    | 44/77 [00:20<00:16,  2.05token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'nosXBVoaCTtYdLvKY6Csb4AC8JCdQKKAaWYtx2ZMoo7' from 1738912837 to 1739101537.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=nosXBVoaCTtYdLvKY6Csb4AC8JCdQKKAaWYtx2ZMoo7&address_type=token&type=5m&time_from=1738912837&time_to=1739101537 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'nosXBVoaCTtYdLvKY6Csb4AC8JCdQKKAaWYtx2ZMoo7'.
# Fetching token historical prices:  58%|█████▊    | 45/77 [00:20<00:15,  2.03token/s]INFO:__main__:fetch_historical_price: Requesting history for token '2mhszy8YHwqs1fxruVHQQAUmNcfq31mtkmYYtNZNpump' from 1738912838 to 1739101538.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=2mhszy8YHwqs1fxruVHQQAUmNcfq31mtkmYYtNZNpump&address_type=token&type=5m&time_from=1738912838&time_to=1739101538 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '2mhszy8YHwqs1fxruVHQQAUmNcfq31mtkmYYtNZNpump'.
# Fetching token historical prices:  60%|█████▉    | 46/77 [00:21<00:15,  2.05token/s]INFO:__main__:fetch_historical_price: Requesting history for token '74SBV4zDXxTRgv1pEMoECskKBkZHc2yGPnc7GYVepump' from 1738912838 to 1739101538.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=74SBV4zDXxTRgv1pEMoECskKBkZHc2yGPnc7GYVepump&address_type=token&type=5m&time_from=1738912838&time_to=1739101538 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '74SBV4zDXxTRgv1pEMoECskKBkZHc2yGPnc7GYVepump'.
# Fetching token historical prices:  61%|██████    | 47/77 [00:21<00:14,  2.12token/s]INFO:__main__:fetch_historical_price: Requesting history for token '7iagMTDPfNSR5zVcERT1To7A9eaQoz58dJAh42EMHcCC' from 1738912839 to 1739101539.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=7iagMTDPfNSR5zVcERT1To7A9eaQoz58dJAh42EMHcCC&address_type=token&type=5m&time_from=1738912839&time_to=1739101539 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '7iagMTDPfNSR5zVcERT1To7A9eaQoz58dJAh42EMHcCC'.
# Fetching token historical prices:  62%|██████▏   | 48/77 [00:22<00:13,  2.19token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'J9KTtypTWfSp912harLxd9jGz8iwsnqGmD5Yqgoopump' from 1738912839 to 1739101539.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=J9KTtypTWfSp912harLxd9jGz8iwsnqGmD5Yqgoopump&address_type=token&type=5m&time_from=1738912839&time_to=1739101539 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'J9KTtypTWfSp912harLxd9jGz8iwsnqGmD5Yqgoopump'.
# Fetching token historical prices:  64%|██████▎   | 49/77 [00:22<00:12,  2.26token/s]INFO:__main__:fetch_historical_price: Requesting history for token '2zMMhcVQEXDtdE6vsFS7S7D5oUodfJHE8vd1gnBouauv' from 1738912839 to 1739101539.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=2zMMhcVQEXDtdE6vsFS7S7D5oUodfJHE8vd1gnBouauv&address_type=token&type=5m&time_from=1738912839&time_to=1739101539 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '2zMMhcVQEXDtdE6vsFS7S7D5oUodfJHE8vd1gnBouauv'.
# Fetching token historical prices:  65%|██████▍   | 50/77 [00:23<00:11,  2.25token/s]INFO:__main__:fetch_historical_price: Requesting history for token '2RBko3xoz56aH69isQMUpzZd9NYHahhwC23A5F3Spkin' from 1738912840 to 1739101540.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=2RBko3xoz56aH69isQMUpzZd9NYHahhwC23A5F3Spkin&address_type=token&type=5m&time_from=1738912840&time_to=1739101540 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '2RBko3xoz56aH69isQMUpzZd9NYHahhwC23A5F3Spkin'.
# Fetching token historical prices:  66%|██████▌   | 51/77 [00:23<00:11,  2.27token/s]INFO:__main__:fetch_historical_price: Requesting history for token '4ccF7FpjTFZBWRZogCftU5aLd5NQMgJpyvrfDfwp2hEu' from 1738912840 to 1739101540.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=4ccF7FpjTFZBWRZogCftU5aLd5NQMgJpyvrfDfwp2hEu&address_type=token&type=5m&time_from=1738912840&time_to=1739101540 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '4ccF7FpjTFZBWRZogCftU5aLd5NQMgJpyvrfDfwp2hEu'.
# Fetching token historical prices:  68%|██████▊   | 52/77 [00:23<00:10,  2.32token/s]INFO:__main__:fetch_historical_price: Requesting history for token '2eXamy7t3kvKhfV6aJ6Uwe3eh8cuREFcTKs1mFKZpump' from 1738912841 to 1739101541.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=2eXamy7t3kvKhfV6aJ6Uwe3eh8cuREFcTKs1mFKZpump&address_type=token&type=5m&time_from=1738912841&time_to=1739101541 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '2eXamy7t3kvKhfV6aJ6Uwe3eh8cuREFcTKs1mFKZpump'.
# Fetching token historical prices:  69%|██████▉   | 53/77 [00:24<00:10,  2.31token/s]INFO:__main__:fetch_historical_price: Requesting history for token '8CzPPqenpfRXvjE5DHfE3kMDgJhHwWZ1WXRzs44KsamW' from 1738912841 to 1739101541.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=8CzPPqenpfRXvjE5DHfE3kMDgJhHwWZ1WXRzs44KsamW&address_type=token&type=5m&time_from=1738912841&time_to=1739101541 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '8CzPPqenpfRXvjE5DHfE3kMDgJhHwWZ1WXRzs44KsamW'.
# Fetching token historical prices:  70%|███████   | 54/77 [00:24<00:10,  2.26token/s]INFO:__main__:fetch_historical_price: Requesting history for token '6ogzHhzdrQr9Pgv6hZ2MNze7UrzBMAFyBBWUYp1Fhitx' from 1738912842 to 1739101542.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=6ogzHhzdrQr9Pgv6hZ2MNze7UrzBMAFyBBWUYp1Fhitx&address_type=token&type=5m&time_from=1738912842&time_to=1739101542 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '6ogzHhzdrQr9Pgv6hZ2MNze7UrzBMAFyBBWUYp1Fhitx'.
# Fetching token historical prices:  71%|███████▏  | 55/77 [00:25<00:10,  2.15token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'Zc4uJVrHC2APe9qKwBD11Gg4BbvQr3naM8f7Wiopump' from 1738912842 to 1739101542.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=Zc4uJVrHC2APe9qKwBD11Gg4BbvQr3naM8f7Wiopump&address_type=token&type=5m&time_from=1738912842&time_to=1739101542 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'Zc4uJVrHC2APe9qKwBD11Gg4BbvQr3naM8f7Wiopump'.
# Fetching token historical prices:  73%|███████▎  | 56/77 [00:25<00:09,  2.18token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'whispF7G9DHaojYHe2cdhRX5EMJzGBdqq7R57kL6inL' from 1738912843 to 1739101543.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=whispF7G9DHaojYHe2cdhRX5EMJzGBdqq7R57kL6inL&address_type=token&type=5m&time_from=1738912843&time_to=1739101543 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'whispF7G9DHaojYHe2cdhRX5EMJzGBdqq7R57kL6inL'.
# Fetching token historical prices:  74%|███████▍  | 57/77 [00:26<00:09,  2.15token/s]INFO:__main__:fetch_historical_price: Requesting history for token '9DHe3pycTuymFk4H4bbPoAJ4hQrr2kaLDF6J6aAKpump' from 1738912843 to 1739101543.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=9DHe3pycTuymFk4H4bbPoAJ4hQrr2kaLDF6J6aAKpump&address_type=token&type=5m&time_from=1738912843&time_to=1739101543 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '9DHe3pycTuymFk4H4bbPoAJ4hQrr2kaLDF6J6aAKpump'.
# ...
# INFO:__main__:fetch_historical_price: Retrieved 147 price snapshots for token 'FHKiJEg2zmhv9DEeaXMSZa7R4P8BPFX5VTRrzrtJpump'.
# Fetching token historical prices:  83%|████████▎ | 64/77 [00:29<00:06,  2.09token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v' from 1738912846 to 1739101546.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v&address_type=token&type=5m&time_from=1738912846&time_to=1739101546 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v'.
# Fetching token historical prices:  84%|████████▍ | 65/77 [00:30<00:05,  2.11token/s]INFO:__main__:fetch_historical_price: Requesting history for token '4TM1ZL64KjyxeffDLzaX7Eybg125qRpLF4tuzvutCu3M' from 1738912847 to 1739101547.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=4TM1ZL64KjyxeffDLzaX7Eybg125qRpLF4tuzvutCu3M&address_type=token&type=5m&time_from=1738912847&time_to=1739101547 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '4TM1ZL64KjyxeffDLzaX7Eybg125qRpLF4tuzvutCu3M'.
# Fetching token historical prices:  86%|████████▌ | 66/77 [00:30<00:05,  2.13token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'Ai4CL1SAxVRigxQFwBH8S2JkuL7EqrdiGwTC7JpCpump' from 1738912847 to 1739101547.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=Ai4CL1SAxVRigxQFwBH8S2JkuL7EqrdiGwTC7JpCpump&address_type=token&type=5m&time_from=1738912847&time_to=1739101547 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'Ai4CL1SAxVRigxQFwBH8S2JkuL7EqrdiGwTC7JpCpump'.
# Fetching token historical prices:  87%|████████▋ | 67/77 [00:31<00:04,  2.14token/s]INFO:__main__:fetch_historical_price: Requesting history for token '5z3EqYQo9HiCEs3R84RCDMu2n7anpDMxRhdK8PSWmrRC' from 1738912848 to 1739101548.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=5z3EqYQo9HiCEs3R84RCDMu2n7anpDMxRhdK8PSWmrRC&address_type=token&type=5m&time_from=1738912848&time_to=1739101548 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '5z3EqYQo9HiCEs3R84RCDMu2n7anpDMxRhdK8PSWmrRC'.
# Fetching token historical prices:  88%|████████▊ | 68/77 [00:31<00:04,  2.13token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'eL5fUxj2J4CiQsmW85k5FG9DvuQjjUoBHoQBi2Kpump' from 1738912848 to 1739101548.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=eL5fUxj2J4CiQsmW85k5FG9DvuQjjUoBHoQBi2Kpump&address_type=token&type=5m&time_from=1738912848&time_to=1739101548 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'eL5fUxj2J4CiQsmW85k5FG9DvuQjjUoBHoQBi2Kpump'.
# Fetching token historical prices:  90%|████████▉ | 69/77 [00:31<00:03,  2.11token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'H4phNbsqjV5rqk8u6FUACTLB6rNZRTAPGnBb8KXJpump' from 1738912849 to 1739101549.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=H4phNbsqjV5rqk8u6FUACTLB6rNZRTAPGnBb8KXJpump&address_type=token&type=5m&time_from=1738912849&time_to=1739101549 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'H4phNbsqjV5rqk8u6FUACTLB6rNZRTAPGnBb8KXJpump'.
# Fetching token historical prices:  91%|█████████ | 70/77 [00:32<00:03,  2.07token/s]INFO:__main__:fetch_historical_price: Requesting history for token '9doRRAik5gvhbEwjbZDbZR6GxXSAfdoomyJR57xKpump' from 1738912849 to 1739101549.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=9doRRAik5gvhbEwjbZDbZR6GxXSAfdoomyJR57xKpump&address_type=token&type=5m&time_from=1738912849&time_to=1739101549 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '9doRRAik5gvhbEwjbZDbZR6GxXSAfdoomyJR57xKpump'.
# Fetching token historical prices:  92%|█████████▏| 71/77 [00:32<00:02,  2.13token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'Hjw6bEcHtbHGpQr8onG3izfJY5DJiWdt7uk2BfdSpump' from 1738912850 to 1739101550.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=Hjw6bEcHtbHGpQr8onG3izfJY5DJiWdt7uk2BfdSpump&address_type=token&type=5m&time_from=1738912850&time_to=1739101550 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'Hjw6bEcHtbHGpQr8onG3izfJY5DJiWdt7uk2BfdSpump'.
# Fetching token historical prices:  94%|█████████▎| 72/77 [00:33<00:02,  2.13token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'AaWVpk6eZbgBfVbq1UfXw3EXBmAvw4QXov1xHuG7pump' from 1738912850 to 1739101550.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=AaWVpk6eZbgBfVbq1UfXw3EXBmAvw4QXov1xHuG7pump&address_type=token&type=5m&time_from=1738912850&time_to=1739101550 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'AaWVpk6eZbgBfVbq1UfXw3EXBmAvw4QXov1xHuG7pump'.
# Fetching token historical prices:  95%|█████████▍| 73/77 [00:33<00:01,  2.14token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'BEP6KhDwv7K211JtZnszNcztHBffSCgRjUuNhucopump' from 1738912851 to 1739101551.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=BEP6KhDwv7K211JtZnszNcztHBffSCgRjUuNhucopump&address_type=token&type=5m&time_from=1738912851&time_to=1739101551 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'BEP6KhDwv7K211JtZnszNcztHBffSCgRjUuNhucopump'.
# Fetching token historical prices:  96%|█████████▌| 74/77 [00:34<00:01,  2.15token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'BrZmDQwbdLXme3uaea8znLhy9Bb3fucMJmcFBuRPpump' from 1738912851 to 1739101551.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=BrZmDQwbdLXme3uaea8znLhy9Bb3fucMJmcFBuRPpump&address_type=token&type=5m&time_from=1738912851&time_to=1739101551 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'BrZmDQwbdLXme3uaea8znLhy9Bb3fucMJmcFBuRPpump'.
# Fetching token historical prices:  97%|█████████▋| 75/77 [00:34<00:00,  2.17token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB' from 1738912852 to 1739101552.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB&address_type=token&type=5m&time_from=1738912852&time_to=1739101552 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB'.
# Fetching token historical prices:  99%|█████████▊| 76/77 [00:35<00:00,  2.14token/s]INFO:__main__:fetch_historical_price: Requesting history for token '3S8qX1MsMqRbiwKg2cQyx7nis1oHMgaCuc9c4VfvVdPN' from 1738912852 to 1739101552.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=3S8qX1MsMqRbiwKg2cQyx7nis1oHMgaCuc9c4VfvVdPN&address_type=token&type=5m&time_from=1738912852&time_to=1739101552 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '3S8qX1MsMqRbiwKg2cQyx7nis1oHMgaCuc9c4VfvVdPN'.
# Fetching token historical prices: 100%|██████████| 77/77 [00:35<00:00,  2.15token/s]
# INFO:__main__:main: Processing transactions to calculate historical prices...
# Processing transactions: 100%|██████████| 208/208 [00:00<00:00, 1806.28it/s]
# INFO:__main__:main: Calculating per-transaction dollar values...
# INFO:__main__:main: Aggregating dollar values per token...
# INFO:__main__:main: Aggregated token values:
# INFO:__main__:                                           token  dollars_sold  dollars_bought
# 0   22Xeo6diWfJrScaoVFzgkwzrCByPukK45fdwkJyrpump      0.000000     3930.970406
# 1   27G8MtK7VtTcCHkpASjSDdkWWYfoqT6ggEuKidVJidD4   2936.528977     2614.842715
# 2   2KchKijPuwnwC92LPWVjFjRwB3WxKtzx9bbXZ7kRpump   2242.652560        0.000000
# 3   2RBko3xoz56aH69isQMUpzZd9NYHahhwC23A5F3Spkin      0.000000      329.750509
# 4   2RuDRx9RAcXrSoLupeMLGuBay6w5Q1nUrdPySjA3pump    277.274235        0.000000
# ..                                           ...           ...             ...
# 72   jUfwXi6BWechD13bzp1R1h2AR3bSKuGkJd5qJmppump   1693.158956        0.000000
# 73   jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v      0.000000     2034.045997
# 74   nosXBVoaCTtYdLvKY6Csb4AC8JCdQKKAaWYtx2ZMoo7   6102.522454        0.000000
# 75   pepo1CFNU2RXf7yXX7HNXazXwxsq8WrPvDHpHriwoLY      0.000000      971.964805
# 76   whispF7G9DHaojYHe2cdhRX5EMJzGBdqq7R57kL6inL      0.000000    43362.654434
#
# [77 rows x 3 columns]
# INFO:__main__:main: Merging aggregated data with token details...
# INFO:__main__:main: Formatting dollar values with comma as decimal separator...
# INFO:__main__:main: Writing final aggregated token details to Excel file...
# INFO:__main__:main: Final Excel file written successfully.
# INFO:__main__:main: Database connection closed.
#                                            token dollars_sold dollars_bought  \
# 0   22Xeo6diWfJrScaoVFzgkwzrCByPukK45fdwkJyrpump         0,00        3930,97
# 1   27G8MtK7VtTcCHkpASjSDdkWWYfoqT6ggEuKidVJidD4      2936,53        2614,84
# 2   2KchKijPuwnwC92LPWVjFjRwB3WxKtzx9bbXZ7kRpump      2242,65           0,00
# 3   2RBko3xoz56aH69isQMUpzZd9NYHahhwC23A5F3Spkin         0,00         329,75
# 4   2RuDRx9RAcXrSoLupeMLGuBay6w5Q1nUrdPySjA3pump       277,27           0,00
# ..                                           ...          ...            ...
# 72   jUfwXi6BWechD13bzp1R1h2AR3bSKuGkJd5qJmppump      1693,16           0,00
# 73   jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v         0,00        2034,05
# 74   nosXBVoaCTtYdLvKY6Csb4AC8JCdQKKAaWYtx2ZMoo7      6102,52           0,00
# 75   pepo1CFNU2RXf7yXX7HNXazXwxsq8WrPvDHpHriwoLY         0,00         971,96
# 76   whispF7G9DHaojYHe2cdhRX5EMJzGBdqq7R57kL6inL         0,00       43362,65
#
#    chainId    dexId                                                url  \
# 0   solana  raydium  https://dexscreener.com/solana/5jbknnv534djg9t...
# 1   solana  meteora  https://dexscreener.com/solana/dbtk2snkwxu9tjb...
# 2   solana  raydium  https://dexscreener.com/solana/aran3nqsk76nkhg...
# 3   solana  meteora  https://dexscreener.com/solana/bwe7mrpusypmnxp...
# 4   solana  raydium  https://dexscreener.com/solana/b6gnknavedrahtt...
# ..     ...      ...                                                ...
# 72  solana  raydium  https://dexscreener.com/solana/4rcf4gzh2o7fjm1...
# 73  solana  meteora  https://dexscreener.com/solana/5cvchrd2uh2cxhm...
# 74  solana  raydium  https://dexscreener.com/solana/cj7kd2vmzwsrwkb...
# 75  solana  meteora  https://dexscreener.com/solana/em4hnb5haokyucc...
# 76  solana  raydium  https://dexscreener.com/solana/7harasaftuyfhq9...
#
#                                      pairAddress  labels  \
# 0   5JbknNv534djG9TeCUMpLevedino2c1WrYB9pqGkyqLe      []
# 1   DbTk2SNKWxu9TJbPzmK9HcQCAmraBCFb5VMo8Svwh34z  [DLMM]
# 2   AraN3NQsK76nkHGjZSV1eVTSN4W32CJhgEZiTq6XvhR3      []
# 3   BwE7MRPusYpmnXPoyoEKY7UbkYBSbTi6M7ME7DPc83jV  [DLMM]
# 4   B6GNKnaVeDrahttqvKyf58GUQYsqyQif6LdxaxHpynnv      []
# ..                                           ...     ...
# 72  4rCf4gZH2o7fJm1cdQSL3ypePRWj4bxGKDLkGq2pMzuL      []
# 73  5cvcHrD2uh2CXhmZnMHsTVWJW1qtyikVaN3MCJNaCKMh  [DLMM]
# 74  Cj7kD2VmzwSrwKBieuYYbjPEvr8gwhNi76KUESbGDNfF      []
# 75  EM4HnB5hAokYuCcgJh4pzH5hbKAHLhk73KkeXwNwevyN   [DYN]
# 76  7HARASAFTUyfhq9wNZrRdEYqMf7kwJSQ4tpJPAbs5jRE      []
#
#                                baseToken_address      baseToken_name  ...  \
# 0   22Xeo6diWfJrScaoVFzgkwzrCByPukK45fdwkJyrpump        MUSTAAAAAARD  ...
# 1   27G8MtK7VtTcCHkpASjSDdkWWYfoqT6ggEuKidVJidD4    Jupiter Perps LP  ...
# 2   2KchKijPuwnwC92LPWVjFjRwB3WxKtzx9bbXZ7kRpump           Fukupuku   ...
# 3   2RBko3xoz56aH69isQMUpzZd9NYHahhwC23A5F3Spkin             PUMPKIN  ...
# 4   2RuDRx9RAcXrSoLupeMLGuBay6w5Q1nUrdPySjA3pump        Dave Fartnoy  ...
# ..                                           ...                 ...  ...
# 72   jUfwXi6BWechD13bzp1R1h2AR3bSKuGkJd5qJmppump          Marsh Coin  ...
# 73   jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v  Jupiter Staked SOL  ...
# 74   nosXBVoaCTtYdLvKY6Csb4AC8JCdQKKAaWYtx2ZMoo7              Nosana  ...
# 75   pepo1CFNU2RXf7yXX7HNXazXwxsq8WrPvDHpHriwoLY                PEPO  ...
# 76   whispF7G9DHaojYHe2cdhRX5EMJzGBdqq7R57kL6inL               WHISP  ...
#
#    priceChange_m5 priceChange_h1 priceChange_h6 priceChange_h24 liquidity_usd  \
# 0           -0.26           0.55          12.02           49.17     450382.42
# 1           -0.12          -0.04          -0.87            2.08     402427.02
# 2           -0.07           0.20           3.76            8.23     372166.98
# 3           -0.69           7.89           4.52           51.47      24986.66
# 4           -1.54          31.87         142.00          161.00      65692.79
# ..            ...            ...            ...             ...           ...
# 72           5.93         -64.26         -59.72          -92.39      35749.93
# 73           0.00           0.31          -2.16            4.89    1350663.55
# 74          -0.50          -0.52          -0.40            4.58    1834697.57
# 75           0.00           5.19           0.09           -7.79     513717.14
# 76          -1.41          -3.30          19.21          277.00    1053380.09
#
#    liquidity_base  liquidity_quote         fdv   marketCap  pairCreatedAt
# 0    8.630894e+07       1113.14940     2611107     2611107  1732334608000
# 1    6.891500e+04      94825.00000  1642377625  1642377625  1708717233000
# 2    3.336107e+07        921.09164     5583113     5583113  1731434763000
# 3    4.235280e+05         73.50880    23928046    22490986  1738140160000
# 4    1.381150e+08        162.68740      237641      237641  1739079791000
# ..            ...              ...         ...         ...            ...
# 72   3.094274e+08         88.29150       57946       57946  1738950008000
# 73   1.862588e+03       3946.32710   801522209   804031901  1718518281000
# 74   5.459570e+05     918495.00000   167815438   139958151  1669606545000
# 75   4.326299e+07       1265.82610     5944051     5944051  1736021181000
# 76   3.162203e+07       2612.72700    16635611    16635611  1736558874000
#
# [77 rows x 38 columns]

# %%
import logging
import requests
import pandas as pd
import time
from time import sleep
from tqdm import tqdm  # progress bar package
from processors.update_tokens import main as update_tokens_main
import sys
from db.connection import DatabaseConnection
from db.queries import DatabaseQueries
from config import load_config
import random
import os
from datetime import datetime

# Configure logging globally
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")
logger = logging.getLogger(__name__)

# -------------------------------------------------------------------
def fetch_historical_price(token_mint, api_key):
    """
    Fetch the historical price data for a given token using the Birdeye API endpoint
    /defi/history_price. The API call requests the price history from:
        time_from = now - 188700 (seconds)
        time_to   = now

    Returns a DataFrame with historical snapshots sorted by unixTime or None if not found.
    """
    now = int(time.time())
    time_from = now - 188700  # 188700 seconds before now
    url = f"https://public-api.birdeye.so/defi/history_price?address={token_mint}&address_type=token&type=5m&time_from={time_from}&time_to={now}"
    logger.info(f"fetch_historical_price: Requesting history for token '{token_mint}' from {time_from} to {now}.")
    headers = {
        "accept": "application/json",
        "x-chain": "solana",
        "X-API-KEY": api_key
    }
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        data = response.json()
        if data.get("success") is True:
            items = data.get("data", {}).get("items", [])
            if items:
                df = pd.DataFrame(items)
                df = df.sort_values("unixTime")
                logger.info(f"fetch_historical_price: Retrieved {len(df)} price snapshots for token '{token_mint}'.")
                return df
            else:
                logger.error(f"fetch_historical_price: No items found in API response for token '{token_mint}'. Response: {data}")
                return None
        else:
            logger.error(f"fetch_historical_price: API returned error for token '{token_mint}'. Response: {data}")
            return None
    except requests.RequestException as e:
        logger.error(f"fetch_historical_price: Request error for token '{token_mint}': {e}")
        return None

# -------------------------------------------------------------------
def fetch_token_details(chain_id, token_addresses, api_key):
    """
    Fetch token details from the Birdeye token overview endpoint.
    For each token address, it sends a GET request to:
      https://public-api.birdeye.so/defi/token_overview?address={token}
    The chain is specified in the request headers.

    Returns a DataFrame containing the details for all tokens.
    """
    logger.info(f"fetch_token_details: Starting to fetch details for {len(token_addresses)} tokens on chain '{chain_id}' using Birdeye API.")
    token_details_list = []
    # Filter out any None values
    token_addresses = [address for address in token_addresses if address is not None]
    for token in tqdm(token_addresses, desc='Fetching token details', unit='token'):
        url = f"https://public-api.birdeye.so/defi/token_overview?address={token}"
        headers = {
            "accept": "application/json",
            "x-chain": chain_id,
            "X-API-KEY": api_key
        }
        logger.info(f"fetch_token_details: Fetching details for token: {token}")
        try:
            response = requests.get(url, headers=headers)
            response.raise_for_status()
            data = response.json()
            if data.get("success") is True:
                token_data = data.get("data", {})
                # Ensure the 'address' field exists for merging later.
                if "address" not in token_data:
                    token_data["address"] = token
                token_details_list.append(token_data)
                logger.info(f"fetch_token_details: Retrieved details for token: {token}")
            else:
                logger.error(f"fetch_token_details: API returned error for token {token}. Response: {data}")
            sleep(0.2)  # avoid rate limiting
        except requests.RequestException as e:
            logger.error(f"fetch_token_details: Request error for token {token}: {e}")
            sleep(0.2)
    token_details_df = pd.DataFrame(token_details_list)
    logger.info("fetch_token_details: Finished fetching all token details.")
    return token_details_df

# -------------------------------------------------------------------
def get_closest_price(token, block_time, token_history_data):
    """
    Given a token and a block_time, look up the historical price data for that token
    (as returned by fetch_historical_price) and return the price ('value') from the
    snapshot with the smallest time difference to block_time.
    """
    df = token_history_data.get(token)
    if df is None or df.empty:
        logger.warning(f"get_closest_price: No historical data available for token {token}.")
        return None
    # Calculate the absolute time difference between block_time and all snapshots
    time_diffs = (df["unixTime"] - block_time).abs()
    closest_idx = time_diffs.idxmin()
    closest_price = df.loc[closest_idx, "value"]
    return closest_price

# -------------------------------------------------------------------
def main():
    # Initialize configuration and database connections
    config = load_config()
    db_connection = DatabaseConnection(config.db)
    db_queries = DatabaseQueries(db_connection)

    try:
        logger.info("main: Starting main function execution.")

        # (1) Optionally update token information
        # logger.info("main: Calling update_tokens.main()...")
        # update_tokens_main()

        # (2) Fetch recent transactions (e.g., from the past 6 hours)
        logger.info("main: Fetching recent transactions...")
        transactions_df = db_queries.get_recent_transactions(n=3)
        logger.info(f"main: Fetched {len(transactions_df)} transactions.")

        # (3) Fetch token details once using the Birdeye API
        token_columns = ["open_input_mint", "open_output_mint", "close_input_mint", "close_output_mint"]
        unique_tokens = pd.unique(transactions_df[token_columns].values.ravel())
        logger.info(f"main: Found {len(unique_tokens)} unique token addresses for details.")
        chain_id = "solana"
        token_details_df = fetch_token_details(chain_id, unique_tokens, config.birdeye.api_key)

        # (4) Add new columns for tokens and their historical prices
        transactions_df["input_token"] = None
        transactions_df["output_token"] = None
        transactions_df["input_price"] = None
        transactions_df["output_price"] = None

        # (5) For each distinct token, fetch its historical price snapshots once
        logger.info("main: Fetching historical price data for each unique token...")
        token_history_data = {}
        for token in tqdm(unique_tokens, desc="Fetching token historical prices", unit="token"):
            df_history = fetch_historical_price(token, config.birdeye.api_key)
            if df_history is not None:
                token_history_data[token] = df_history
            else:
                logger.warning(f"main: No historical data found for token {token}.")
            sleep(0.2)  # To avoid rate limiting

        # (6) Process each transaction to look up the closest historical price for both input and output tokens
        logger.info("main: Processing transactions to calculate historical prices...")
        for index, row in tqdm(transactions_df.iterrows(), total=len(transactions_df), desc="Processing transactions"):
            if pd.notnull(row["open_input_mint"]):
                input_token = row["open_input_mint"]
                output_token = row["open_output_mint"]
                block_time = row["open_block_time"]
            else:
                input_token = row["close_input_mint"]
                output_token = row["close_output_mint"]
                block_time = row["close_block_time"]

            transactions_df.at[index, "input_token"] = input_token
            transactions_df.at[index, "output_token"] = output_token

            # Look up the closest price snapshot for each token based on block_time
            input_price = get_closest_price(input_token, block_time, token_history_data)
            output_price = get_closest_price(output_token, block_time, token_history_data)

            transactions_df.at[index, "input_price"] = input_price
            transactions_df.at[index, "output_price"] = output_price

        # (7) Calculate per-transaction dollar amounts
        logger.info("main: Calculating per-transaction dollar values...")
        transactions_df["dollars_sold"] = (
                transactions_df["in_amount"].astype(float) *
                transactions_df["input_price"].astype(float)
        )
        transactions_df["dollars_bought"] = (
                transactions_df["out_amount"].astype(float) *
                transactions_df["output_price"].astype(float)
        )

        # (8) Aggregate dollar amounts per token
        logger.info("main: Aggregating dollar values per token...")
        aggregated_sold = (
            transactions_df.groupby("input_token")["dollars_sold"]
            .sum()
            .reset_index()
            .rename(columns={"input_token": "token"})
        )
        aggregated_bought = (
            transactions_df.groupby("output_token")["dollars_bought"]
            .sum()
            .reset_index()
            .rename(columns={"output_token": "token"})
        )
        aggregated = pd.merge(aggregated_sold, aggregated_bought, on="token", how="outer")
        aggregated["dollars_sold"] = aggregated["dollars_sold"].fillna(0)
        aggregated["dollars_bought"] = aggregated["dollars_bought"].fillna(0)
        logger.info("main: Aggregated token values:")
        logger.info(aggregated)

        # (9) Merge aggregated data with token details
        # We merge on the token address field ("address") from the Birdeye API data.
        logger.info("main: Merging aggregated data with token details...")
        final_df = pd.merge(aggregated, token_details_df, left_on="token", right_on="address", how="left")

        # (10) Format dollars columns to use a comma as the decimal separator
        logger.info("main: Formatting dollar values with comma as decimal separator...")
        final_df["dollars_sold"] = final_df["dollars_sold"].apply(lambda x: f"{x:.2f}".replace('.',','))
        final_df["dollars_bought"] = final_df["dollars_bought"].apply(lambda x: f"{x:.2f}".replace('.',','))

        # (11) Remove timezone information for Excel compatibility
        for col in transactions_df.select_dtypes(include=["datetimetz"]).columns:
            transactions_df[col] = transactions_df[col].dt.tz_localize(None)
        for col in final_df.select_dtypes(include=["datetimetz"]).columns:
            final_df[col] = final_df[col].dt.tz_localize(None)

        # (12) Create a folder to store generated Excel files (if not exists) and write the final merged output to an Excel file.
        output_folder = "../data/"
        if not os.path.exists(output_folder):
            os.makedirs(output_folder)
            logger.info(f"main: Created output folder '{output_folder}'.")

        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        excel_filename = f"final_aggregated_token_details_{timestamp}.xlsx"
        output_path = os.path.join(output_folder, excel_filename)

        logger.info(f"main: Writing final aggregated token details to Excel file at '{output_path}'...")
        final_df.to_excel(output_path, index=False)
        logger.info("main: Final Excel file written successfully.")
        print(final_df)

    except Exception as e:
        logger.error(f"main: An error occurred: {e}", exc_info=True)
    finally:
        db_connection.close()
        logger.info("main: Database connection closed.")

if __name__ == "__main__":
    main()
# Out:
# INFO:__main__:main: Starting main function execution.
# INFO:__main__:main: Fetching recent transactions...
# INFO:db.queries:Fetching recent transactions for the past 3 hours.
# INFO:db.queries:Fetched 232 rows of transactions.
# INFO:__main__:main: Fetched 232 transactions.
# INFO:__main__:main: Found 84 unique token addresses for details.
# INFO:__main__:fetch_token_details: Starting to fetch details for 84 tokens on chain 'solana' using Birdeye API.
# Fetching token details:   0%|          | 0/84 [00:00<?, ?token/s]INFO:__main__:fetch_token_details: Fetching details for token: AT7RRrFhBU1Dw1WghdgAqeNKNXKomDFXm77owQgppump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=AT7RRrFhBU1Dw1WghdgAqeNKNXKomDFXm77owQgppump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: AT7RRrFhBU1Dw1WghdgAqeNKNXKomDFXm77owQgppump
# Fetching token details:   1%|          | 1/84 [00:00<00:38,  2.14token/s]INFO:__main__:fetch_token_details: Fetching details for token: EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v
# Fetching token details:   2%|▏         | 2/84 [00:00<00:37,  2.18token/s]INFO:__main__:fetch_token_details: Fetching details for token: EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm
# Fetching token details:   4%|▎         | 3/84 [00:01<00:36,  2.24token/s]INFO:__main__:fetch_token_details: Fetching details for token: 6dKCoWjpj5MFU5gWDEFdpUUeBasBLK3wLEwhUzQPAa1e
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=6dKCoWjpj5MFU5gWDEFdpUUeBasBLK3wLEwhUzQPAa1e HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 6dKCoWjpj5MFU5gWDEFdpUUeBasBLK3wLEwhUzQPAa1e
# Fetching token details:   5%|▍         | 4/84 [00:01<00:34,  2.34token/s]INFO:__main__:fetch_token_details: Fetching details for token: 27G8MtK7VtTcCHkpASjSDdkWWYfoqT6ggEuKidVJidD4
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=27G8MtK7VtTcCHkpASjSDdkWWYfoqT6ggEuKidVJidD4 HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 27G8MtK7VtTcCHkpASjSDdkWWYfoqT6ggEuKidVJidD4
# Fetching token details:   6%|▌         | 5/84 [00:02<00:32,  2.41token/s]INFO:__main__:fetch_token_details: Fetching details for token: 4FfTcjSySNCK5FMncfPYMFyp4QpFR4GERDKnfECr7ntg
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=4FfTcjSySNCK5FMncfPYMFyp4QpFR4GERDKnfECr7ntg HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 4FfTcjSySNCK5FMncfPYMFyp4QpFR4GERDKnfECr7ntg
# Fetching token details:   7%|▋         | 6/84 [00:02<00:33,  2.34token/s]INFO:__main__:fetch_token_details: Fetching details for token: J7tYmq2JnQPvxyhcXpCDrvJnc9R5ts8rv7tgVHDPsw7U
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=J7tYmq2JnQPvxyhcXpCDrvJnc9R5ts8rv7tgVHDPsw7U HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: J7tYmq2JnQPvxyhcXpCDrvJnc9R5ts8rv7tgVHDPsw7U
# Fetching token details:   8%|▊         | 7/84 [00:03<00:32,  2.34token/s]INFO:__main__:fetch_token_details: Fetching details for token: 9So52ugZh2BLBT3f7p61947q91uQh2DyvbfyMDeRpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=9So52ugZh2BLBT3f7p61947q91uQh2DyvbfyMDeRpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 9So52ugZh2BLBT3f7p61947q91uQh2DyvbfyMDeRpump
# Fetching token details:  10%|▉         | 8/84 [00:03<00:31,  2.39token/s]INFO:__main__:fetch_token_details: Fetching details for token: So11111111111111111111111111111111111111112
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=So11111111111111111111111111111111111111112 HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: So11111111111111111111111111111111111111112
# Fetching token details:  11%|█         | 9/84 [00:03<00:32,  2.28token/s]INFO:__main__:fetch_token_details: Fetching details for token: M3M3pSFptfpZYnWNUgAbyWzKKgPo5d1eWmX6tbiSF2K
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=M3M3pSFptfpZYnWNUgAbyWzKKgPo5d1eWmX6tbiSF2K HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: M3M3pSFptfpZYnWNUgAbyWzKKgPo5d1eWmX6tbiSF2K
# Fetching token details:  12%|█▏        | 10/84 [00:04<00:31,  2.34token/s]INFO:__main__:fetch_token_details: Fetching details for token: Grass7B4RdKfBCjTKgSqnXkqjwiGvQyFbuSCUJr3XXjs
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=Grass7B4RdKfBCjTKgSqnXkqjwiGvQyFbuSCUJr3XXjs HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: Grass7B4RdKfBCjTKgSqnXkqjwiGvQyFbuSCUJr3XXjs
# Fetching token details:  13%|█▎        | 11/84 [00:04<00:30,  2.39token/s]INFO:__main__:fetch_token_details: Fetching details for token: FFgfStKwuF3DSxEeogA69FNkPrkb7XDA5Tw29TBEpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=FFgfStKwuF3DSxEeogA69FNkPrkb7XDA5Tw29TBEpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: FFgfStKwuF3DSxEeogA69FNkPrkb7XDA5Tw29TBEpump
# Fetching token details:  14%|█▍        | 12/84 [00:05<00:29,  2.42token/s]INFO:__main__:fetch_token_details: Fetching details for token: HNg5PYJmtqcmzXrv6S9zP1CDKk5BgDuyFBxbvNApump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=HNg5PYJmtqcmzXrv6S9zP1CDKk5BgDuyFBxbvNApump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: HNg5PYJmtqcmzXrv6S9zP1CDKk5BgDuyFBxbvNApump
# Fetching token details:  15%|█▌        | 13/84 [00:05<00:29,  2.43token/s]INFO:__main__:fetch_token_details: Fetching details for token: 86t88w3MKT38HChTBKBwEeb1RW1MeTceaW68qY2Vpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=86t88w3MKT38HChTBKBwEeb1RW1MeTceaW68qY2Vpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 86t88w3MKT38HChTBKBwEeb1RW1MeTceaW68qY2Vpump
# Fetching token details:  17%|█▋        | 14/84 [00:05<00:29,  2.39token/s]INFO:__main__:fetch_token_details: Fetching details for token: AxriehR6Xw3adzHopnvMn7GcpRFcD41ddpiTWMg6pump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=AxriehR6Xw3adzHopnvMn7GcpRFcD41ddpiTWMg6pump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: AxriehR6Xw3adzHopnvMn7GcpRFcD41ddpiTWMg6pump
# Fetching token details:  18%|█▊        | 15/84 [00:06<00:28,  2.41token/s]INFO:__main__:fetch_token_details: Fetching details for token: STrikemJEk2tFVYpg7SMo9nGPrnJ56fHnS1K7PV2fPw
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=STrikemJEk2tFVYpg7SMo9nGPrnJ56fHnS1K7PV2fPw HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: STrikemJEk2tFVYpg7SMo9nGPrnJ56fHnS1K7PV2fPw
# Fetching token details:  19%|█▉        | 16/84 [00:06<00:28,  2.36token/s]INFO:__main__:fetch_token_details: Fetching details for token: 4WMcTsfEMNwhpPhfWDrnKAGintoFhmRcN5p1UDB6pump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=4WMcTsfEMNwhpPhfWDrnKAGintoFhmRcN5p1UDB6pump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 4WMcTsfEMNwhpPhfWDrnKAGintoFhmRcN5p1UDB6pump
# Fetching token details:  20%|██        | 17/84 [00:07<00:28,  2.35token/s]INFO:__main__:fetch_token_details: Fetching details for token: 8N55oASGu5qcJZixeZMTJnT5R1HeBuoa2DB6EaZBpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=8N55oASGu5qcJZixeZMTJnT5R1HeBuoa2DB6EaZBpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 8N55oASGu5qcJZixeZMTJnT5R1HeBuoa2DB6EaZBpump
# Fetching token details:  21%|██▏       | 18/84 [00:07<00:28,  2.34token/s]INFO:__main__:fetch_token_details: Fetching details for token: EcUgGEve9YX7Na4AtdqLH27V51iRZnoisDShQEGfpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=EcUgGEve9YX7Na4AtdqLH27V51iRZnoisDShQEGfpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: EcUgGEve9YX7Na4AtdqLH27V51iRZnoisDShQEGfpump
# Fetching token details:  23%|██▎       | 19/84 [00:08<00:27,  2.35token/s]INFO:__main__:fetch_token_details: Fetching details for token: 3NZ9JMVBmGAqocybic2c7LQCJScmgsAZ6vQqTDzcqmJh
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=3NZ9JMVBmGAqocybic2c7LQCJScmgsAZ6vQqTDzcqmJh HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 3NZ9JMVBmGAqocybic2c7LQCJScmgsAZ6vQqTDzcqmJh
# Fetching token details:  24%|██▍       | 20/84 [00:08<00:27,  2.35token/s]INFO:__main__:fetch_token_details: Fetching details for token: Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB
# Fetching token details:  25%|██▌       | 21/84 [00:08<00:26,  2.35token/s]INFO:__main__:fetch_token_details: Fetching details for token: 7mHCx9iXPJ7EJDbDAUGmej39Kme8cxZfeVi1EAvEpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=7mHCx9iXPJ7EJDbDAUGmej39Kme8cxZfeVi1EAvEpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 7mHCx9iXPJ7EJDbDAUGmej39Kme8cxZfeVi1EAvEpump
# Fetching token details:  26%|██▌       | 22/84 [00:09<00:26,  2.35token/s]INFO:__main__:fetch_token_details: Fetching details for token: CSChJMDH1drnxaN5ZXr8ZPZtqXv2FJqNTGcSujyfmoon
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=CSChJMDH1drnxaN5ZXr8ZPZtqXv2FJqNTGcSujyfmoon HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: CSChJMDH1drnxaN5ZXr8ZPZtqXv2FJqNTGcSujyfmoon
# Fetching token details:  27%|██▋       | 23/84 [00:09<00:25,  2.36token/s]INFO:__main__:fetch_token_details: Fetching details for token: jUfwXi6BWechD13bzp1R1h2AR3bSKuGkJd5qJmppump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=jUfwXi6BWechD13bzp1R1h2AR3bSKuGkJd5qJmppump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: jUfwXi6BWechD13bzp1R1h2AR3bSKuGkJd5qJmppump
# Fetching token details:  29%|██▊       | 24/84 [00:10<00:25,  2.36token/s]INFO:__main__:fetch_token_details: Fetching details for token: 9VpurAQLFaRQcTuJ3oVHdGDwJ8LRFWJA3ZVsYySsmoon
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=9VpurAQLFaRQcTuJ3oVHdGDwJ8LRFWJA3ZVsYySsmoon HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 9VpurAQLFaRQcTuJ3oVHdGDwJ8LRFWJA3ZVsYySsmoon
# Fetching token details:  30%|██▉       | 25/84 [00:10<00:24,  2.39token/s]INFO:__main__:fetch_token_details: Fetching details for token: 6P8ixuqGZpfyHAxyxbU4a31vsMiFiCQjBzVV58gPpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=6P8ixuqGZpfyHAxyxbU4a31vsMiFiCQjBzVV58gPpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 6P8ixuqGZpfyHAxyxbU4a31vsMiFiCQjBzVV58gPpump
# Fetching token details:  31%|███       | 26/84 [00:11<00:24,  2.38token/s]INFO:__main__:fetch_token_details: Fetching details for token: ANTT2Ve8c3JC6fAksFxUGtByzEHmJs49EupP7htA5W7j
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=ANTT2Ve8c3JC6fAksFxUGtByzEHmJs49EupP7htA5W7j HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: ANTT2Ve8c3JC6fAksFxUGtByzEHmJs49EupP7htA5W7j
# Fetching token details:  32%|███▏      | 27/84 [00:11<00:23,  2.40token/s]INFO:__main__:fetch_token_details: Fetching details for token: whispF7G9DHaojYHe2cdhRX5EMJzGBdqq7R57kL6inL
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=whispF7G9DHaojYHe2cdhRX5EMJzGBdqq7R57kL6inL HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: whispF7G9DHaojYHe2cdhRX5EMJzGBdqq7R57kL6inL
# Fetching token details:  33%|███▎      | 28/84 [00:11<00:23,  2.42token/s]INFO:__main__:fetch_token_details: Fetching details for token: BzpqoPc44oaHu9SB5hek1GRNjzc4UwFcL4oWusWozm3N
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=BzpqoPc44oaHu9SB5hek1GRNjzc4UwFcL4oWusWozm3N HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: BzpqoPc44oaHu9SB5hek1GRNjzc4UwFcL4oWusWozm3N
# Fetching token details:  35%|███▍      | 29/84 [00:12<00:23,  2.37token/s]INFO:__main__:fetch_token_details: Fetching details for token: CFrd1PnphJcNiGHtL3QYLb2Fvs1aBbJfah3FqgNPpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=CFrd1PnphJcNiGHtL3QYLb2Fvs1aBbJfah3FqgNPpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: CFrd1PnphJcNiGHtL3QYLb2Fvs1aBbJfah3FqgNPpump
# Fetching token details:  36%|███▌      | 30/84 [00:12<00:22,  2.37token/s]INFO:__main__:fetch_token_details: Fetching details for token: 7GCihgDB8fe6KNjn2MYtkzZcRjQy3t9GHdC8uHYmW2hr
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=7GCihgDB8fe6KNjn2MYtkzZcRjQy3t9GHdC8uHYmW2hr HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 7GCihgDB8fe6KNjn2MYtkzZcRjQy3t9GHdC8uHYmW2hr
# Fetching token details:  37%|███▋      | 31/84 [00:13<00:22,  2.35token/s]INFO:__main__:fetch_token_details: Fetching details for token: 6p6xgHyF7AeE6TZkSmFsko444wqoP15icUSqi2jfGiPN
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=6p6xgHyF7AeE6TZkSmFsko444wqoP15icUSqi2jfGiPN HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 6p6xgHyF7AeE6TZkSmFsko444wqoP15icUSqi2jfGiPN
# Fetching token details:  38%|███▊      | 32/84 [00:13<00:22,  2.29token/s]INFO:__main__:fetch_token_details: Fetching details for token: 9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump
# Fetching token details:  39%|███▉      | 33/84 [00:14<00:21,  2.35token/s]INFO:__main__:fetch_token_details: Fetching details for token: FasH397CeZLNYWkd3wWK9vrmjd1z93n3b59DssRXpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=FasH397CeZLNYWkd3wWK9vrmjd1z93n3b59DssRXpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: FasH397CeZLNYWkd3wWK9vrmjd1z93n3b59DssRXpump
# Fetching token details:  40%|████      | 34/84 [00:14<00:21,  2.35token/s]INFO:__main__:fetch_token_details: Fetching details for token: A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: A8C3xuqscfmyLrte3VmTqrAq8kgMASius9AFNANwpump
# Fetching token details:  42%|████▏     | 35/84 [00:14<00:21,  2.33token/s]INFO:__main__:fetch_token_details: Fetching details for token: 2z1p8xCEjRzpBHjXWrx4tJnz7BFL6z7NnvbCxH7bpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=2z1p8xCEjRzpBHjXWrx4tJnz7BFL6z7NnvbCxH7bpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 2z1p8xCEjRzpBHjXWrx4tJnz7BFL6z7NnvbCxH7bpump
# Fetching token details:  43%|████▎     | 36/84 [00:15<00:20,  2.31token/s]INFO:__main__:fetch_token_details: Fetching details for token: 2ru87k7yAZnDRsnqVpgJYETFgqVApuBcwB2xDb19pump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=2ru87k7yAZnDRsnqVpgJYETFgqVApuBcwB2xDb19pump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 2ru87k7yAZnDRsnqVpgJYETFgqVApuBcwB2xDb19pump
# Fetching token details:  44%|████▍     | 37/84 [00:15<00:19,  2.36token/s]INFO:__main__:fetch_token_details: Fetching details for token: 74SBV4zDXxTRgv1pEMoECskKBkZHc2yGPnc7GYVepump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=74SBV4zDXxTRgv1pEMoECskKBkZHc2yGPnc7GYVepump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 74SBV4zDXxTRgv1pEMoECskKBkZHc2yGPnc7GYVepump
# Fetching token details:  45%|████▌     | 38/84 [00:16<00:19,  2.35token/s]INFO:__main__:fetch_token_details: Fetching details for token: 7iagMTDPfNSR5zVcERT1To7A9eaQoz58dJAh42EMHcCC
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=7iagMTDPfNSR5zVcERT1To7A9eaQoz58dJAh42EMHcCC HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 7iagMTDPfNSR5zVcERT1To7A9eaQoz58dJAh42EMHcCC
# Fetching token details:  46%|████▋     | 39/84 [00:16<00:19,  2.36token/s]INFO:__main__:fetch_token_details: Fetching details for token: J9KTtypTWfSp912harLxd9jGz8iwsnqGmD5Yqgoopump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=J9KTtypTWfSp912harLxd9jGz8iwsnqGmD5Yqgoopump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: J9KTtypTWfSp912harLxd9jGz8iwsnqGmD5Yqgoopump
# Fetching token details:  48%|████▊     | 40/84 [00:16<00:18,  2.40token/s]INFO:__main__:fetch_token_details: Fetching details for token: 2RBko3xoz56aH69isQMUpzZd9NYHahhwC23A5F3Spkin
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=2RBko3xoz56aH69isQMUpzZd9NYHahhwC23A5F3Spkin HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 2RBko3xoz56aH69isQMUpzZd9NYHahhwC23A5F3Spkin
# Fetching token details:  49%|████▉     | 41/84 [00:17<00:18,  2.39token/s]INFO:__main__:fetch_token_details: Fetching details for token: 2eXamy7t3kvKhfV6aJ6Uwe3eh8cuREFcTKs1mFKZpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=2eXamy7t3kvKhfV6aJ6Uwe3eh8cuREFcTKs1mFKZpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 2eXamy7t3kvKhfV6aJ6Uwe3eh8cuREFcTKs1mFKZpump
# Fetching token details:  50%|█████     | 42/84 [00:17<00:17,  2.39token/s]INFO:__main__:fetch_token_details: Fetching details for token: DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263 HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263
# Fetching token details:  51%|█████     | 43/84 [00:18<00:17,  2.39token/s]INFO:__main__:fetch_token_details: Fetching details for token: 2KchKijPuwnwC92LPWVjFjRwB3WxKtzx9bbXZ7kRpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=2KchKijPuwnwC92LPWVjFjRwB3WxKtzx9bbXZ7kRpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 2KchKijPuwnwC92LPWVjFjRwB3WxKtzx9bbXZ7kRpump
# Fetching token details:  52%|█████▏    | 44/84 [00:18<00:16,  2.38token/s]INFO:__main__:fetch_token_details: Fetching details for token: jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v
# Fetching token details:  54%|█████▎    | 45/84 [00:19<00:16,  2.39token/s]INFO:__main__:fetch_token_details: Fetching details for token: 4TM1ZL64KjyxeffDLzaX7Eybg125qRpLF4tuzvutCu3M
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=4TM1ZL64KjyxeffDLzaX7Eybg125qRpLF4tuzvutCu3M HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 4TM1ZL64KjyxeffDLzaX7Eybg125qRpLF4tuzvutCu3M
# Fetching token details:  55%|█████▍    | 46/84 [00:19<00:15,  2.38token/s]INFO:__main__:fetch_token_details: Fetching details for token: 5z3EqYQo9HiCEs3R84RCDMu2n7anpDMxRhdK8PSWmrRC
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=5z3EqYQo9HiCEs3R84RCDMu2n7anpDMxRhdK8PSWmrRC HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 5z3EqYQo9HiCEs3R84RCDMu2n7anpDMxRhdK8PSWmrRC
# Fetching token details:  56%|█████▌    | 47/84 [00:19<00:15,  2.37token/s]INFO:__main__:fetch_token_details: Fetching details for token: 4Atupq32xLbD7Txa38fP2oxAv6RGNca62CBPw817vbxC
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=4Atupq32xLbD7Txa38fP2oxAv6RGNca62CBPw817vbxC HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 4Atupq32xLbD7Txa38fP2oxAv6RGNca62CBPw817vbxC
# Fetching token details:  57%|█████▋    | 48/84 [00:20<00:15,  2.32token/s]INFO:__main__:fetch_token_details: Fetching details for token: GzAFVCBvWfdyjWxvn1QXqSSS5caSTi62t9aCC6nV3ivD
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=GzAFVCBvWfdyjWxvn1QXqSSS5caSTi62t9aCC6nV3ivD HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: GzAFVCBvWfdyjWxvn1QXqSSS5caSTi62t9aCC6nV3ivD
# Fetching token details:  58%|█████▊    | 49/84 [00:20<00:15,  2.33token/s]INFO:__main__:fetch_token_details: Fetching details for token: 3iHMnc58WuVhBoEfkJKkUYDAypAe9XQKA11Luo5HkPpR
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=3iHMnc58WuVhBoEfkJKkUYDAypAe9XQKA11Luo5HkPpR HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 3iHMnc58WuVhBoEfkJKkUYDAypAe9XQKA11Luo5HkPpR
# Fetching token details:  60%|█████▉    | 50/84 [00:21<00:14,  2.35token/s]INFO:__main__:fetch_token_details: Fetching details for token: 9xb4jRNU4MYgfu87mkRFFjSZN9MTL5gayXHhxpKUpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=9xb4jRNU4MYgfu87mkRFFjSZN9MTL5gayXHhxpKUpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 9xb4jRNU4MYgfu87mkRFFjSZN9MTL5gayXHhxpKUpump
# Fetching token details:  61%|██████    | 51/84 [00:21<00:14,  2.35token/s]INFO:__main__:fetch_token_details: Fetching details for token: FddUq36DRuqDMyxxyLy4CxcU9evrsBCdKLtoAPHKpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=FddUq36DRuqDMyxxyLy4CxcU9evrsBCdKLtoAPHKpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: FddUq36DRuqDMyxxyLy4CxcU9evrsBCdKLtoAPHKpump
# Fetching token details:  62%|██████▏   | 52/84 [00:22<00:13,  2.40token/s]INFO:__main__:fetch_token_details: Fetching details for token: EoRe4xECTe9imaYtwfdmrGoinD2S1N5yMeu1LrjQpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=EoRe4xECTe9imaYtwfdmrGoinD2S1N5yMeu1LrjQpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: EoRe4xECTe9imaYtwfdmrGoinD2S1N5yMeu1LrjQpump
# Fetching token details:  63%|██████▎   | 53/84 [00:22<00:12,  2.40token/s]INFO:__main__:fetch_token_details: Fetching details for token: 4mEE8uXrqfM6LDpshWVJbSAJVmDsGJgQ2Bnq8SAApump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=4mEE8uXrqfM6LDpshWVJbSAJVmDsGJgQ2Bnq8SAApump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 4mEE8uXrqfM6LDpshWVJbSAJVmDsGJgQ2Bnq8SAApump
# Fetching token details:  64%|██████▍   | 54/84 [00:22<00:12,  2.39token/s]INFO:__main__:fetch_token_details: Fetching details for token: FeR8VBqNRSUD5NtXAj2n3j1dAHkZHfyDktKuLXD4pump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=FeR8VBqNRSUD5NtXAj2n3j1dAHkZHfyDktKuLXD4pump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: FeR8VBqNRSUD5NtXAj2n3j1dAHkZHfyDktKuLXD4pump
# Fetching token details:  65%|██████▌   | 55/84 [00:23<00:11,  2.43token/s]INFO:__main__:fetch_token_details: Fetching details for token: h5NciPdMZ5QCB5BYETJMYBMpVx9ZuitR6HcVjyBhood
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=h5NciPdMZ5QCB5BYETJMYBMpVx9ZuitR6HcVjyBhood HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: h5NciPdMZ5QCB5BYETJMYBMpVx9ZuitR6HcVjyBhood
# Fetching token details:  67%|██████▋   | 56/84 [00:23<00:11,  2.38token/s]INFO:__main__:fetch_token_details: Fetching details for token: 5mbK36SZ7J19An8jFochhQS4of8g6BwUjbeCSxBSoWdp
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=5mbK36SZ7J19An8jFochhQS4of8g6BwUjbeCSxBSoWdp HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 5mbK36SZ7J19An8jFochhQS4of8g6BwUjbeCSxBSoWdp
# Fetching token details:  68%|██████▊   | 57/84 [00:24<00:11,  2.37token/s]INFO:__main__:fetch_token_details: Fetching details for token: FVdo7CDJarhYoH6McyTFqx71EtzCPViinvdd1v86Qmy5
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=FVdo7CDJarhYoH6McyTFqx71EtzCPViinvdd1v86Qmy5 HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: FVdo7CDJarhYoH6McyTFqx71EtzCPViinvdd1v86Qmy5
# Fetching token details:  69%|██████▉   | 58/84 [00:24<00:11,  2.33token/s]INFO:__main__:fetch_token_details: Fetching details for token: FcsgEKX5cu2xeYQeQ5GiWKvPCEYmdBtPRTvYNFrLxoxo
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=FcsgEKX5cu2xeYQeQ5GiWKvPCEYmdBtPRTvYNFrLxoxo HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: FcsgEKX5cu2xeYQeQ5GiWKvPCEYmdBtPRTvYNFrLxoxo
# Fetching token details:  70%|███████   | 59/84 [00:25<00:10,  2.30token/s]INFO:__main__:fetch_token_details: Fetching details for token: ZEXy1pqteRu3n13kdyh4LwPQknkFk3GzmMYMuNadWPo
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=ZEXy1pqteRu3n13kdyh4LwPQknkFk3GzmMYMuNadWPo HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: ZEXy1pqteRu3n13kdyh4LwPQknkFk3GzmMYMuNadWPo
# Fetching token details:  71%|███████▏  | 60/84 [00:25<00:10,  2.36token/s]INFO:__main__:fetch_token_details: Fetching details for token: 61V8vBaqAGMpgDQi4JcAwo1dmBGHsyhzodcPqnEVpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=61V8vBaqAGMpgDQi4JcAwo1dmBGHsyhzodcPqnEVpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 61V8vBaqAGMpgDQi4JcAwo1dmBGHsyhzodcPqnEVpump
# Fetching token details:  73%|███████▎  | 61/84 [00:25<00:09,  2.38token/s]INFO:__main__:fetch_token_details: Fetching details for token: 7vfCXTUXx5WJV5JADk17DUJ4ksgau7utNKj4b963voxs
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=7vfCXTUXx5WJV5JADk17DUJ4ksgau7utNKj4b963voxs HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 7vfCXTUXx5WJV5JADk17DUJ4ksgau7utNKj4b963voxs
# Fetching token details:  74%|███████▍  | 62/84 [00:26<00:09,  2.38token/s]INFO:__main__:fetch_token_details: Fetching details for token: 9doRRAik5gvhbEwjbZDbZR6GxXSAfdoomyJR57xKpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=9doRRAik5gvhbEwjbZDbZR6GxXSAfdoomyJR57xKpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 9doRRAik5gvhbEwjbZDbZR6GxXSAfdoomyJR57xKpump
# Fetching token details:  75%|███████▌  | 63/84 [00:26<00:08,  2.38token/s]INFO:__main__:fetch_token_details: Fetching details for token: J3NKxxXZcnNiMjKw9hYb2K4LUxgwB6t1FtPtQVsv3KFr
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=J3NKxxXZcnNiMjKw9hYb2K4LUxgwB6t1FtPtQVsv3KFr HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: J3NKxxXZcnNiMjKw9hYb2K4LUxgwB6t1FtPtQVsv3KFr
# Fetching token details:  76%|███████▌  | 64/84 [00:27<00:08,  2.39token/s]INFO:__main__:fetch_token_details: Fetching details for token: GekTNfm84QfyP2GdAHZ5AgACBRd69aNmgA5FDhZupump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=GekTNfm84QfyP2GdAHZ5AgACBRd69aNmgA5FDhZupump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: GekTNfm84QfyP2GdAHZ5AgACBRd69aNmgA5FDhZupump
# Fetching token details:  77%|███████▋  | 65/84 [00:27<00:07,  2.40token/s]INFO:__main__:fetch_token_details: Fetching details for token: CzLSujWBLFsSjncfkh59rUFqvafWcY5tzedWJSuypump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=CzLSujWBLFsSjncfkh59rUFqvafWcY5tzedWJSuypump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: CzLSujWBLFsSjncfkh59rUFqvafWcY5tzedWJSuypump
# Fetching token details:  79%|███████▊  | 66/84 [00:27<00:07,  2.39token/s]INFO:__main__:fetch_token_details: Fetching details for token: GAMwtMB6onAvBNBQJCJFuxoaqfPH8uCQ2dewNMVVpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=GAMwtMB6onAvBNBQJCJFuxoaqfPH8uCQ2dewNMVVpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: GAMwtMB6onAvBNBQJCJFuxoaqfPH8uCQ2dewNMVVpump
# Fetching token details:  80%|███████▉  | 67/84 [00:28<00:07,  2.38token/s]INFO:__main__:fetch_token_details: Fetching details for token: 5LafQUrVco6o7KMz42eqVEJ9LW31StPyGjeeu5sKoMtA
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=5LafQUrVco6o7KMz42eqVEJ9LW31StPyGjeeu5sKoMtA HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 5LafQUrVco6o7KMz42eqVEJ9LW31StPyGjeeu5sKoMtA
# Fetching token details:  81%|████████  | 68/84 [00:28<00:06,  2.38token/s]INFO:__main__:fetch_token_details: Fetching details for token: Cy1GS2FqefgaMbi45UunrUzin1rfEmTUYnomddzBpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=Cy1GS2FqefgaMbi45UunrUzin1rfEmTUYnomddzBpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: Cy1GS2FqefgaMbi45UunrUzin1rfEmTUYnomddzBpump
# Fetching token details:  82%|████████▏ | 69/84 [00:29<00:06,  2.37token/s]INFO:__main__:fetch_token_details: Fetching details for token: JUPyiwrYJFskUPiHa7hkeR8VUtAeFoSYbKedZNsDvCN
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=JUPyiwrYJFskUPiHa7hkeR8VUtAeFoSYbKedZNsDvCN HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: JUPyiwrYJFskUPiHa7hkeR8VUtAeFoSYbKedZNsDvCN
# Fetching token details:  83%|████████▎ | 70/84 [00:29<00:05,  2.38token/s]INFO:__main__:fetch_token_details: Fetching details for token: DWEmswm2X2L3wbTmEfoyt5LqTtvFRha6HnNUfWfThuS6
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=DWEmswm2X2L3wbTmEfoyt5LqTtvFRha6HnNUfWfThuS6 HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: DWEmswm2X2L3wbTmEfoyt5LqTtvFRha6HnNUfWfThuS6
# Fetching token details:  85%|████████▍ | 71/84 [00:30<00:05,  2.35token/s]INFO:__main__:fetch_token_details: Fetching details for token: GEQxsGyc1HYbdVDzdk7qrX4zZ6334AHjswj1R3wgoxQE
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=GEQxsGyc1HYbdVDzdk7qrX4zZ6334AHjswj1R3wgoxQE HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: GEQxsGyc1HYbdVDzdk7qrX4zZ6334AHjswj1R3wgoxQE
# Fetching token details:  86%|████████▌ | 72/84 [00:30<00:05,  2.34token/s]INFO:__main__:fetch_token_details: Fetching details for token: HW7D5MyYG4Dz2C98axfjVBeLWpsEnofrqy6ZUwqwpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=HW7D5MyYG4Dz2C98axfjVBeLWpsEnofrqy6ZUwqwpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: HW7D5MyYG4Dz2C98axfjVBeLWpsEnofrqy6ZUwqwpump
# Fetching token details:  87%|████████▋ | 73/84 [00:30<00:04,  2.36token/s]INFO:__main__:fetch_token_details: Fetching details for token: 6AJcP7wuLwmRYLBNbi825wgguaPsWzPBEHcHndpRpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=6AJcP7wuLwmRYLBNbi825wgguaPsWzPBEHcHndpRpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 6AJcP7wuLwmRYLBNbi825wgguaPsWzPBEHcHndpRpump
# Fetching token details:  88%|████████▊ | 74/84 [00:31<00:04,  2.34token/s]INFO:__main__:fetch_token_details: Fetching details for token: Ai4CL1SAxVRigxQFwBH8S2JkuL7EqrdiGwTC7JpCpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=Ai4CL1SAxVRigxQFwBH8S2JkuL7EqrdiGwTC7JpCpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: Ai4CL1SAxVRigxQFwBH8S2JkuL7EqrdiGwTC7JpCpump
# Fetching token details:  89%|████████▉ | 75/84 [00:31<00:03,  2.28token/s]INFO:__main__:fetch_token_details: Fetching details for token: FUAfBo2jgks6gB4Z4LfZkqSZgzNucisEHqnNebaRxM1P
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=FUAfBo2jgks6gB4Z4LfZkqSZgzNucisEHqnNebaRxM1P HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: FUAfBo2jgks6gB4Z4LfZkqSZgzNucisEHqnNebaRxM1P
# Fetching token details:  90%|█████████ | 76/84 [00:32<00:03,  2.33token/s]INFO:__main__:fetch_token_details: Fetching details for token: FzsP5hGf2UHcLpwQjY8jwszHfNZShAfFaVLAXFs5HZBN
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=FzsP5hGf2UHcLpwQjY8jwszHfNZShAfFaVLAXFs5HZBN HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: FzsP5hGf2UHcLpwQjY8jwszHfNZShAfFaVLAXFs5HZBN
# Fetching token details:  92%|█████████▏| 77/84 [00:32<00:03,  2.30token/s]INFO:__main__:fetch_token_details: Fetching details for token: AKvyTsNr7v7x4WhEU6Z8X2Muh1uBTQNJgMoB39bB4LGE
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=AKvyTsNr7v7x4WhEU6Z8X2Muh1uBTQNJgMoB39bB4LGE HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: AKvyTsNr7v7x4WhEU6Z8X2Muh1uBTQNJgMoB39bB4LGE
# Fetching token details:  93%|█████████▎| 78/84 [00:33<00:02,  2.31token/s]INFO:__main__:fetch_token_details: Fetching details for token: EWMfSJgDCE7CXDAYz3hbCaA7NsFHTnddySXx3shco2Hs
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=EWMfSJgDCE7CXDAYz3hbCaA7NsFHTnddySXx3shco2Hs HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: EWMfSJgDCE7CXDAYz3hbCaA7NsFHTnddySXx3shco2Hs
# Fetching token details:  94%|█████████▍| 79/84 [00:33<00:02,  2.37token/s]INFO:__main__:fetch_token_details: Fetching details for token: 4dikXY7cZW2R5Zout46LLEGrS4Zn2K8Dm6AQJhtg1H56
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=4dikXY7cZW2R5Zout46LLEGrS4Zn2K8Dm6AQJhtg1H56 HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 4dikXY7cZW2R5Zout46LLEGrS4Zn2K8Dm6AQJhtg1H56
# Fetching token details:  95%|█████████▌| 80/84 [00:33<00:01,  2.41token/s]INFO:__main__:fetch_token_details: Fetching details for token: AATo232QyveLNTcUbxbv4LMLxaQe133a1jx3RjiGpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=AATo232QyveLNTcUbxbv4LMLxaQe133a1jx3RjiGpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: AATo232QyveLNTcUbxbv4LMLxaQe133a1jx3RjiGpump
# Fetching token details:  96%|█████████▋| 81/84 [00:34<00:01,  2.44token/s]INFO:__main__:fetch_token_details: Fetching details for token: 87aHjvVPYPyxqbfMcDNkbwLw22kiptHyxjNWAioCpump
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=87aHjvVPYPyxqbfMcDNkbwLw22kiptHyxjNWAioCpump HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 87aHjvVPYPyxqbfMcDNkbwLw22kiptHyxjNWAioCpump
# Fetching token details:  98%|█████████▊| 82/84 [00:34<00:00,  2.43token/s]INFO:__main__:fetch_token_details: Fetching details for token: FSTRgYfDaudjDwFg5A9LQpDMq5vxqhskHq4rkjUMwERE
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=FSTRgYfDaudjDwFg5A9LQpDMq5vxqhskHq4rkjUMwERE HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: FSTRgYfDaudjDwFg5A9LQpDMq5vxqhskHq4rkjUMwERE
# Fetching token details:  99%|█████████▉| 83/84 [00:35<00:00,  2.31token/s]INFO:__main__:fetch_token_details: Fetching details for token: 9McvH6w97oewLmPxqQEoHUAv3u5iYMyQ9AeZZhguYf1T
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/token_overview?address=9McvH6w97oewLmPxqQEoHUAv3u5iYMyQ9AeZZhguYf1T HTTP/1.1" 200 None
# INFO:__main__:fetch_token_details: Retrieved details for token: 9McvH6w97oewLmPxqQEoHUAv3u5iYMyQ9AeZZhguYf1T
# Fetching token details: 100%|██████████| 84/84 [00:35<00:00,  2.36token/s]
# INFO:__main__:fetch_token_details: Finished fetching all token details.
# INFO:__main__:main: Fetching historical price data for each unique token...
# Fetching token historical prices:   0%|          | 0/84 [00:00<?, ?token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'AT7RRrFhBU1Dw1WghdgAqeNKNXKomDFXm77owQgppump' from 1738920872 to 1739109572.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=AT7RRrFhBU1Dw1WghdgAqeNKNXKomDFXm77owQgppump&address_type=token&type=5m&time_from=1738920872&time_to=1739109572 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'AT7RRrFhBU1Dw1WghdgAqeNKNXKomDFXm77owQgppump'.
# Fetching token historical prices:   1%|          | 1/84 [00:00<00:35,  2.32token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v' from 1738920872 to 1739109572.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v&address_type=token&type=5m&time_from=1738920872&time_to=1739109572 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v'.
# Fetching token historical prices:   2%|▏         | 2/84 [00:00<00:34,  2.35token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm' from 1738920873 to 1739109573.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# ...
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'GEQxsGyc1HYbdVDzdk7qrX4zZ6334AHjswj1R3wgoxQE'.
# Fetching token historical prices:  86%|████████▌ | 72/84 [00:38<00:05,  2.17token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'HW7D5MyYG4Dz2C98axfjVBeLWpsEnofrqy6ZUwqwpump' from 1738920910 to 1739109610.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=HW7D5MyYG4Dz2C98axfjVBeLWpsEnofrqy6ZUwqwpump&address_type=token&type=5m&time_from=1738920910&time_to=1739109610 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'HW7D5MyYG4Dz2C98axfjVBeLWpsEnofrqy6ZUwqwpump'.
# Fetching token historical prices:  87%|████████▋ | 73/84 [00:38<00:04,  2.22token/s]INFO:__main__:fetch_historical_price: Requesting history for token '6AJcP7wuLwmRYLBNbi825wgguaPsWzPBEHcHndpRpump' from 1738920911 to 1739109611.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=6AJcP7wuLwmRYLBNbi825wgguaPsWzPBEHcHndpRpump&address_type=token&type=5m&time_from=1738920911&time_to=1739109611 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '6AJcP7wuLwmRYLBNbi825wgguaPsWzPBEHcHndpRpump'.
# Fetching token historical prices:  88%|████████▊ | 74/84 [00:39<00:04,  2.25token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'Ai4CL1SAxVRigxQFwBH8S2JkuL7EqrdiGwTC7JpCpump' from 1738920911 to 1739109611.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=Ai4CL1SAxVRigxQFwBH8S2JkuL7EqrdiGwTC7JpCpump&address_type=token&type=5m&time_from=1738920911&time_to=1739109611 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'Ai4CL1SAxVRigxQFwBH8S2JkuL7EqrdiGwTC7JpCpump'.
# Fetching token historical prices:  89%|████████▉ | 75/84 [00:39<00:04,  2.25token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'FUAfBo2jgks6gB4Z4LfZkqSZgzNucisEHqnNebaRxM1P' from 1738920912 to 1739109612.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=FUAfBo2jgks6gB4Z4LfZkqSZgzNucisEHqnNebaRxM1P&address_type=token&type=5m&time_from=1738920912&time_to=1739109612 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'FUAfBo2jgks6gB4Z4LfZkqSZgzNucisEHqnNebaRxM1P'.
# Fetching token historical prices:  90%|█████████ | 76/84 [00:40<00:03,  2.26token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'FzsP5hGf2UHcLpwQjY8jwszHfNZShAfFaVLAXFs5HZBN' from 1738920912 to 1739109612.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=FzsP5hGf2UHcLpwQjY8jwszHfNZShAfFaVLAXFs5HZBN&address_type=token&type=5m&time_from=1738920912&time_to=1739109612 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'FzsP5hGf2UHcLpwQjY8jwszHfNZShAfFaVLAXFs5HZBN'.
# Fetching token historical prices:  92%|█████████▏| 77/84 [00:40<00:03,  2.26token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'AKvyTsNr7v7x4WhEU6Z8X2Muh1uBTQNJgMoB39bB4LGE' from 1738920912 to 1739109612.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=AKvyTsNr7v7x4WhEU6Z8X2Muh1uBTQNJgMoB39bB4LGE&address_type=token&type=5m&time_from=1738920912&time_to=1739109612 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'AKvyTsNr7v7x4WhEU6Z8X2Muh1uBTQNJgMoB39bB4LGE'.
# Fetching token historical prices:  93%|█████████▎| 78/84 [00:41<00:02,  2.26token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'EWMfSJgDCE7CXDAYz3hbCaA7NsFHTnddySXx3shco2Hs' from 1738920913 to 1739109613.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=EWMfSJgDCE7CXDAYz3hbCaA7NsFHTnddySXx3shco2Hs&address_type=token&type=5m&time_from=1738920913&time_to=1739109613 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'EWMfSJgDCE7CXDAYz3hbCaA7NsFHTnddySXx3shco2Hs'.
# Fetching token historical prices:  94%|█████████▍| 79/84 [00:41<00:02,  2.29token/s]INFO:__main__:fetch_historical_price: Requesting history for token '4dikXY7cZW2R5Zout46LLEGrS4Zn2K8Dm6AQJhtg1H56' from 1738920913 to 1739109613.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=4dikXY7cZW2R5Zout46LLEGrS4Zn2K8Dm6AQJhtg1H56&address_type=token&type=5m&time_from=1738920913&time_to=1739109613 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '4dikXY7cZW2R5Zout46LLEGrS4Zn2K8Dm6AQJhtg1H56'.
# Fetching token historical prices:  95%|█████████▌| 80/84 [00:42<00:01,  2.25token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'AATo232QyveLNTcUbxbv4LMLxaQe133a1jx3RjiGpump' from 1738920914 to 1739109614.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=AATo232QyveLNTcUbxbv4LMLxaQe133a1jx3RjiGpump&address_type=token&type=5m&time_from=1738920914&time_to=1739109614 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'AATo232QyveLNTcUbxbv4LMLxaQe133a1jx3RjiGpump'.
# Fetching token historical prices:  96%|█████████▋| 81/84 [00:42<00:01,  2.16token/s]INFO:__main__:fetch_historical_price: Requesting history for token '87aHjvVPYPyxqbfMcDNkbwLw22kiptHyxjNWAioCpump' from 1738920914 to 1739109614.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=87aHjvVPYPyxqbfMcDNkbwLw22kiptHyxjNWAioCpump&address_type=token&type=5m&time_from=1738920914&time_to=1739109614 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '87aHjvVPYPyxqbfMcDNkbwLw22kiptHyxjNWAioCpump'.
# Fetching token historical prices:  98%|█████████▊| 82/84 [00:42<00:00,  2.22token/s]INFO:__main__:fetch_historical_price: Requesting history for token 'FSTRgYfDaudjDwFg5A9LQpDMq5vxqhskHq4rkjUMwERE' from 1738920915 to 1739109615.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=FSTRgYfDaudjDwFg5A9LQpDMq5vxqhskHq4rkjUMwERE&address_type=token&type=5m&time_from=1738920915&time_to=1739109615 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token 'FSTRgYfDaudjDwFg5A9LQpDMq5vxqhskHq4rkjUMwERE'.
# Fetching token historical prices:  99%|█████████▉| 83/84 [00:43<00:00,  2.27token/s]INFO:__main__:fetch_historical_price: Requesting history for token '9McvH6w97oewLmPxqQEoHUAv3u5iYMyQ9AeZZhguYf1T' from 1738920915 to 1739109615.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): public-api.birdeye.so:443
# DEBUG:urllib3.connectionpool:https://public-api.birdeye.so:443 "GET /defi/history_price?address=9McvH6w97oewLmPxqQEoHUAv3u5iYMyQ9AeZZhguYf1T&address_type=token&type=5m&time_from=1738920915&time_to=1739109615 HTTP/1.1" 200 None
# INFO:__main__:fetch_historical_price: Retrieved 629 price snapshots for token '9McvH6w97oewLmPxqQEoHUAv3u5iYMyQ9AeZZhguYf1T'.
# Fetching token historical prices: 100%|██████████| 84/84 [00:43<00:00,  1.91token/s]
# INFO:__main__:main: Processing transactions to calculate historical prices...
# Processing transactions: 100%|██████████| 232/232 [00:00<00:00, 2808.78it/s]
# INFO:__main__:main: Calculating per-transaction dollar values...
# INFO:__main__:main: Aggregating dollar values per token...
# INFO:__main__:main: Aggregated token values:
# INFO:__main__:                                           token  dollars_sold  dollars_bought
# 0   27G8MtK7VtTcCHkpASjSDdkWWYfoqT6ggEuKidVJidD4   5167.170567     5050.654246
# 1   2KchKijPuwnwC92LPWVjFjRwB3WxKtzx9bbXZ7kRpump   2242.652560        0.000000
# 2   2RBko3xoz56aH69isQMUpzZd9NYHahhwC23A5F3Spkin      0.000000      329.750509
# 3   2eXamy7t3kvKhfV6aJ6Uwe3eh8cuREFcTKs1mFKZpump      0.000000    12536.422425
# 4   2ru87k7yAZnDRsnqVpgJYETFgqVApuBcwB2xDb19pump  16535.504022        0.000000
# ..                                           ...           ...             ...
# 79   ZEXy1pqteRu3n13kdyh4LwPQknkFk3GzmMYMuNadWPo      0.000000      990.052200
# 80   h5NciPdMZ5QCB5BYETJMYBMpVx9ZuitR6HcVjyBhood  20415.072324        0.000000
# 81   jUfwXi6BWechD13bzp1R1h2AR3bSKuGkJd5qJmppump  29164.151719     4750.597404
# 82   jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v      0.000000     2034.045997
# 83   whispF7G9DHaojYHe2cdhRX5EMJzGBdqq7R57kL6inL      0.000000    48324.741983
#
# [84 rows x 3 columns]
# INFO:__main__:main: Merging aggregated data with token details...
# INFO:__main__:main: Formatting dollar values with comma as decimal separator...
# INFO:__main__:main: Writing final aggregated token details to Excel file at '../data/final_aggregated_token_details_20250209_150016.xlsx'...
# INFO:__main__:main: Final Excel file written successfully.
# INFO:__main__:main: Database connection closed.
#                                            token dollars_sold dollars_bought  \
# 0   27G8MtK7VtTcCHkpASjSDdkWWYfoqT6ggEuKidVJidD4      5167,17        5050,65
# 1   2KchKijPuwnwC92LPWVjFjRwB3WxKtzx9bbXZ7kRpump      2242,65           0,00
# 2   2RBko3xoz56aH69isQMUpzZd9NYHahhwC23A5F3Spkin         0,00         329,75
# 3   2eXamy7t3kvKhfV6aJ6Uwe3eh8cuREFcTKs1mFKZpump         0,00       12536,42
# 4   2ru87k7yAZnDRsnqVpgJYETFgqVApuBcwB2xDb19pump     16535,50           0,00
# ..                                           ...          ...            ...
# 79   ZEXy1pqteRu3n13kdyh4LwPQknkFk3GzmMYMuNadWPo         0,00         990,05
# 80   h5NciPdMZ5QCB5BYETJMYBMpVx9ZuitR6HcVjyBhood     20415,07           0,00
# 81   jUfwXi6BWechD13bzp1R1h2AR3bSKuGkJd5qJmppump     29164,15        4750,60
# 82   jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v         0,00        2034,05
# 83   whispF7G9DHaojYHe2cdhRX5EMJzGBdqq7R57kL6inL         0,00       48324,74
#
#                                          address  decimals  symbol  \
# 0   27G8MtK7VtTcCHkpASjSDdkWWYfoqT6ggEuKidVJidD4         6     JLP
# 1   2KchKijPuwnwC92LPWVjFjRwB3WxKtzx9bbXZ7kRpump         6    FUKU
# 2   2RBko3xoz56aH69isQMUpzZd9NYHahhwC23A5F3Spkin         6    PKIN
# 3   2eXamy7t3kvKhfV6aJ6Uwe3eh8cuREFcTKs1mFKZpump         6    nuit
# 4   2ru87k7yAZnDRsnqVpgJYETFgqVApuBcwB2xDb19pump         6    BIAO
# ..                                           ...       ...     ...
# 79   ZEXy1pqteRu3n13kdyh4LwPQknkFk3GzmMYMuNadWPo         6     ZEX
# 80   h5NciPdMZ5QCB5BYETJMYBMpVx9ZuitR6HcVjyBhood         6    HOOD
# 81   jUfwXi6BWechD13bzp1R1h2AR3bSKuGkJd5qJmppump         6   MARSH
# 82   jupSoLaHXQiZZTSfEWMTRRgpnyFm8f6sZdosWBjx93v         9  JupSOL
# 83   whispF7G9DHaojYHe2cdhRX5EMJzGBdqq7R57kL6inL         6   WHISP
#
#                   name                                         extensions  \
# 0     Jupiter Perps LP  {'coingeckoId': 'jupiter-perpetuals-liquidity-...
# 1            Fukupuku   {'coingeckoId': 'fuku-2', 'description': 'Hi I...
# 2              PUMPKIN  {'twitter': 'https://x.com/pumpkindotfun', 'we...
# 3                 nuit  {'description': 'Notte transforms the internet...
# 4                 BIAO  {'coingeckoId': 'biao-on-sol', 'description': ...
# ..                 ...                                                ...
# 79                Zeta  {'coingeckoId': 'zeta', 'description': 'ZEX is...
# 80           Robinhood  {'description': 'Robinhood colluded with Wall ...
# 81          Marsh Coin  {'twitter': 'https://x.com/marshcoinsol', 'web...
# 82  Jupiter Staked SOL  {'coingeckoId': 'jupiter-staked-sol', 'twitter...
# 83               WHISP  {'description': 'I am Whisp, the gateway to th...
#
#                                               logoURI     liquidity  ...  \
# 0                  https://static.jup.ag/jlp/icon.png  2.700158e+07  ...
# 1   https://ipfs.io/ipfs/QmNmqqwWCGzyKJfX2uLmUFrzf...  5.247109e+05  ...
# 2   https://18564990519de0ce20cba215aa970ca1.ipfsc...  6.588769e+06  ...
# 3   https://ipfs.io/ipfs/QmXVLXErjusKBA7ULADdKNFmk...  8.964647e+05  ...
# 4   https://ipfs.io/ipfs/QmT5p12s821591NjE88Vg2eaM...  1.557955e+05  ...
# ..                                                ...           ...  ...
# 79  https://raw.githubusercontent.com/zetamarkets/...  2.208006e+05  ...
# 80  https://gateway.pinata.cloud/ipfs/bafkreihz4vf...  1.422236e+06  ...
# 81  https://ipfs.io/ipfs/QmdExm1rmxegtWHYD94GhwEoJ...  5.364783e-01  ...
# 82              https://static.jup.ag/jupSOL/icon.png  7.961512e+06  ...
# 83  https://arweave.net/jRpN9SLH1m5uNVSGGwJ9P2YAL6...  1.407613e+06  ...
#
#       vBuy24hUSD vBuyHistory24h  vBuyHistory24hUSD  vBuy24hChangePercent  \
# 0   5.004306e+07   1.796292e+07       7.911070e+07            -37.224357
# 1   5.933141e+05   1.153850e+08       6.354711e+05             -1.238650
# 2   6.017138e+06   7.963081e+07       1.310109e+06            244.300744
# 3   7.349927e+05   1.095336e+08       8.257438e+05            -21.466451
# 4   5.164107e+04   3.254507e+07       3.378710e+04            120.896368
# ..           ...            ...                ...                   ...
# 79  2.292714e+04   1.633721e+05       7.388064e+03            213.077058
# 80  4.816136e+06   6.181564e+09       4.319957e+06             47.720640
# 81  1.688784e+06   7.027518e+09       4.382898e+06             62.161491
# 82  9.157082e+06   6.793163e+04       1.425484e+07            -37.763773
# 83  7.148380e+06   7.952848e+07       3.700579e+05            631.836972
#
#         vSell24h   vSell24hUSD  vSellHistory24h  vSellHistory24hUSD  \
# 0   1.205650e+07  5.349448e+07     1.816448e+07        7.998598e+07
# 1   1.158277e+08  5.997496e+05     1.160816e+08        6.340976e+05
# 2   2.467703e+08  5.392634e+06     8.216090e+07        1.340861e+06
# 3   8.956698e+07  7.568162e+05     1.089395e+08        8.162468e+05
# 4   1.321065e+08  9.555958e+04     4.799895e+07        5.017829e+04
# ..           ...           ...              ...                 ...
# 79  4.964244e+05  2.214492e+04     1.968732e+05        8.864048e+03
# 80  9.090766e+09  4.770335e+06     6.787274e+09        4.714191e+06
# 81  1.227932e+10  1.758102e+06     6.123306e+09        4.331578e+06
# 82  2.660659e+04  5.777344e+06     3.891386e+04        8.116483e+06
# 83  5.404409e+08  6.664159e+06     8.866781e+07        4.155423e+05
#
#     vSell24hChangePercent  numberMarkets
# 0              -33.625959            134
# 1               -0.218699              7
# 2              200.350006             35
# 3              -17.782825             16
# 4              175.227824              3
# ..                    ...            ...
# 79             152.154415              9
# 80              33.938390             25
# 81             100.534231              3
# 82             -31.626963             47
# 83             509.511885              9
#
# [84 rows x 197 columns]
